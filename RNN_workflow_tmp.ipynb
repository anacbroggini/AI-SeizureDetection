# %% [markdown]
# ## Pre-Processing

# %%
from source import data_import
from source.constants import CHANNELS, DEFAULT_PATIENTS
import numpy as np
import pandas as pd
# import modin.pandas as pd

from source.filter_eeg_channels import filter_eeg_channels
from source.calculate_mean_psd import calculate_mean_psd
from source.constants import CHANNELS, FREQUENCY_RANGES
                                            
from sklearn.preprocessing import StandardScaler, minmax_scale, MinMaxScaler

# %%
def load_file(file_name):
    if file_name.endswith('.arrow'):
        return data_import.load_pyarrow(file_name=file_name)
    elif file_name.endswith('.npy'):
        print('loading npy')
        return np.load('data/' + file_name, allow_pickle=True)
    else:
        print('no filename provided, trying npy')
        try:
            np.load('data/' + file_name + '.npy', allow_pickle=True)
        except FileNotFoundError:
            print('no npy file found, trying arrow')
            return data_import.load_pyarrow(file_name=file_name + '.arrow')
        
def save_file(data, file_name):
    if file_name is None:
        print('skipping save file.')
    elif file_name.endswith('.arrow'):
        data_import.save_pyarrow(data, file_name=file_name)
    elif file_name.endswith('.npy'):
        print('saving npy')
        np.save('data/' + file_name, data)
    else:
        print('no filetype provided, saving as npy')
        np.save('data/' + file_name + '.npy', data)

# %%
## PARAMETERS ##
SKIP_DATA = False
data_filename = "processed_data.arrow" # data will be loaded/saved with this filename. Put None to skip saving the file

SKIP_FEATURES = False
feature_filename = 'extracted_features.npy' # data will be loaded/saved with this filename. Put None to skip saving the file

### DATA ###
# Load Patient Data #
patient_ids = DEFAULT_PATIENTS #DEFAULT_PATIENTS # use DEFAULT_PATIENTS for default patients selection
nr_segments=60
segment_duration=1
ictal_segmentation_foo=data_import.preictal_segmentation
interictal_segmentation_foo=data_import.inter_segmentation
channels=CHANNELS
seizure_offset=0

# filter #
exclude_ranges=[[58, 62], [118, 122]]

### FEATURES ###
target_colname = 'target'
PRED_INTERVAL = 6000 # how long should a segment count as preictal in seconds

window_size = 30 # Define the sequence_train window size

# %%
if not SKIP_DATA:
    # Load Patient Data
    p_df = data_import.load_segmented_data(patient_ids=patient_ids,
                                            nr_segments=nr_segments,
                                            segment_duration=segment_duration,
                                            ictal_segmentation_foo=data_import.preictal_segmentation,
                                            interictal_segmentation_foo=data_import.inter_segmentation,
                                            channels=channels,
                                            seizure_offset=seizure_offset
                                            )
    
    # Filter
    fit_df = filter_eeg_channels(p_df, CHANNELS, fs=256, exclude_ranges=exclude_ranges, Q=30)
    pd_toconcat = p_df[['epoch', 'segment_id']]
    fit_df = pd.concat(objs=[fit_df, pd_toconcat], axis =1)
    save_file(data=fit_df, file_name=data_filename)
else:
    fit_df = load_file(data_filename)
    fit_df = pd.DataFrame(fit_df)
fit_df.head
# Out:
# chb01_01.edf was import but not resampled 256Hz.
# chb01_02.edf was import but not resampled 256Hz.
# chb01_03.edf was import but not resampled 256Hz.
# chb01_03.edf seizure and buffer was labeled
# chb01_04.edf was import but not resampled 256Hz.
# chb01_04.edf seizure and buffer was labeled
# chb01_05.edf was import but not resampled 256Hz.
# chb01_06.edf was import but not resampled 256Hz.
# chb01_07.edf was import but not resampled 256Hz.
# chb01_08.edf was import but not resampled 256Hz.
# chb01_09.edf was import but not resampled 256Hz.
# chb01_10.edf was import but not resampled 256Hz.
# chb01_11.edf was import but not resampled 256Hz.
# chb01_12.edf was import but not resampled 256Hz.
# chb01_13.edf was import but not resampled 256Hz.
# chb01_14.edf was import but not resampled 256Hz.
# chb01_15.edf was import but not resampled 256Hz.
# chb01_15.edf seizure and buffer was labeled
# chb01_16.edf was import but not resampled 256Hz.
# chb01_16.edf seizure and buffer was labeled
# chb01_17.edf was import but not resampled 256Hz.
# chb01_18.edf was import but not resampled 256Hz.
# chb01_18.edf seizure and buffer was labeled
# chb01_19.edf was import but not resampled 256Hz.
# chb01_20.edf was import but not resampled 256Hz.
# chb01_21.edf was import but not resampled 256Hz.
# chb01_21.edf seizure and buffer was labeled
# chb01_22.edf was import but not resampled 256Hz.
# chb01_23.edf was import but not resampled 256Hz.
# chb01_24.edf was import but not resampled 256Hz.
# chb01_25.edf was import but not resampled 256Hz.
# chb01_26.edf was import but not resampled 256Hz.
# chb01_26.edf seizure and buffer was labeled
# chb01_27.edf was import but not resampled 256Hz.
# chb01_29.edf was import but not resampled 256Hz.
# chb01_30.edf was import but not resampled 256Hz.
# chb01_31.edf was import but not resampled 256Hz.
# chb01_32.edf was import but not resampled 256Hz.
# chb01_33.edf was import but not resampled 256Hz.
# chb01_34.edf was import but not resampled 256Hz.
# chb01_36.edf was import but not resampled 256Hz.
# chb01_37.edf was import but not resampled 256Hz.
# chb01_38.edf was import but not resampled 256Hz.
# chb01_39.edf was import but not resampled 256Hz.
# chb01_40.edf was import but not resampled 256Hz.
# chb01_41.edf was import but not resampled 256Hz.
# chb01_42.edf was import but not resampled 256Hz.
# chb01_43.edf was import but not resampled 256Hz.
# chb01_46.edf was import but not resampled 256Hz.
# chb02_01.edf was import but not resampled 256Hz.
# chb02_02.edf was import but not resampled 256Hz.
# chb02_03.edf was import but not resampled 256Hz.
# chb02_04.edf was import but not resampled 256Hz.
# chb02_05.edf was import but not resampled 256Hz.
# chb02_06.edf was import but not resampled 256Hz.
# chb02_07.edf was import but not resampled 256Hz.
# chb02_08.edf was import but not resampled 256Hz.
# chb02_09.edf was import but not resampled 256Hz.
# chb02_10.edf was import but not resampled 256Hz.
# chb02_11.edf was import but not resampled 256Hz.
# chb02_12.edf was import but not resampled 256Hz.
# chb02_13.edf was import but not resampled 256Hz.
# chb02_14.edf was import but not resampled 256Hz.
# chb02_15.edf was import but not resampled 256Hz.
# chb02_16+.edf was import but not resampled 256Hz.
# chb02_16+.edf seizure and buffer was labeled
# chb02_16.edf was import but not resampled 256Hz.
# chb02_16.edf seizure and buffer was labeled
# chb02_17.edf was import but not resampled 256Hz.
# chb02_18.edf was import but not resampled 256Hz.
# chb02_19.edf was import but not resampled 256Hz.
# chb02_19.edf seizure and buffer was labeled
# chb02_20.edf was import but not resampled 256Hz.
# chb02_21.edf was import but not resampled 256Hz.
# chb02_22.edf was import but not resampled 256Hz.
# chb02_23.edf was import but not resampled 256Hz.
# chb02_24.edf was import but not resampled 256Hz.
# chb02_25.edf was import but not resampled 256Hz.
# chb02_26.edf was import but not resampled 256Hz.
# chb02_27.edf was import but not resampled 256Hz.
# chb02_28.edf was import but not resampled 256Hz.
# chb02_29.edf was import but not resampled 256Hz.
# chb02_30.edf was import but not resampled 256Hz.
# chb02_31.edf was import but not resampled 256Hz.
# chb02_32.edf was import but not resampled 256Hz.
# chb02_33.edf was import but not resampled 256Hz.
# chb02_34.edf was import but not resampled 256Hz.
# chb02_35.edf was import but not resampled 256Hz.
# chb03_01.edf was import but not resampled 256Hz.
# chb03_01.edf seizure and buffer was labeled
# chb03_02.edf was import but not resampled 256Hz.
# chb03_02.edf seizure and buffer was labeled
# chb03_03.edf was import but not resampled 256Hz.
# chb03_03.edf seizure and buffer was labeled
# chb03_04.edf was import but not resampled 256Hz.
# chb03_04.edf seizure and buffer was labeled
# chb03_05.edf was import but not resampled 256Hz.
# chb03_06.edf was import but not resampled 256Hz.
# chb03_07.edf was import but not resampled 256Hz.
# chb03_08.edf was import but not resampled 256Hz.
# chb03_09.edf was import but not resampled 256Hz.
# chb03_10.edf was import but not resampled 256Hz.
# chb03_11.edf was import but not resampled 256Hz.
# chb03_12.edf was import but not resampled 256Hz.
# chb03_13.edf was import but not resampled 256Hz.
# chb03_14.edf was import but not resampled 256Hz.
# chb03_15.edf was import but not resampled 256Hz.
# chb03_16.edf was import but not resampled 256Hz.
# chb03_17.edf was import but not resampled 256Hz.
# chb03_18.edf was import but not resampled 256Hz.
# chb03_19.edf was import but not resampled 256Hz.
# chb03_20.edf was import but not resampled 256Hz.
# chb03_21.edf was import but not resampled 256Hz.
# chb03_22.edf was import but not resampled 256Hz.
# chb03_23.edf was import but not resampled 256Hz.
# chb03_24.edf was import but not resampled 256Hz.
# chb03_25.edf was import but not resampled 256Hz.
# chb03_26.edf was import but not resampled 256Hz.
# chb03_27.edf was import but not resampled 256Hz.
# chb03_28.edf was import but not resampled 256Hz.
# chb03_29.edf was import but not resampled 256Hz.
# chb03_30.edf was import but not resampled 256Hz.
# chb03_31.edf was import but not resampled 256Hz.
# chb03_32.edf was import but not resampled 256Hz.
# chb03_33.edf was import but not resampled 256Hz.
# chb03_34.edf was import but not resampled 256Hz.
# chb03_34.edf seizure and buffer was labeled
# chb03_35.edf was import but not resampled 256Hz.
# chb03_35.edf seizure and buffer was labeled
# chb03_36.edf was import but not resampled 256Hz.
# chb03_36.edf seizure and buffer was labeled
# chb03_37.edf was import but not resampled 256Hz.
# chb03_38.edf was import but not resampled 256Hz.
# chb04_01.edf was import but not resampled 256Hz.
# chb04_02.edf was import but not resampled 256Hz.
# chb04_03.edf was import but not resampled 256Hz.
# chb04_04.edf was import but not resampled 256Hz.
# chb04_05.edf was import but not resampled 256Hz.
# chb04_05.edf seizure and buffer was labeled
# chb04_06.edf was import but not resampled 256Hz.
# chb04_07.edf was import but not resampled 256Hz.
# chb04_08.edf was import but not resampled 256Hz.
# chb04_08.edf seizure and buffer was labeled
# chb04_09.edf was import but not resampled 256Hz.
# chb04_10.edf was import but not resampled 256Hz.
# chb04_11.edf was import but not resampled 256Hz.
# chb04_12.edf was import but not resampled 256Hz.
# chb04_14.edf was import but not resampled 256Hz.
# chb04_15.edf was import but not resampled 256Hz.
# chb04_16.edf was import but not resampled 256Hz.
# chb04_17.edf was import but not resampled 256Hz.
# chb04_18.edf was import but not resampled 256Hz.
# chb04_19.edf was import but not resampled 256Hz.
# chb04_21.edf was import but not resampled 256Hz.
# chb04_22.edf was import but not resampled 256Hz.
# chb04_23.edf was import but not resampled 256Hz.
# chb04_24.edf was import but not resampled 256Hz.
# chb04_25.edf was import but not resampled 256Hz.
# chb04_26.edf was import but not resampled 256Hz.
# chb04_27.edf was import but not resampled 256Hz.
# chb04_28.edf was import but not resampled 256Hz.
# chb04_28.edf seizure and buffer was labeled
# chb04_28.edf seizure and buffer was labeled
# chb04_29.edf was import but not resampled 256Hz.
# chb04_30.edf was import but not resampled 256Hz.
# chb04_31.edf was import but not resampled 256Hz.
# chb04_32.edf was import but not resampled 256Hz.
# chb04_33.edf was import but not resampled 256Hz.
# chb04_34.edf was import but not resampled 256Hz.
# chb04_35.edf was import but not resampled 256Hz.
# chb04_36.edf was import but not resampled 256Hz.
# chb04_37.edf was import but not resampled 256Hz.
# chb04_38.edf was import but not resampled 256Hz.
# chb04_40.edf was import but not resampled 256Hz.
# chb04_41.edf was import but not resampled 256Hz.
# chb04_42.edf was import but not resampled 256Hz.
# chb04_43.edf was import but not resampled 256Hz.
# chb05_01.edf was import but not resampled 256Hz.
# chb05_02.edf was import but not resampled 256Hz.
# chb05_03.edf was import but not resampled 256Hz.
# chb05_04.edf was import but not resampled 256Hz.
# chb05_05.edf was import but not resampled 256Hz.
# chb05_06.edf was import but not resampled 256Hz.
# chb05_06.edf seizure and buffer was labeled
# chb05_07.edf was import but not resampled 256Hz.
# chb05_08.edf was import but not resampled 256Hz.
# chb05_09.edf was import but not resampled 256Hz.
# chb05_10.edf was import but not resampled 256Hz.
# chb05_11.edf was import but not resampled 256Hz.
# chb05_12.edf was import but not resampled 256Hz.
# chb05_13.edf was import but not resampled 256Hz.
# chb05_13.edf seizure and buffer was labeled
# chb05_14.edf was import but not resampled 256Hz.
# chb05_15.edf was import but not resampled 256Hz.
# chb05_16.edf was import but not resampled 256Hz.
# chb05_16.edf seizure and buffer was labeled
# chb05_17.edf was import but not resampled 256Hz.
# chb05_17.edf seizure and buffer was labeled
# chb05_18.edf was import but not resampled 256Hz.
# chb05_19.edf was import but not resampled 256Hz.
# chb05_20.edf was import but not resampled 256Hz.
# chb05_21.edf was import but not resampled 256Hz.
# chb05_22.edf was import but not resampled 256Hz.
# chb05_22.edf seizure and buffer was labeled
# chb05_23.edf was import but not resampled 256Hz.
# chb05_24.edf was import but not resampled 256Hz.
# chb05_25.edf was import but not resampled 256Hz.
# chb05_26.edf was import but not resampled 256Hz.
# chb05_27.edf was import but not resampled 256Hz.
# chb05_28.edf was import but not resampled 256Hz.
# chb05_29.edf was import but not resampled 256Hz.
# chb05_30.edf was import but not resampled 256Hz.
# chb05_31.edf was import but not resampled 256Hz.
# chb05_32.edf was import but not resampled 256Hz.
# chb05_33.edf was import but not resampled 256Hz.
# chb05_34.edf was import but not resampled 256Hz.
# chb05_35.edf was import but not resampled 256Hz.
# chb05_36.edf was import but not resampled 256Hz.
# chb05_37.edf was import but not resampled 256Hz.
# chb05_38.edf was import but not resampled 256Hz.
# chb05_39.edf was import but not resampled 256Hz.
# chb07_02.edf was import but not resampled 256Hz.
# chb07_03.edf was import but not resampled 256Hz.
# chb07_06.edf was import but not resampled 256Hz.
# chb07_07.edf was import but not resampled 256Hz.
# chb07_08.edf was import but not resampled 256Hz.
# chb07_09.edf was import but not resampled 256Hz.
# chb07_10.edf was import but not resampled 256Hz.
# chb07_11.edf was import but not resampled 256Hz.
# chb07_12.edf was import but not resampled 256Hz.
# chb07_12.edf seizure and buffer was labeled
# chb07_13.edf was import but not resampled 256Hz.
# chb07_13.edf seizure and buffer was labeled
# chb07_14.edf was import but not resampled 256Hz.
# chb07_15.edf was import but not resampled 256Hz.
# chb07_16.edf was import but not resampled 256Hz.
# chb07_17.edf was import but not resampled 256Hz.
# chb07_18.edf was import but not resampled 256Hz.
# chb07_19.edf was import but not resampled 256Hz.
# chb07_19.edf seizure and buffer was labeled
# chb08_02.edf was import but not resampled 256Hz.
# chb08_02.edf seizure and buffer was labeled
# chb08_03.edf was import but not resampled 256Hz.
# chb08_04.edf was import but not resampled 256Hz.
# chb08_05.edf was import but not resampled 256Hz.
# chb08_05.edf seizure and buffer was labeled
# chb08_10.edf was import but not resampled 256Hz.
# chb08_11.edf was import but not resampled 256Hz.
# chb08_11.edf seizure and buffer was labeled
# chb08_12.edf was import but not resampled 256Hz.
# chb08_13.edf was import but not resampled 256Hz.
# chb08_13.edf seizure and buffer was labeled
# chb08_14.edf was import but not resampled 256Hz.
# chb08_15.edf was import but not resampled 256Hz.
# chb08_16.edf was import but not resampled 256Hz.
# chb08_17.edf was import but not resampled 256Hz.
# chb08_18.edf was import but not resampled 256Hz.
# chb08_19.edf was import but not resampled 256Hz.
# chb08_20.edf was import but not resampled 256Hz.
# chb08_21.edf was import but not resampled 256Hz.
# chb08_21.edf seizure and buffer was labeled
# chb08_22.edf was import but not resampled 256Hz.
# chb08_23.edf was import but not resampled 256Hz.
# chb08_24.edf was import but not resampled 256Hz.
# chb08_29.edf was import but not resampled 256Hz.
# chb09_01.edf was import but not resampled 256Hz.
# chb09_02.edf was import but not resampled 256Hz.
# chb09_03.edf was import but not resampled 256Hz.
# chb09_04.edf was import but not resampled 256Hz.
# chb09_05.edf was import but not resampled 256Hz.
# chb09_06.edf was import but not resampled 256Hz.
# chb09_06.edf seizure and buffer was labeled
# chb09_07.edf was import but not resampled 256Hz.
# chb09_08.edf was import but not resampled 256Hz.
# chb09_08.edf seizure and buffer was labeled
# chb09_08.edf seizure and buffer was labeled
# chb09_09.edf was import but not resampled 256Hz.
# chb09_10.edf was import but not resampled 256Hz.
# chb09_11.edf was import but not resampled 256Hz.
# chb09_12.edf was import but not resampled 256Hz.
# chb09_13.edf was import but not resampled 256Hz.
# chb09_14.edf was import but not resampled 256Hz.
# chb09_15.edf was import but not resampled 256Hz.
# chb09_16.edf was import but not resampled 256Hz.
# chb09_17.edf was import but not resampled 256Hz.
# chb09_18.edf was import but not resampled 256Hz.
# chb09_19.edf was import but not resampled 256Hz.
# chb09_19.edf seizure and buffer was labeled
# chb11_01.edf was import but not resampled 256Hz.
# chb11_02.edf was import but not resampled 256Hz.
# chb11_03.edf was import but not resampled 256Hz.
# chb11_04.edf was import but not resampled 256Hz.
# chb11_05.edf was import but not resampled 256Hz.
# chb11_06.edf was import but not resampled 256Hz.
# chb11_07.edf was import but not resampled 256Hz.
# chb11_08.edf was import but not resampled 256Hz.
# chb11_09.edf was import but not resampled 256Hz.
# chb11_10.edf was import but not resampled 256Hz.
# chb11_11.edf was import but not resampled 256Hz.
# chb11_12.edf was import but not resampled 256Hz.
# chb11_13.edf was import but not resampled 256Hz.
# chb11_14.edf was import but not resampled 256Hz.
# chb11_15.edf was import but not resampled 256Hz.
# chb11_16.edf was import but not resampled 256Hz.
# chb11_17.edf was import but not resampled 256Hz.
# chb11_18.edf was import but not resampled 256Hz.
# chb11_19.edf was import but not resampled 256Hz.
# chb11_24.edf was import but not resampled 256Hz.
# chb11_25.edf was import but not resampled 256Hz.
# chb11_26.edf was import but not resampled 256Hz.
# chb11_27.edf was import but not resampled 256Hz.
# chb11_53.edf was import but not resampled 256Hz.
# chb11_54.edf was import but not resampled 256Hz.
# chb11_55.edf was import but not resampled 256Hz.
# chb11_56.edf was import but not resampled 256Hz.
# chb11_58.edf was import but not resampled 256Hz.
# chb11_60.edf was import but not resampled 256Hz.
# chb11_61.edf was import but not resampled 256Hz.
# chb11_62.edf was import but not resampled 256Hz.
# chb11_63.edf was import but not resampled 256Hz.
# chb11_82.edf was import but not resampled 256Hz.
# chb11_82.edf seizure and buffer was labeled
# chb11_92.edf was import but not resampled 256Hz.
# chb11_92.edf seizure and buffer was labeled
# chb11_99.edf was import but not resampled 256Hz.
# chb11_99.edf seizure and buffer was labeled
# chb17a_03.edf was import but not resampled 256Hz.
# chb17a_03.edf seizure and buffer was labeled
# chb17a_04.edf was import but not resampled 256Hz.
# chb17a_04.edf seizure and buffer was labeled
# chb17a_05.edf was import but not resampled 256Hz.
# chb17a_06.edf was import but not resampled 256Hz.
# chb17a_08.edf was import but not resampled 256Hz.
# chb17b_57.edf was import but not resampled 256Hz.
# chb17b_58.edf was import but not resampled 256Hz.
# chb17b_59.edf was import but not resampled 256Hz.
# chb17b_60.edf was import but not resampled 256Hz.
# chb17b_63.edf was import but not resampled 256Hz.
# chb17b_63.edf seizure and buffer was labeled
# chb17b_67.edf was import but not resampled 256Hz.
# chb17b_68.edf was import but not resampled 256Hz.
# chb17b_69.edf was import but not resampled 256Hz.
# chb17c_02.edf was import but not resampled 256Hz.
# chb17c_03.edf was import but not resampled 256Hz.
# chb17c_04.edf was import but not resampled 256Hz.
# chb17c_05.edf was import but not resampled 256Hz.
# chb17c_06.edf was import but not resampled 256Hz.
# chb17c_07.edf was import but not resampled 256Hz.
# chb17c_08.edf was import but not resampled 256Hz.
# chb17c_13.edf was import but not resampled 256Hz.
# incomplete channels. skipping ...
# chb18_01.edf was import but not resampled 256Hz.
# incomplete channels. skipping ...
# chb18_02.edf was import but not resampled 256Hz.
# chb18_03.edf was import but not resampled 256Hz.
# chb18_04.edf was import but not resampled 256Hz.
# chb18_05.edf was import but not resampled 256Hz.
# chb18_06.edf was import but not resampled 256Hz.
# chb18_07.edf was import but not resampled 256Hz.
# chb18_08.edf was import but not resampled 256Hz.
# chb18_09.edf was import but not resampled 256Hz.
# chb18_10.edf was import but not resampled 256Hz.
# chb18_11.edf was import but not resampled 256Hz.
# chb18_12.edf was import but not resampled 256Hz.
# chb18_13.edf was import but not resampled 256Hz.
# chb18_14.edf was import but not resampled 256Hz.
# chb18_15.edf was import but not resampled 256Hz.
# chb18_16.edf was import but not resampled 256Hz.
# chb18_17.edf was import but not resampled 256Hz.
# chb18_18.edf was import but not resampled 256Hz.
# chb18_19.edf was import but not resampled 256Hz.
# chb18_20.edf was import but not resampled 256Hz.
# chb18_21.edf was import but not resampled 256Hz.
# chb18_22.edf was import but not resampled 256Hz.
# chb18_23.edf was import but not resampled 256Hz.
# chb18_24.edf was import but not resampled 256Hz.
# chb18_25.edf was import but not resampled 256Hz.
# chb18_26.edf was import but not resampled 256Hz.
# chb18_27.edf was import but not resampled 256Hz.
# chb18_28.edf was import but not resampled 256Hz.
# chb18_29.edf was import but not resampled 256Hz.
# chb18_29.edf seizure and buffer was labeled
# chb18_30.edf was import but not resampled 256Hz.
# chb18_30.edf seizure and buffer was labeled
# chb18_31.edf was import but not resampled 256Hz.
# chb18_31.edf seizure and buffer was labeled
# chb18_32.edf was import but not resampled 256Hz.
# chb18_32.edf seizure and buffer was labeled
# chb18_33.edf was import but not resampled 256Hz.
# chb18_34.edf was import but not resampled 256Hz.
# chb18_35.edf was import but not resampled 256Hz.
# chb18_35.edf seizure and buffer was labeled
# chb18_36.edf was import but not resampled 256Hz.
# chb18_36.edf seizure and buffer was labeled
# chb19_01.edf was import but not resampled 256Hz.
# incomplete channels. skipping ...
# chb19_02.edf was import but not resampled 256Hz.
# chb19_03.edf was import but not resampled 256Hz.
# chb19_04.edf was import but not resampled 256Hz.
# chb19_05.edf was import but not resampled 256Hz.
# chb19_06.edf was import but not resampled 256Hz.
# chb19_07.edf was import but not resampled 256Hz.
# chb19_08.edf was import but not resampled 256Hz.
# chb19_09.edf was import but not resampled 256Hz.
# chb19_10.edf was import but not resampled 256Hz.
# chb19_11.edf was import but not resampled 256Hz.
# chb19_12.edf was import but not resampled 256Hz.
# chb19_13.edf was import but not resampled 256Hz.
# chb19_14.edf was import but not resampled 256Hz.
# chb19_15.edf was import but not resampled 256Hz.
# chb19_16.edf was import but not resampled 256Hz.
# chb19_17.edf was import but not resampled 256Hz.
# chb19_18.edf was import but not resampled 256Hz.
# chb19_19.edf was import but not resampled 256Hz.
# chb19_20.edf was import but not resampled 256Hz.
# chb19_21.edf was import but not resampled 256Hz.
# chb19_22.edf was import but not resampled 256Hz.
# chb19_23.edf was import but not resampled 256Hz.
# chb19_24.edf was import but not resampled 256Hz.
# chb19_25.edf was import but not resampled 256Hz.
# chb19_26.edf was import but not resampled 256Hz.
# chb19_27.edf was import but not resampled 256Hz.
# chb19_28.edf was import but not resampled 256Hz.
# chb19_28.edf seizure and buffer was labeled
# chb19_29.edf was import but not resampled 256Hz.
# chb19_29.edf seizure and buffer was labeled
# chb19_30.edf was import but not resampled 256Hz.
# chb19_30.edf seizure and buffer was labeled
# chb21_01.edf was import but not resampled 256Hz.
# chb21_02.edf was import but not resampled 256Hz.
# chb21_03.edf was import but not resampled 256Hz.
# chb21_04.edf was import but not resampled 256Hz.
# chb21_05.edf was import but not resampled 256Hz.
# chb21_06.edf was import but not resampled 256Hz.
# chb21_07.edf was import but not resampled 256Hz.
# chb21_08.edf was import but not resampled 256Hz.
# chb21_09.edf was import but not resampled 256Hz.
# chb21_10.edf was import but not resampled 256Hz.
# chb21_11.edf was import but not resampled 256Hz.
# chb21_12.edf was import but not resampled 256Hz.
# chb21_13.edf was import but not resampled 256Hz.
# chb21_14.edf was import but not resampled 256Hz.
# chb21_15.edf was import but not resampled 256Hz.
# chb21_16.edf was import but not resampled 256Hz.
# chb21_17.edf was import but not resampled 256Hz.
# chb21_18.edf was import but not resampled 256Hz.
# chb21_19.edf was import but not resampled 256Hz.
# chb21_19.edf seizure and buffer was labeled
# chb21_20.edf was import but not resampled 256Hz.
# chb21_20.edf seizure and buffer was labeled
# chb21_21.edf was import but not resampled 256Hz.
# chb21_21.edf seizure and buffer was labeled
# chb21_22.edf was import but not resampled 256Hz.
# chb21_22.edf seizure and buffer was labeled
# chb21_23.edf was import but not resampled 256Hz.
# chb21_24.edf was import but not resampled 256Hz.
# chb21_25.edf was import but not resampled 256Hz.
# chb21_26.edf was import but not resampled 256Hz.
# chb21_27.edf was import but not resampled 256Hz.
# chb21_28.edf was import but not resampled 256Hz.
# chb21_29.edf was import but not resampled 256Hz.
# chb21_30.edf was import but not resampled 256Hz.
# chb21_31.edf was import but not resampled 256Hz.
# chb21_32.edf was import but not resampled 256Hz.
# chb21_33.edf was import but not resampled 256Hz.
# chb22_01.edf was import but not resampled 256Hz.
# chb22_02.edf was import but not resampled 256Hz.
# chb22_03.edf was import but not resampled 256Hz.
# chb22_04.edf was import but not resampled 256Hz.
# chb22_05.edf was import but not resampled 256Hz.
# chb22_06.edf was import but not resampled 256Hz.
# chb22_07.edf was import but not resampled 256Hz.
# chb22_08.edf was import but not resampled 256Hz.
# chb22_09.edf was import but not resampled 256Hz.
# chb22_10.edf was import but not resampled 256Hz.
# chb22_11.edf was import but not resampled 256Hz.
# chb22_15.edf was import but not resampled 256Hz.
# chb22_16.edf was import but not resampled 256Hz.
# chb22_17.edf was import but not resampled 256Hz.
# chb22_18.edf was import but not resampled 256Hz.
# chb22_19.edf was import but not resampled 256Hz.
# chb22_20.edf was import but not resampled 256Hz.
# chb22_20.edf seizure and buffer was labeled
# chb22_21.edf was import but not resampled 256Hz.
# chb22_22.edf was import but not resampled 256Hz.
# chb22_23.edf was import but not resampled 256Hz.
# chb22_24.edf was import but not resampled 256Hz.
# chb22_25.edf was import but not resampled 256Hz.
# chb22_25.edf seizure and buffer was labeled
# chb22_26.edf was import but not resampled 256Hz.
# chb22_27.edf was import but not resampled 256Hz.
# chb22_28.edf was import but not resampled 256Hz.
# chb22_29.edf was import but not resampled 256Hz.
# chb22_30.edf was import but not resampled 256Hz.
# chb22_38.edf was import but not resampled 256Hz.
# chb22_38.edf seizure and buffer was labeled
# chb22_51.edf was import but not resampled 256Hz.
# chb22_54.edf was import but not resampled 256Hz.
# chb22_77.edf was import but not resampled 256Hz.
# reached_file_start 0
# reached_file_end 0
# seizure_too_small 0
# overlapping_seizure 0
# ictal_epochs 0
# preictal_epochs 60
# interictal_epochs 375
# seizure_max_reached 0
# incomplete_channels 3
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/source/../data/processed_data.arrow was successfully written.
# <bound method NDFrame.head of channel                        F4-C4      F3-C3    FT9-FT10      FZ-CZ  \
# 0 days 00:30:00            16.878726  20.334213   -3.322584  17.941953
# 0 days 00:30:00.003906250  22.891349  24.865283   -8.175141  23.784967
# 0 days 00:30:00.007812500  22.162881  25.360125   -8.902114  25.615925
# 0 days 00:30:00.011718750  29.573426  33.953147  -14.930178  33.038895
# 0 days 00:30:00.015625     21.292400  18.163275  -11.955401  21.366748
# ...                              ...        ...         ...        ...
# 0 days 00:30:59.980468750 -20.346613  49.010707 -134.061671  63.770272
# 0 days 00:30:59.984375    -24.982277  46.104258 -128.042600  54.845428
# 0 days 00:30:59.988281250 -29.788733  44.714241 -121.098945  46.930801
# 0 days 00:30:59.992187500 -29.929097  44.638886 -116.133400  44.989220
# 0 days 00:30:59.996093750 -26.791851  47.276784 -109.226131  47.871392
#
# channel                        F7-T7     FP2-F4    T8-P8-1    T8-P8-0  \
# 0 days 00:30:00            18.739373  33.092935  12.625819  12.625819
# 0 days 00:30:00.003906250  26.448730  40.639022  11.874291  11.874291
# 0 days 00:30:00.007812500  27.023819  40.074853   5.285063   5.285063
# 0 days 00:30:00.011718750  32.700204  52.956037   8.308854   8.308854
# 0 days 00:30:00.015625     20.938086  35.328903  -1.132117  -1.132117
# ...                              ...        ...        ...        ...
# 0 days 00:30:59.980468750  67.656278  -0.115045 -56.566096 -56.566096
# 0 days 00:30:59.984375     59.579291  -6.192870 -53.171362 -53.171362
# 0 days 00:30:59.988281250  49.074838 -12.132790 -50.776841 -50.776841
# 0 days 00:30:59.992187500  41.012706 -17.749290 -47.691561 -47.691561
# 0 days 00:30:59.996093750  31.406916 -18.951701 -43.130898 -43.130898
#
    unique_epoch_ids_np = unique_epoch_ids.to_numpy()

    # Shuffle the unique epoch IDs
    np.random.seed(random_state)
    np.random.shuffle(unique_epoch_ids_np)

    # Calculate the number of unique epoch IDs for training, validation, and testing
    train_samples_nr = int(np.floor(0.8 * len(unique_epoch_ids_np)))

    # Split the unique epoch IDs into train, validation, and test sets
    train_sample_ids = unique_epoch_ids_np[:train_samples_nr]
    test_sample_ids = unique_epoch_ids_np[train_samples_nr:]

    # Create boolean masks for filtering
    train_mask = ids_column.isin(train_sample_ids)
    test_mask = ids_column.isin(test_sample_ids)

    # Apply the masks to create train and test samples
    train_sample = data[train_mask]
    test_sample = data[test_mask]

    X_train = train_sample.drop(["is_seizure"], axis=1)
    X_test = test_sample.drop(["is_seizure"], axis=1)

    Y_train = train_sample.iloc[:, -4]
    Y_test = test_sample.iloc[:, -4]

    #y_test = Y_test.groupby(ids_column[test_mask]).max()
    #y_train = Y_train.groupby(ids_column[train_mask]).max()

    return X_train, X_test, Y_train, Y_test #, y_train, y_test

# %%
X_train, X_test, Y_train, Y_test = split_data(fit_df, random_state=42)

# %% [markdown]
# ## Feature Extraction

# %%
### aggregate Functions for mean psd:
delta = lambda x: calculate_mean_psd(x, frequency_ranges={'Delta' : FREQUENCY_RANGES['Delta']})[x.name]['Delta']
theta = lambda x: calculate_mean_psd(x, frequency_ranges={'Theta' : FREQUENCY_RANGES['Theta']})[x.name]['Theta']
gamma = lambda x: calculate_mean_psd(x, frequency_ranges={'Gamma': FREQUENCY_RANGES['Gamma']})[x.name]['Gamma']

delta_agg = pd.NamedAgg(column='delta', aggfunc=delta)
theta_agg = pd.NamedAgg(column='theta', aggfunc=theta)
gamma_agg = pd.NamedAgg(column='gamma', aggfunc=gamma)

### aggregate mean features:
abs_mean = lambda x: x.apply(abs).mean()
abs_mean_agg = pd.NamedAgg(column='abs_mean', aggfunc=abs_mean)

### aggregate Functions for target:
target_foo = lambda x, pred_interval=PRED_INTERVAL: 0 < x.dt.total_seconds().min() < pred_interval

# %%
def preprocess_data(df, window_size):
    # Grouping and aggregating features
    df_features = df.groupby(['epoch', 'segment_id']).agg(
        {C: ['std', 'var', abs_mean_agg, delta_agg, theta_agg, gamma_agg] for C in CHANNELS} | 
        {target_colname: [target_foo]}
    )
    
    # Renaming columns
    df_features.columns = ['_'.join(col).strip() for col in df_features.columns.values if target_colname != col[0]] + [target_colname]
    df_features.reset_index(inplace=True)

    # Scaling features
    num_features = df_features.drop(['epoch', 'segment_id', 'target'], axis=1)
    scaler = StandardScaler()
    num_features_scaled = scaler.fit_transform(num_features)

    # Combining columns into an array
    original_array = np.array(df_features)
    target = original_array[:, -1]
    target = target[:, np.newaxis]
    segseiz_column = original_array[:, 0:2]
    array_all_scaled = np.concatenate((segseiz_column, num_features_scaled, target), axis=1)

    # Reshaping array
    original_array = np.array(df_features)
    epoch_column = original_array[:, 0]
    num_epochs = df_features.epoch.unique()[-1]
    num_segments = len(df_features.segment_id.unique())
    reshaped_array = np.empty((num_epochs, num_segments, array_all_scaled.shape[1]))

    for epoch in range(num_epochs):
        start_idx = epoch * num_segments
        end_idx = (epoch + 1) * num_segments
        reshaped_array[epoch, :, :] = array_all_scaled[start_idx:end_idx, :]

    # Creating sequence trains
    num_batches, num_sequences, num_features = reshaped_array.shape
    num_augmented_batches = num_sequences - window_size + 1

    data = np.zeros((num_batches * num_augmented_batches, window_size, num_features))

    for batch_idx in range(num_batches):
        for seq_idx in range(num_augmented_batches):
            data[batch_idx * num_augmented_batches + seq_idx, :, :] = reshaped_array[batch_idx, seq_idx:seq_idx + window_size, :]

    return data

# %%
if not SKIP_FEATURES:
    data = preprocess_data(X_train, window_size=window_size)
    print(data.shape)
# Out:
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 198, using nperseg = 198
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 219, using nperseg = 219
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 210, using nperseg = 210
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 205, using nperseg = 205
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 211, using nperseg = 211
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 207, using nperseg = 207
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 216, using nperseg = 216
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 201, using nperseg = 201
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 203, using nperseg = 203
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 195, using nperseg = 195
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 202, using nperseg = 202
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 196, using nperseg = 196
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 204, using nperseg = 204
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 194, using nperseg = 194
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 197, using nperseg = 197
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 192, using nperseg = 192
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 209, using nperseg = 209
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 215, using nperseg = 215
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 208, using nperseg = 208
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 213, using nperseg = 213
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 214, using nperseg = 214
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 191, using nperseg = 191
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 217, using nperseg = 217
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 200, using nperseg = 200
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 190, using nperseg = 190
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 206, using nperseg = 206
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 199, using nperseg = 199
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 212, using nperseg = 212
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 218, using nperseg = 218
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 220, using nperseg = 220
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 189, using nperseg = 189
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 221, using nperseg = 221
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 193, using nperseg = 193
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 223, using nperseg = 223
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 226, using nperseg = 226
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 224, using nperseg = 224
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 185, using nperseg = 185
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 222, using nperseg = 222
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 227, using nperseg = 227
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 186, using nperseg = 186
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 183, using nperseg = 183
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 198, using nperseg = 198
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 219, using nperseg = 219
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 210, using nperseg = 210
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 205, using nperseg = 205
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 211, using nperseg = 211
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 207, using nperseg = 207
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 216, using nperseg = 216
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 201, using nperseg = 201
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 203, using nperseg = 203
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 195, using nperseg = 195
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 202, using nperseg = 202
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 196, using nperseg = 196
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 204, using nperseg = 204
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 194, using nperseg = 194
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 197, using nperseg = 197
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 192, using nperseg = 192
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 209, using nperseg = 209
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 215, using nperseg = 215
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 208, using nperseg = 208
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 213, using nperseg = 213
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 214, using nperseg = 214
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 191, using nperseg = 191
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 217, using nperseg = 217
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 200, using nperseg = 200
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 190, using nperseg = 190
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 206, using nperseg = 206
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 199, using nperseg = 199
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 212, using nperseg = 212
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 218, using nperseg = 218
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 220, using nperseg = 220
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 189, using nperseg = 189
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 221, using nperseg = 221
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 193, using nperseg = 193
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 223, using nperseg = 223
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 226, using nperseg = 226
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 224, using nperseg = 224
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 185, using nperseg = 185
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 222, using nperseg = 222
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 227, using nperseg = 227
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 186, using nperseg = 186
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 183, using nperseg = 183
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 198, using nperseg = 198
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 219, using nperseg = 219
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 210, using nperseg = 210
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 205, using nperseg = 205
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 211, using nperseg = 211
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 207, using nperseg = 207
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 216, using nperseg = 216
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 201, using nperseg = 201
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 203, using nperseg = 203
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 195, using nperseg = 195
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 202, using nperseg = 202
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  =
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 222, using nperseg = 222
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 227, using nperseg = 227
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 186, using nperseg = 186
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /Users/tassiloheinrich/Documents/DS/ai-seizure-detectives/.venv/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:2017: UserWarning: nperseg = 256 is greater than input length  = 183, using nperseg = 183
#   warnings.warn('nperseg = {0:d} is greater than input length '
# (13454, 30, 63)

# %%
if not SKIP_FEATURES:
    # aggregate features
    df_features = fit_df.groupby(['epoch', 'segment_id']).agg(
        {C:['std',
            'var',
            #'mean',
            abs_mean_agg,
            delta_agg,
            theta_agg,
            gamma_agg
            ] for C in CHANNELS} | 
        {target_colname: [target_foo]} 
        ) 

    # joining column names with agg functions, but leaving target column
    df_features.columns = ['_'.join(col).strip() for col in df_features.columns.values if target_colname != col[0]] + [target_colname]
    df_features.reset_index(inplace=True)

    # Scaling the features
    num_features= df_features.drop(['epoch','segment_id','target'],axis =1)
    scaler = StandardScaler()
    num_features_scaled = scaler.fit_transform(num_features)

    import numpy as np

    original_array = np.array(df_features)
    target = original_array[:,-1]
    target = target[:, np.newaxis]
    segseiz_column = original_array[:, 0:2] ## epoch and segment_id
    array_all_scaled = np.concatenate((segseiz_column, num_features_scaled, target), axis=1)
    array_all_scaled.shape

    ### Reshape Array ###
    original_array =np.array(df_features)

    # Extract the epoch column
    epoch_column = original_array[:, 0]

    # Determine the number of epochs (assuming epochs are from 1 to number of segments)
    num_epochs = df_features.epoch.unique()[-1]

    # Determine the number of segments for each epoch
    num_segments = len(df_features.segment_id.unique())  # Assuming there are 30 segments for each epoch

    # Initialize an empty 3D array
    reshaped_array = np.empty((num_epochs,num_segments, array_all_scaled.shape[1]))

    # Reshape the data for each epoch and insert it into the 3D array
    for epoch in range(num_epochs):
        start_idx = epoch * num_segments
        end_idx = (epoch + 1) * num_segments
        reshaped_array[epoch,:, :] = array_all_scaled[start_idx:end_idx,:]

    ### Create Sequence Trains ###
    # Assuming original_data_array has dimensions (batch, sequence, features)
    num_batches, num_sequences, num_features = reshaped_array.shape

    # Calculate the number of augmented batches
    num_augmented_batches = num_sequences - window_size + 1
    print(f"num_augmented_batches: {num_augmented_batches}")

    # Create an empty array for the augmented data
    data = np.zeros((num_batches * num_augmented_batches, window_size, num_features))
    print(f"data.shape: {data.shape}")

    # Iterate through batches
    for batch_idx in range(num_batches):
        # Iterate through sequences to create augmented batches
        for seq_idx in range(num_augmented_batches):
            # Copy the window of data
            data[batch_idx * num_augmented_batches + seq_idx, :, :] = reshaped_array[batch_idx, seq_idx:seq_idx + window_size, :]

    save_file(data=data, file_name=feature_filename)
else:
    data = load_file(feature_filename)

data.shape
# Out:
# num_augmented_batches: 31
# data.shape: (13454, 30, 63)
# saving npy
# (13454, 30, 63)

# %%
# %run model_rnn.ipynb
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# data already loaded in parent notebook
# train shape (10757, 30, 62)
# test shape (2697, 30, 62)
# Epoch 1/300
# 87/87 [==============================] - 4s 27ms/step - loss: 0.7485 - accuracy: 0.5182 - val_loss: 0.6275 - val_accuracy: 0.8685
# Epoch 2/300
# 87/87 [==============================] - 2s 20ms/step - loss: 0
# 87/87 [==============================] - 2s 22ms/step - loss: 0.0315 - accuracy: 0.9879 - val_loss: 1.7638 - val_accuracy: 0.6143
# 85/85 - 0s - loss: 2.3708 - accuracy: 0.6978 - 295ms/epoch - 3ms/step
# Model accuracy: 0.6978123784065247
# 337/337 [==============================] - 1s 2ms/step
# 85/85 [==============================] - 0s 3ms/step
# 85/85 [==============================] - 0s 3ms/step - loss: 2.3708 - accuracy: 0.6978
# Loss: 2.370793342590332
# Accuracy: 0.6978123784065247
# Precision: 0.17758369723435224
# Recall: 0.3279569892473118
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.76      0.81      2325
#          1.0       0.18      0.33      0.23       372
#
#     accuracy                           0.70      2697
#    macro avg       0.53      0.54      0.52      2697
# weighted avg       0.78      0.70      0.73      2697
# Epoch 1/300
# 108/108 [==============================] - 1s 4ms/step - loss: 0.6655 - accuracy: 0.5543
# Epoch 2/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.6289 - accuracy: 0.5991
# Epoch 3/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.6011 - accuracy: 0.6097
# Epoch 4/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.5875 - accuracy: 0.6579
# Epoch 5/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.5677 - accuracy: 0.6739
# Epoch 6/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.5552 - accuracy: 0.6824
# Epoch 7/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.5489 - accuracy: 0.6808
# Epoch 8/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.5353 - accuracy: 0.7142
# Epoch 9/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.5210 - accuracy: 0.7342
# Epoch 10/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.5225 - accuracy: 0.7405
# Epoch 11/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.5326 - accuracy: 0.6797
# Epoch 12/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.5065 - accuracy: 0.7291
# Epoch 13/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4879 - accuracy: 0.7778
# Epoch 14/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4846 - accuracy: 0.7329
# Epoch 15/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4790 - accuracy: 0.7680
# Epoch 16/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4767 - accuracy: 0.7640
# Epoch 17/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4654 - accuracy: 0.7513
# Epoch 18/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.5154 - accuracy: 0.6946
# Epoch 19/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4704 - accuracy: 0.7295
# Epoch 20/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4672 - accuracy: 0.7479
# Epoch 21/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4642 - accuracy: 0.7591
# Epoch 22/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4548 - accuracy: 0.7672
# Epoch 23/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4484 - accuracy: 0.7688
# Epoch 24/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4350 - accuracy: 0.8083
# Epoch 25/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4717 - accuracy: 0.7293
# Epoch 26/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4297 - accuracy: 0.7811
# Epoch 27/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4356 - accuracy: 0.7602
# Epoch 28/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.5201 - accuracy: 0.6786
# Epoch 29/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4868 - accuracy: 0.6693
# Epoch 30/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4774 - accuracy: 0.6924
# Epoch 31/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4723 - accuracy: 0.7021
# Epoch 32/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4658 - accuracy: 0.6961
# Epoch 33/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.5111 - accuracy: 0.6915
# Epoch 34/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4878 - accuracy: 0.6704
# Epoch 35/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4774 - accuracy: 0.6890
# Epoch 36/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.5049 - accuracy: 0.7187
# Epoch 37/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4893 - accuracy: 0.7088
# Epoch 38/300
# ...
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4345 - accuracy: 0.7634
# Epoch 150/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4583 - accuracy: 0.7246
# Epoch 151/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4556 - accuracy: 0.7273
# Epoch 152/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4489 - accuracy: 0.7515
# Epoch 153/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4281 - accuracy: 0.7501
# Epoch 154/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4208 - accuracy: 0.7811
# Epoch 155/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4296 - accuracy: 0.7643
# Epoch 156/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4354 - accuracy: 0.7265
# Epoch 157/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4278 - accuracy: 0.7868
# Epoch 158/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4339 - accuracy: 0.7691
# Epoch 159/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4394 - accuracy: 0.7310
# Epoch 160/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.5077 - accuracy: 0.6856
# Epoch 161/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.5236 - accuracy: 0.6696
# Epoch 162/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4944 - accuracy: 0.7151
# Epoch 163/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4900 - accuracy: 0.6812
# Epoch 164/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4731 - accuracy: 0.7049
# Epoch 165/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4804 - accuracy: 0.7180
# Epoch 166/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4914 - accuracy: 0.7269
# Epoch 167/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4946 - accuracy: 0.7561
# Epoch 168/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4628 - accuracy: 0.7500
# Epoch 169/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4595 - accuracy: 0.7132
# Epoch 170/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4536 - accuracy: 0.7242
# Epoch 171/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4541 - accuracy: 0.7181
# Epoch 172/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4685 - accuracy: 0.7336
# Epoch 173/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4763 - accuracy: 0.7479
# Epoch 174/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4551 - accuracy: 0.7458
# Epoch 175/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4544 - accuracy: 0.7541
# Epoch 176/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4457 - accuracy: 0.7708
# Epoch 177/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4319 - accuracy: 0.7436
# Epoch 178/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4238 - accuracy: 0.7828
# Epoch 179/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4563 - accuracy: 0.7487
# Epoch 180/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4881 - accuracy: 0.7005
# Epoch 181/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4319 - accuracy: 0.7645
# Epoch 182/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4383 - accuracy: 0.7564
# Epoch 183/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4568 - accuracy: 0.7413
# Epoch 184/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4471 - accuracy: 0.7617
# Epoch 185/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4533 - accuracy: 0.7295
# Epoch 186/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4528 - accuracy: 0.7149
# Epoch 187/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4601 - accuracy: 0.7203
# Epoch 188/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4253 - accuracy: 0.7368
# Epoch 189/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4545 - accuracy: 0.7307
# Epoch 190/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4467 - accuracy: 0.7813
# Epoch 191/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4338 - accuracy: 0.7852
# Epoch 192/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4128 - accuracy: 0.8106
# Epoch 193/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4365 - accuracy: 0.8131
# Epoch 194/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4343 - accuracy: 0.7597
# Epoch 195/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4619 - accuracy: 0.7165
# Epoch 196/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4533 - accuracy: 0.7094
# Epoch 197/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4243 - accuracy: 0.7855
# Epoch 198/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4025 - accuracy: 0.7795
# Epoch 199/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4719 - accuracy: 0.6689
# Epoch 200/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4612 - accuracy: 0.7156
# Epoch 201/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4637 - accuracy: 0.7097
# Epoch 202/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4863 - accuracy: 0.6983
# Epoch 203/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4936 - accuracy: 0.6847
# Epoch 204/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4912 - accuracy: 0.6768
# Epoch 205/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4711 - accuracy: 0.6955
# Epoch 206/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4499 - accuracy: 0.7706
# Epoch 207/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4698 - accuracy: 0.7657
# Epoch 208/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4702 - accuracy: 0.6917
# Epoch 209/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4748 - accuracy: 0.6678
# Epoch 210/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4585 - accuracy: 0.6706
# Epoch 211/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4365 - accuracy: 0.7109
# Epoch 212/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4225 - accuracy: 0.7388
# Epoch 213/300
# 108/108 [==============================] - 0s 5ms/step - loss: 0.4175 - accuracy: 0.7235
# Epoch 214/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4373 - accuracy: 0.7034
# Epoch 215/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4699 - accuracy: 0.7063
# Epoch 216/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4241 - accuracy: 0.7770
# Epoch 217/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4176 - accuracy: 0.7536
# Epoch 218/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4492 - accuracy: 0.7715
# Epoch 219/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4334 - accuracy: 0.7820
# Epoch 220/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.3907 - accuracy: 0.8119
# Epoch 221/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.3843 - accuracy: 0.7898
# Epoch 222/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4387 - accuracy: 0.7130
# Epoch 223/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4451 - accuracy: 0.7223
# Epoch 224/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4697 - accuracy: 0.7499
# Epoch 225/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4586 - accuracy: 0.7146
# Epoch 226/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4454 - accuracy: 0.7742
# Epoch 227/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4272 - accuracy: 0.7472
# Epoch 228/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4647 - accuracy: 0.7858
# Epoch 229/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4244 - accuracy: 0.8249
# Epoch 230/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4572 - accuracy: 0.6835
# Epoch 231/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4433 - accuracy: 0.6731
# Epoch 232/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4583 - accuracy: 0.7483
# Epoch 233/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4529 - accuracy: 0.7130
# Epoch 234/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4743 - accuracy: 0.7465
# Epoch 235/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4888 - accuracy: 0.7451
# Epoch 236/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4646 - accuracy: 0.7060
# Epoch 237/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4733 - accuracy: 0.7282
# Epoch 238/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.6685 - accuracy: 0.6552
# Epoch 239/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.5187 - accuracy: 0.6774
# Epoch 240/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.5316 - accuracy: 0.6973
# Epoch 241/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.5303 - accuracy: 0.6578
# Epoch 242/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4836 - accuracy: 0.6948
# Epoch 243/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4716 - accuracy: 0.7065
# Epoch 244/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4584 - accuracy: 0.7307
# Epoch 245/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4500 - accuracy: 0.7339
# Epoch 246/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4572 - accuracy: 0.7430
# Epoch 247/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4853 - accuracy: 0.7553
# Epoch 248/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4584 - accuracy: 0.7478
# Epoch 249/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4374 - accuracy: 0.7554
# Epoch 250/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4503 - accuracy: 0.7214
# Epoch 251/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4560 - accuracy: 0.7472
# Epoch 252/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4555 - accuracy: 0.7572
# Epoch 253/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.5103 - accuracy: 0.6333
# Epoch 254/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.5061 - accuracy: 0.6328
# Epoch 255/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.5008 - accuracy: 0.6202
# Epoch 256/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4958 - accuracy: 0.6306
# Epoch 257/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4858 - accuracy: 0.6793
# Epoch 258/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4784 - accuracy: 0.6427
# Epoch 259/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4786 - accuracy: 0.6986
# Epoch 260/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4940 - accuracy: 0.6677
# Epoch 261/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4944 - accuracy: 0.6699
# Epoch 262/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4705 - accuracy: 0.6734
# Epoch 263/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4547 - accuracy: 0.6749
# Epoch 264/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4479 - accuracy: 0.6920
# Epoch 265/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4449 - accuracy: 0.7161
# Epoch 266/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4620 - accuracy: 0.7393
# Epoch 267/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4878 - accuracy: 0.6999
# Epoch 268/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.5040 - accuracy: 0.7301
# Epoch 269/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.5110 - accuracy: 0.7251
# Epoch 270/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4600 - accuracy: 0.6713
# Epoch 271/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4519 - accuracy: 0.6958
# Epoch 272/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4893 - accuracy: 0.6911
# Epoch 273/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4399 - accuracy: 0.7055
# Epoch 274/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4631 - accuracy: 0.6715
# Epoch 275/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4331 - accuracy: 0.7129
# Epoch 276/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4457 - accuracy: 0.7053
# Epoch 277/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4721 - accuracy: 0.7274
# Epoch 278/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4889 - accuracy: 0.7034
# Epoch 279/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4616 - accuracy: 0.6916
# Epoch 280/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4653 - accuracy: 0.7186
# Epoch 281/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4387 - accuracy: 0.7048
# Epoch 282/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4481 - accuracy: 0.7282
# Epoch 283/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4582 - accuracy: 0.7110
# Epoch 284/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4646 - accuracy: 0.7310
# Epoch 285/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4853 - accuracy: 0.6900
# Epoch 286/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.5262 - accuracy: 0.6590
# Epoch 287/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4857 - accuracy: 0.7083
# Epoch 288/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4563 - accuracy: 0.7266
# Epoch 289/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4733 - accuracy: 0.7312
# Epoch 290/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4453 - accuracy: 0.6971
# Epoch 291/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4542 - accuracy: 0.6977
# Epoch 292/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4804 - accuracy: 0.7250
# Epoch 293/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4528 - accuracy: 0.7008
# Epoch 294/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4248 - accuracy: 0.7633
# Epoch 295/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4264 - accuracy: 0.7365
# Epoch 296/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4313 - accuracy: 0.7566
# Epoch 297/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4598 - accuracy: 0.7296
# Epoch 298/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4578 - accuracy: 0.7639
# Epoch 299/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4518 - accuracy: 0.7477
# Epoch 300/300
# 108/108 [==============================] - 0s 4ms/step - loss: 0.4420 - accuracy: 0.7528
# 85/85 [==============================] - 0s 1ms/step
# 85/85 - 0s - loss: 0.9126 - accuracy: 0.5121 - 202ms/epoch - 2ms/step
# Model accuracy: 0.512050449848175
# 85/85 [==============================] - 0s 1ms/step - loss: 0.9126 - accuracy: 0.5121
# Loss: 0.9126222729682922
# Accuracy: 0.512050449848175
# Precision: 0.12420382165605096
# Recall: 0.41935483870967744
