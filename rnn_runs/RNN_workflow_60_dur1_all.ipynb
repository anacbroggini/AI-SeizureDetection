# %% [markdown]
# ## Pre-Processing

# %%
from source import data_import
from source.constants import CHANNELS, DEFAULT_PATIENTS
import numpy as np
import matplotlib.pyplot as plt

import os
import pandas as pd
# os.environ["MODIN_ENGINE"] = "ray"
# import modin.pandas as pd
# import ray
# ray.shutdown()
# ray.init()

from source.filter_eeg_channels import filter_eeg_channels
from source.calculate_mean_psd import calculate_mean_psd
from source.constants import CHANNELS, FREQUENCY_RANGES
from source.data_import import save_file, load_file 
                                            
from sklearn.preprocessing import StandardScaler, minmax_scale, MinMaxScaler

# %%
## PARAMETERS ##
SKIP_DATA = False
data_filename = "preprocessed_60_dur2_all.arrow" # data will be loaded/saved with this filename. Put None to skip saving the file

SKIP_FEATURES = False
feature_filename = 'features_60_dur2_all.npy' # data will be loaded/saved with this filename. Put None to skip saving the file

### DATA ###
# Load Patient Data #
patient_ids = None #DEFAULT_PATIENTS #DEFAULT_PATIENTS # use DEFAULT_PATIENTS for default patients selection
nr_segments=60
segment_duration=1
ictal_segmentation_foo=data_import.preictal_segmentation
interictal_segmentation_foo=data_import.inter_segmentation
channels=CHANNELS
seizure_offset=0

# filter #
exclude_ranges=[[58, 62], [118, 122]]

### FEATURES ###
target_colname = 'target'
PRED_INTERVAL = 6000 # how long should a segment count as preictal in seconds

window_size = 30 # Define the sequence_train window size

# %%
if not SKIP_DATA:
    # Load Patient Data
    p_df = data_import.load_segmented_data(patient_ids=patient_ids,
                                            nr_segments=nr_segments,
                                            segment_duration=segment_duration,
                                            ictal_segmentation_foo=data_import.preictal_segmentation,
                                            interictal_segmentation_foo=data_import.inter_segmentation,
                                            channels=channels,
                                            seizure_offset=seizure_offset
                                            )
    
    # Filter
    fit_df = filter_eeg_channels(p_df, CHANNELS, fs=256, exclude_ranges=exclude_ranges, Q=30)
    pd_toconcat = p_df[['epoch', 'segment_id']]
    fit_df = pd.concat(objs=[fit_df, pd_toconcat], axis =1)
    save_file(data=fit_df, file_name=data_filename)
    fit_df.head()
elif data_filename is not None:
    fit_df = load_file(data_filename)
    fit_df = pd.DataFrame(fit_df)
    fit_df.head()
# Out:
# chb01_01.edf was import but not resampled 256Hz.
# chb01_02.edf was import but not resampled 256Hz.
# chb01_03.edf was import but not resampled 256Hz.
# chb01_03.edf seizure and buffer was labeled
# chb01_04.edf was import but not resampled 256Hz.
# chb01_04.edf seizure and buffer was labeled
# chb01_05.edf was import but not resampled 256Hz.
# chb01_06.edf was import but not resampled 256Hz.
# chb01_07.edf was import but not resampled 256Hz.
# chb01_08.edf was import but not resampled 256Hz.
# chb01_09.edf was import but not resampled 256Hz.
# chb01_10.edf was import but not resampled 256Hz.
# chb01_11.edf was import but not resampled 256Hz.
# chb01_12.edf was import but not resampled 256Hz.
# chb01_13.edf was import but not resampled 256Hz.
# chb01_14.edf was import but not resampled 256Hz.
# chb01_15.edf was import but not resampled 256Hz.
# chb01_15.edf seizure and buffer was labeled
# chb01_16.edf was import but not resampled 256Hz.
# chb01_16.edf seizure and buffer was labeled
# chb01_17.edf was import but not resampled 256Hz.
# chb01_18.edf was import but not resampled 256Hz.
# chb01_18.edf seizure and buffer was labeled
# chb01_19.edf was import but not resampled 256Hz.
# chb01_20.edf was import but not resampled 256Hz.
# chb01_21.edf was import but not resampled 256Hz.
# chb01_21.edf seizure and buffer was labeled
# chb01_22.edf was import but not resampled 256Hz.
# chb01_23.edf was import but not resampled 256Hz.
# chb01_24.edf was import but not resampled 256Hz.
# chb01_25.edf was import but not resampled 256Hz.
# chb01_26.edf was import but not resampled 256Hz.
# chb01_26.edf seizure and buffer was labeled
# chb01_27.edf was import but not resampled 256Hz.
# file too short to host interictal sequence.
# chb01_29.edf was import but not resampled 256Hz.
# chb01_30.edf was import but not resampled 256Hz.
# chb01_31.edf was import but not resampled 256Hz.
# chb01_32.edf was import but not resampled 256Hz.
# chb01_33.edf was import but not resampled 256Hz.
# chb01_34.edf was import but not resampled 256Hz.
# chb01_36.edf was import but not resampled 256Hz.
# chb01_37.edf was import but not resampled 256Hz.
# chb01_38.edf was import but not resampled 256Hz.
# chb01_39.edf was import but not resampled 256Hz.
# chb01_40.edf was import but not resampled 256Hz.
# chb01_41.edf was import but not resampled 256Hz.
# chb01_42.edf was import but not resampled 256Hz.
# chb01_43.edf was import but not resampled 256Hz.
# chb01_46.edf was import but not resampled 256Hz.
# chb02_01.edf was import but not resampled 256Hz.
# chb02_02.edf was import but not resampled 256Hz.
# chb02_03.edf was import but not resampled 256Hz.
# chb02_04.edf was import but not resampled 256Hz.
# chb02_05.edf was import but not resampled 256Hz.
# chb02_06.edf was import but not resampled 256Hz.
# chb02_07.edf was import but not resampled 256Hz.
# chb02_08.edf was import but not resampled 256Hz.
# chb02_09.edf was import but not resampled 256Hz.
# chb02_10.edf was import but not resampled 256Hz.
# chb02_11.edf was import but not resampled 256Hz.
# chb02_12.edf was import but not resampled 256Hz.
# chb02_13.edf was import but not resampled 256Hz.
# chb02_14.edf was import but not resampled 256Hz.
# chb02_15.edf was import but not resampled 256Hz.
# chb02_16+.edf was import but not resampled 256Hz.
# chb02_16+.edf seizure and buffer was labeled
# chb02_16.edf was import but not resampled 256Hz.
# chb02_16.edf seizure and buffer was labeled
# chb02_17.edf was import but not resampled 256Hz.
# chb02_18.edf was import but not resampled 256Hz.
# chb02_19.edf was import but not resampled 256Hz.
# chb02_19.edf seizure and buffer was labeled
# chb02_20.edf was import but not resampled 256Hz.
# chb02_21.edf was import but not resampled 256Hz.
# chb02_22.edf was import but not resampled 256Hz.
# chb02_23.edf was import but not resampled 256Hz.
# chb02_24.edf was import but not resampled 256Hz.
# chb02_25.edf was import but not resampled 256Hz.
# chb02_26.edf was import but not resampled 256Hz.
# chb02_27.edf was import but not resampled 256Hz.
# chb02_28.edf was import but not resampled 256Hz.
# chb02_29.edf was import but not resampled 256Hz.
# chb02_30.edf was import but not resampled 256Hz.
# chb02_31.edf was import but not resampled 256Hz.
# chb02_32.edf was import but not resampled 256Hz.
# chb02_33.edf was import but not resampled 256Hz.
# chb02_34.edf was import but not resampled 256Hz.
# chb02_35.edf was import but not resampled 256Hz.
# chb03_01.edf was import but not resampled 256Hz.
# chb03_01.edf seizure and buffer was labeled
# chb03_02.edf was import but not resampled 256Hz.
# chb03_02.edf seizure and buffer was labeled
# chb03_03.edf was import but not resampled 256Hz.
# chb03_03.edf seizure and buffer was labeled
# chb03_04.edf was import but not resampled 256Hz.
# chb03_04.edf seizure and buffer was labeled
# chb03_05.edf was import but not resampled 256Hz.
# chb03_06.edf was import but not resampled 256Hz.
# chb03_07.edf was import but not resampled 256Hz.
# chb03_08.edf was import but not resampled 256Hz.
# chb03_09.edf was import but not resampled 256Hz.
# chb03_10.edf was import but not resampled 256Hz.
# chb03_11.edf was import but not resampled 256Hz.
# chb03_12.edf was import but not resampled 256Hz.
# chb03_13.edf was import but not resampled 256Hz.
# chb03_14.edf was import but not resampled 256Hz.
# chb03_15.edf was import but not resampled 256Hz.
# chb03_16.edf was import but not resampled 256Hz.
# chb03_17.edf was import but not resampled 256Hz.
# chb03_18.edf was import but not resampled 256Hz.
# chb03_19.edf was import but not resampled 256Hz.
# chb03_20.edf was import but not resampled 256Hz.
# chb03_21.edf was import but not resampled 256Hz.
# chb03_22.edf was import but not resampled 256Hz.
# chb03_23.edf was import but not resampled 256Hz.
# chb03_24.edf was import but not resampled 256Hz.
# chb03_25.edf was import but not resampled 256Hz.
# chb03_26.edf was import but not resampled 256Hz.
# chb03_27.edf was import but not resampled 256Hz.
# chb03_28.edf was import but not resampled 256Hz.
# chb03_29.edf was import but not resampled 256Hz.
# chb03_30.edf was import but not resampled 256Hz.
# chb03_31.edf was import but not resampled 256Hz.
# chb03_32.edf was import but not resampled 256Hz.
# chb03_33.edf was import but not resampled 256Hz.
# chb03_34.edf was import but not resampled 256Hz.
# chb03_34.edf seizure and buffer was labeled
# chb03_35.edf was import but not resampled 256Hz.
# chb03_35.edf seizure and buffer was labeled
# chb03_36.edf was import but not resampled 256Hz.
# chb03_36.edf seizure and buffer was labeled
# chb03_37.edf was import but not resampled 256Hz.
# chb03_38.edf was import but not resampled 256Hz.
# chb04_01.edf was import but not resampled 256Hz.
# chb04_02.edf was import but not resampled 256Hz.
# chb04_03.edf was import but not resampled 256Hz.
# chb04_04.edf was import but not resampled 256Hz.
# chb04_05.edf was import but not resampled 256Hz.
# chb04_05.edf seizure and buffer was labeled
# chb04_06.edf was import but not resampled 256Hz.
# chb04_07.edf was import but not resampled 256Hz.
# chb04_08.edf was import but not resampled 256Hz.
# chb04_08.edf seizure and buffer was labeled
# chb04_09.edf was import but not resampled 256Hz.
# chb04_10.edf was import but not resampled 256Hz.
# chb04_11.edf was import but not resampled 256Hz.
# chb04_12.edf was import but not resampled 256Hz.
# chb04_13.edf was import but not resampled 256Hz.
# chb04_14.edf was import but not resampled 256Hz.
# chb04_15.edf was import but not resampled 256Hz.
# chb04_16.edf was import but not resampled 256Hz.
# chb04_17.edf was import but not resampled 256Hz.
# chb04_18.edf was import but not resampled 256Hz.
# chb04_19.edf was import but not resampled 256Hz.
# chb04_21.edf was import but not resampled 256Hz.
# chb04_22.edf was import but not resampled 256Hz.
# chb04_23.edf was import but not resampled 256Hz.
# chb04_24.edf was import but not resampled 256Hz.
# chb04_25.edf was import but not resampled 256Hz.
# chb04_26.edf was import but not resampled 256Hz.
# chb04_27.edf was import but not resampled 256Hz.
# chb04_28.edf was import but not resampled 256Hz.
# chb04_28.edf seizure and buffer was labeled
# chb04_28.edf seizure and buffer was labeled
# chb04_29.edf was import but not resampled 256Hz.
# chb04_30.edf was import but not resampled 256Hz.
# chb04_31.edf was import but not resampled 256Hz.
# chb04_32.edf was import but not resampled 256Hz.
# chb04_33.edf was import but not resampled 256Hz.
# chb04_34.edf was import but not resampled 256Hz.
# chb04_35.edf was import but not resampled 256Hz.
# chb04_36.edf was import but not resampled 256Hz.
# chb04_37.edf was import but not resampled 256Hz.
# chb04_38.edf was import but not resampled 256Hz.
# chb04_39.edf was import but not resampled 256Hz.
# chb04_40.edf was import but not resampled 256Hz.
# chb04_41.edf was import but not resampled 256Hz.
# chb04_42.edf was import but not resampled 256Hz.
# chb04_43.edf was import but not resampled 256Hz.
# chb05_01.edf was import but not resampled 256Hz.
# chb05_02.edf was import but not resampled 256Hz.
# chb05_03.edf was import but not resampled 256Hz.
# chb05_04.edf was import but not resampled 256Hz.
# chb05_05.edf was import but not resampled 256Hz.
# chb05_06.edf was import but not resampled 256Hz.
# chb05_06.edf seizure and buffer was labeled
# chb05_07.edf was import but not resampled 256Hz.
# chb05_08.edf was import but not resampled 256Hz.
# chb05_09.edf was import but not resampled 256Hz.
# chb05_10.edf was import but not resampled 256Hz.
# chb05_11.edf was import but not resampled 256Hz.
# chb05_12.edf was import but not resampled 256Hz.
# chb05_13.edf was import but not resampled 256Hz.
# chb05_13.edf seizure and buffer was labeled
# chb05_14.edf was import but not resampled 256Hz.
# chb05_15.edf was import but not resampled 256Hz.
# chb05_16.edf was import but not resampled 256Hz.
# chb05_16.edf seizure and buffer was labeled
# chb05_17.edf was import but not resampled 256Hz.
# chb05_17.edf seizure and buffer was labeled
# chb05_18.edf was import but not resampled 256Hz.
# chb05_19.edf was import but not resampled 256Hz.
# chb05_20.edf was import but not resampled 256Hz.
# chb05_21.edf was import but not resampled 256Hz.
# chb05_22.edf was import but not resampled 256Hz.
# chb05_22.edf seizure and buffer was labeled
# chb05_23.edf was import but not resampled 256Hz.
# chb05_24.edf was import but not resampled 256Hz.
# chb05_25.edf was import but not resampled 256Hz.
# chb05_26.edf was import but not resampled 256Hz.
# chb05_27.edf was import but not resampled 256Hz.
# chb05_28.edf was import but not resampled 256Hz.
# chb05_29.edf was import but not resampled 256Hz.
# chb05_30.edf was import but not resampled 256Hz.
# chb05_31.edf was import but not resampled 256Hz.
# chb05_32.edf was import but not resampled 256Hz.
# chb05_33.edf was import but not resampled 256Hz.
# chb05_34.edf was import but not resampled 256Hz.
# chb05_35.edf was import but not resampled 256Hz.
# chb05_36.edf was import but not resampled 256Hz.
# chb05_37.edf was import but not resampled 256Hz.
# chb05_38.edf was import but not resampled 256Hz.
# chb05_39.edf was import but not resampled 256Hz.
# chb06_01.edf was import but not resampled 256Hz.
# chb06_01.edf seizure and buffer was labeled
# chb06_01.edf seizure and buffer was labeled
# chb06_01.edf seizure and buffer was labeled
# chb06_02.edf was import but not resampled 256Hz.
# chb06_03.edf was import but not resampled 256Hz.
# chb06_04.edf was import but not resampled 256Hz.
# chb06_04.edf seizure and buffer was labeled
# chb06_04.edf seizure and buffer was labeled
# chb06_05.edf was import but not resampled 256Hz.
# chb06_06.edf was import but not resampled 256Hz.
# chb06_07.edf was import but not resampled 256Hz.
# chb06_08.edf was import but not resampled 256Hz.
# chb06_09.edf was import but not resampled 256Hz.
# chb06_09.edf seizure and buffer was labeled
# chb06_10.edf was import but not resampled 256Hz.
# chb06_10.edf seizure and buffer was labeled
# chb06_12.edf was import but not resampled 256Hz.
# chb06_13.edf was import but not resampled 256Hz.
# chb06_13.edf seizure and buffer was labeled
# chb06_14.edf was import but not resampled 256Hz.
# chb06_15.edf was import but not resampled 256Hz.
# chb06_16.edf was import but not resampled 256Hz.
# chb06_17.edf was import but not resampled 256Hz.
# chb06_18.edf was import but not resampled 256Hz.
# chb06_18.edf seizure and buffer was labeled
# chb06_24.edf was import but not resampled 256Hz.
# chb06_24.edf seizure and buffer was labeled
# chb07_01.edf was import but not resampled 256Hz.
# chb07_02.edf was import but not resampled 256Hz.
# chb07_03.edf was import but not resampled 256Hz.
# chb07_04.edf was import but not resampled 256Hz.
# chb07_05.edf was import but not resampled 256Hz.
# chb07_06.edf was import but not resampled 256Hz.
# chb07_07.edf was import but not resampled 256Hz.
# chb07_08.edf was import but not resampled 256Hz.
# chb07_09.edf was import but not resampled 256Hz.
# chb07_10.edf was import but not resampled 256Hz.
# chb07_11.edf was import but not resampled 256Hz.
# chb07_12.edf was import but not resampled 256Hz.
# chb07_12.edf seizure and buffer was labeled
# chb07_13.edf was import but not resampled 256Hz.
# chb07_13.edf seizure and buffer was labeled
# chb07_14.edf was import but not resampled 256Hz.
# chb07_15.edf was import but not resampled 256Hz.
# chb07_16.edf was import but not resampled 256Hz.
# chb07_17.edf was import but not resampled 256Hz.
# chb07_18.edf was import but not resampled 256Hz.
# chb07_19.edf was import but not resampled 256Hz.
# chb07_19.edf seizure and buffer was labeled
# chb08_02.edf was import but not resampled 256Hz.
# chb08_02.edf seizure and buffer was labeled
# chb08_03.edf was import but not resampled 256Hz.
# chb08_04.edf was import but not resampled 256Hz.
# chb08_05.edf was import but not resampled 256Hz.
# chb08_05.edf seizure and buffer was labeled
# chb08_10.edf was import but not resampled 256Hz.
# chb08_11.edf was import but not resampled 256Hz.
# chb08_11.edf seizure and buffer was labeled
# chb08_12.edf was import but not resampled 256Hz.
# chb08_13.edf was import but not resampled 256Hz.
# chb08_13.edf seizure and buffer was labeled
# chb08_14.edf was import but not resampled 256Hz.
# chb08_15.edf was import but not resampled 256Hz.
# chb08_16.edf was import but not resampled 256Hz.
# chb08_17.edf was import but not resampled 256Hz.
# chb08_18.edf was import but not resampled 256Hz.
# chb08_19.edf was import but not resampled 256Hz.
# chb08_20.edf was import but not resampled 256Hz.
# chb08_21.edf was import but not resampled 256Hz.
# chb08_21.edf seizure and buffer was labeled
# chb08_22.edf was import but not resampled 256Hz.
# chb08_23.edf was import but not resampled 256Hz.
# chb08_24.edf was import but not resampled 256Hz.
# chb08_29.edf was import but not resampled 256Hz.
# chb09_01.edf was import but not resampled 256Hz.
# chb09_02.edf was import but not resampled 256Hz.
# chb09_03.edf was import but not resampled 256Hz.
# chb09_04.edf was import but not resampled 256Hz.
# chb09_05.edf was import but not resampled 256Hz.
# chb09_06.edf was import but not resampled 256Hz.
# chb09_06.edf seizure and buffer was labeled
# chb09_07.edf was import but not resampled 256Hz.
# chb09_08.edf was import but not resampled 256Hz.
# chb09_08.edf seizure and buffer was labeled
# chb09_08.edf seizure and buffer was labeled
# chb09_09.edf was import but not resampled 256Hz.
# chb09_10.edf was import but not resampled 256Hz.
# chb09_11.edf was import but not resampled 256Hz.
# chb09_12.edf was import but not resampled 256Hz.
# chb09_13.edf was import but not resampled 256Hz.
# chb09_14.edf was import but not resampled 256Hz.
# chb09_15.edf was import but not resampled 256Hz.
# chb09_16.edf was import but not resampled 256Hz.
# chb09_17.edf was import but not resampled 256Hz.
# file too short to host interictal sequence.
# chb09_18.edf was import but not resampled 256Hz.
# chb09_19.edf was import but not resampled 256Hz.
# chb09_19.edf seizure and buffer was labeled
# chb10_01.edf was import but not resampled 256Hz.
# chb10_02.edf was import but not resampled 256Hz.
# chb10_03.edf was import but not resampled 256Hz.
# chb10_04.edf was import but not resampled 256Hz.
# chb10_05.edf was import but not resampled 256Hz.
# chb10_06.edf was import but not resampled 256Hz.
# chb10_07.edf was import but not resampled 256Hz.
# chb10_08.edf was import but not resampled 256Hz.
# chb10_12.edf was import but not resampled 256Hz.
# chb10_12.edf seizure and buffer was labeled
# chb10_13.edf was import but not resampled 256Hz.
# chb10_14.edf was import but not resampled 256Hz.
# chb10_15.edf was import but not resampled 256Hz.
# chb10_16.edf was import but not resampled 256Hz.
# chb10_17.edf was import but not resampled 256Hz.
# chb10_18.edf was import but not resampled 256Hz.
# chb10_19.edf was import but not resampled 256Hz.
# chb10_20.edf was import but not resampled 256Hz.
# chb10_20.edf seizure and buffer was labeled
# chb10_21.edf was import but not resampled 256Hz.
# chb10_22.edf was import but not resampled 256Hz.
# chb10_27.edf was import but not resampled 256Hz.
# chb10_27.edf seizure and buffer was labeled
# chb10_28.edf was import but not resampled 256Hz.
# chb10_30.edf was import but not resampled 256Hz.
# chb10_30.edf seizure and buffer was labeled
# chb10_31.edf was import but not resampled 256Hz.
# chb10_31.edf seizure and buffer was labeled
# chb10_38.edf was import but not resampled 256Hz.
# chb10_38.edf seizure and buffer was labeled
# chb10_89.edf was import but not resampled 256Hz.
# chb10_89.edf seizure and buffer was labeled
# chb11_01.edf was import but not resampled 256Hz.
# chb11_02.edf was import but not resampled 256Hz.
# chb11_03.edf was import but not resampled 256Hz.
# chb11_04.edf was import but not resampled 256Hz.
# chb11_05.edf was import but not resampled 256Hz.
# chb11_06.edf was import but not resampled 256Hz.
# chb11_07.edf was import but not resampled 256Hz.
# chb11_08.edf was import but not resampled 256Hz.
# chb11_09.edf was import but not resampled 256Hz.
# chb11_10.edf was import but not resampled 256Hz.
# chb11_11.edf was import but not resampled 256Hz.
# chb11_12.edf was import but not resampled 256Hz.
# chb11_13.edf was import but not resampled 256Hz.
# chb11_14.edf was import but not resampled 256Hz.
# chb11_15.edf was import but not resampled 256Hz.
# chb11_16.edf was import but not resampled 256Hz.
# chb11_17.edf was import but not resampled 256Hz.
# chb11_18.edf was import but not resampled 256Hz.
# chb11_19.edf was import but not resampled 256Hz.
# chb11_24.edf was import but not resampled 256Hz.
# chb11_25.edf was import but not resampled 256Hz.
# chb11_26.edf was import but not resampled 256Hz.
# chb11_27.edf was import but not resampled 256Hz.
# chb11_53.edf was import but not resampled 256Hz.
# chb11_54.edf was import but not resampled 256Hz.
# chb11_55.edf was import but not resampled 256Hz.
# chb11_56.edf was import but not resampled 256Hz.
# chb11_58.edf was import but not resampled 256Hz.
# chb11_60.edf was import but not resampled 256Hz.
# chb11_61.edf was import but not resampled 256Hz.
# chb11_62.edf was import but not resampled 256Hz.
# chb11_63.edf was import but not resampled 256Hz.
# chb11_82.edf was import but not resampled 256Hz.
# chb11_82.edf seizure and buffer was labeled
# chb11_92.edf was import but not resampled 256Hz.
# chb11_92.edf seizure and buffer was labeled
# chb11_99.edf was import but not resampled 256Hz.
# chb11_99.edf seizure and buffer was labeled
# chb12_06.edf was import but not resampled 256Hz.
# chb12_06.edf seizure and buffer was labeled
# chb12_06.edf seizure and buffer was labeled
# chb12_08.edf was import but not resampled 256Hz.
# chb12_08.edf seizure and buffer was labeled
# chb12_08.edf seizure and buffer was labeled
# chb12_08.edf seizure and buffer was labeled
# chb12_08.edf seizure and buffer was labeled
# chb12_09.edf was import but not resampled 256Hz.
# chb12_09.edf seizure and buffer was labeled
# chb12_09.edf seizure and buffer was labeled
# chb12_10.edf was import but not resampled 256Hz.
# chb12_10.edf seizure and buffer was labeled
# chb12_10.edf seizure and buffer was labeled
# chb12_11.edf was import but not resampled 256Hz.
# chb12_11.edf seizure and buffer was labeled
# chb12_19.edf was import but not resampled 256Hz.
# chb12_20.edf was import but not resampled 256Hz.
# chb12_21.edf was import but not resampled 256Hz.
# chb12_23.edf was import but not resampled 256Hz.
# chb12_23.edf seizure and buffer was labeled
# chb12_23.edf seizure and buffer was labeled
# chb12_23.edf seizure and buffer was labeled
# chb12_24.edf was import but not resampled 256Hz.
# couldnt load datafile chb12chb12_27.edf
# couldnt read data from edf ...
# couldnt load datafile chb12chb12_28.edf
# couldnt read data from edf ...
# couldnt load datafile chb12chb12_29.edf
# couldnt read data from edf ...
# chb12_32.edf was import but not resampled 256Hz.
# chb12_33.edf was import but not resampled 256Hz.
# chb12_33.edf seizure and buffer was labeled
# chb12_33.edf seizure and buffer was labeled
# chb12_34.edf was import but not resampled 256Hz.
# chb12_35.edf was import but not resampled 256Hz.
# chb12_36.edf was import but not resampled 256Hz.
# chb12_36.edf seizure and buffer was labeled
# chb12_37.edf was import but not resampled 256Hz.
# chb12_38.edf was import but not resampled 256Hz.
# chb12_38.edf seizure and buffer was labeled
# chb12_38.edf seizure and buffer was labeled
# chb12_38.edf seizure and buffer was labeled
# chb12_38.edf seizure and buffer was labeled
# chb12_38.edf seizure and buffer was labeled
# chb12_39.edf was import but not resampled 256Hz.
# chb12_40.edf was import but not resampled 256Hz.
# chb12_41.edf was import but not resampled 256Hz.
# chb12_42.edf was import but not resampled 256Hz.
# chb12_42.edf seizure and buffer was labeled
# chb12_42.edf seizure and buffer was labeled
# chb12_42.edf seizure and buffer was labeled
# chb12_42.edf seizure and buffer was labeled
# chb12_42.edf seizure and buffer was labeled
# chb13_02.edf was import but not resampled 256Hz.
# chb13_03.edf was import but not resampled 256Hz.
# chb13_04.edf was import but not resampled 256Hz.
# incomplete channels. skipping ...
# chb13_05.edf was import but not resampled 256Hz.
# incomplete channels. skipping ...
# chb13_06.edf was import but not resampled 256Hz.
# incomplete channels. skipping ...
# chb13_07.edf was import but not resampled 256Hz.
# incomplete channels. skipping ...
# chb13_08.edf was import but not resampled 256Hz.
# incomplete channels. skipping ...
# chb13_09.edf was import but not resampled 256Hz.
# incomplete channels. skipping ...
# chb13_10.edf was import but not resampled 256Hz.
# incomplete channels. skipping ...
# chb13_11.edf was import but not resampled 256Hz.
# incomplete channels. skipping ...
# chb13_12.edf was import but not resampled 256Hz.
# incomplete channels. skipping ...
# chb13_13.edf was import but not resampled 256Hz.
# incomplete channels. skipping ...
# chb13_14.edf was import but not resampled 256Hz.
# incomplete channels. skipping ...
# chb13_15.edf was import but not resampled 256Hz.
# incomplete channels. skipping ...
# chb13_16.edf was import but not resampled 256Hz.
# incomplete channels. skipping ...
# chb13_18.edf was import but not resampled 256Hz.
# incomplete channels. skipping ...
# chb13_19.edf was import but not resampled 256Hz.
# chb13_19.edf seizure and buffer was labeled
# chb13_21.edf was import but not resampled 256Hz.
# chb13_21.edf seizure and buffer was labeled
# chb13_22.edf was import but not resampled 256Hz.
# chb13_24.edf was import but not resampled 256Hz.
# incomplete channels. skipping ...
# chb13_30.edf was import but not resampled 256Hz.
# incomplete channels. skipping ...
# chb13_36.edf was import but not resampled 256Hz.
# incomplete channels. skipping ...
# chb13_37.edf was import but not resampled 256Hz.
# incomplete channels. skipping ...
# chb13_38.edf was import but not resampled 256Hz.
# incomplete channels. skipping ...
# chb13_39.edf was import but not resampled 256Hz.
# incomplete channels. skipping ...
# chb13_40.edf was import but not resampled 256Hz.
# chb13_40.edf seizure and buffer was labeled
# chb13_40.edf seizure and buffer was labeled
# incomplete channels. skipping ...
# chb13_47.edf was import but not resampled 256Hz.
# incomplete channels. skipping ...
# chb13_55.edf was import but not resampled 256Hz.
# chb13_55.edf seizure and buffer was labeled
# chb13_55.edf seizure and buffer was labeled
# chb13_56.edf was import but not resampled 256Hz.
# chb13_58.edf was import but not resampled 256Hz.
# chb13_58.edf seizure and buffer was labeled
# chb13_59.edf was import but not resampled 256Hz.
# chb13_59.edf seizure and buffer was labeled
# chb13_60.edf was import but not resampled 256Hz.
# chb13_60.edf seizure and buffer was labeled
# chb13_62.edf was import but not resampled 256Hz.
# chb13_62.edf seizure and buffer was labeled
# chb13_62.edf seizure and buffer was labeled
# chb13_62.edf seizure and buffer was labeled
# chb14_01.edf was import but not resampled 256Hz.
# chb14_02.edf was import but not resampled 256Hz.
# chb14_03.edf was import but not resampled 256Hz.
# chb14_03.edf seizure and buffer was labeled
# chb14_04.edf was import but not resampled 256Hz.
# chb14_04.edf seizure and buffer was labeled
# chb14_04.edf seizure and buffer was labeled
# chb14_06.edf was import but not resampled 256Hz.
# chb14_06.edf seizure and buffer was labeled
# chb14_07.edf was import but not resampled 256Hz.
# chb14_11.edf was import but not resampled 256Hz.
# chb14_11.edf seizure and buffer was labeled
# chb14_12.edf was import but not resampled 256Hz.
# chb14_13.edf was import but not resampled 256Hz.
# chb14_14.edf was import but not resampled 256Hz.
# chb14_16.edf was import but not resampled 256Hz.
# chb14_17.edf was import but not resampled 256Hz.
# chb14_17.edf seizure and buffer was labeled
# chb14_18.edf was import but not resampled 256Hz.
# chb14_18.edf seizure and buffer was labeled
# chb14_19.edf was import but not resampled 256Hz.
# chb14_20.edf was import but not resampled 256Hz.
# chb14_22.edf was import but not resampled 256Hz.
# chb14_24.edf was import but not resampled 256Hz.
# chb14_25.edf was import but not resampled 256Hz.
# chb14_26.edf was import but not resampled 256Hz.
# chb14_27.edf was import but not resampled 256Hz.
# chb14_27.edf seizure and buffer was labeled
# chb14_29.edf was import but not resampled 256Hz.
# chb14_30.edf was import but not resampled 256Hz.
# chb14_32.edf was import but not resampled 256Hz.
# chb14_37.edf was import but not resampled 256Hz.
# chb14_39.edf was import but not resampled 256Hz.
# chb14_42.edf was import but not resampled 256Hz.
# chb15_01.edf was import but not resampled 256Hz.
# incomplete channels. skipping ...
# chb15_02.edf was import but not resampled 256Hz.
# chb15_03.edf was import but not resampled 256Hz.
# chb15_04.edf was import but not resampled 256Hz.
# chb15_05.edf was import but not resampled 256Hz.
# chb15_06.edf was import but not resampled 256Hz.
# chb15_06.edf seizure and buffer was labeled
# chb15_07.edf was import but not resampled 256Hz.
# chb15_08.edf was import but not resampled 256Hz.
# chb15_09.edf was import but not resampled 256Hz.
# chb15_10.edf was import but not resampled 256Hz.
# chb15_10.edf seizure and buffer was labeled
# chb15_11.edf was import but not resampled 256Hz.
# chb15_12.edf was import but not resampled 256Hz.
# chb15_13.edf was import but not resampled 256Hz.
# chb15_14.edf was import but not resampled 256Hz.
# chb15_15.edf was import but not resampled 256Hz.
# chb15_15.edf seizure and buffer was labeled
# chb15_16.edf was import but not resampled 256Hz.
# chb15_17.edf was import but not resampled 256Hz.
# chb15_17.edf seizure and buffer was labeled
# chb15_19.edf was import but not resampled 256Hz.
# chb15_20.edf was import but not resampled 256Hz.
# chb15_20.edf seizure and buffer was labeled
# chb15_22.edf was import but not resampled 256Hz.
# chb15_22.edf seizure and buffer was labeled
# chb15_26.edf was import but not resampled 256Hz.
# chb15_28.edf was import but not resampled 256Hz.
# chb15_28.edf seizure and buffer was labeled
# chb15_29.edf was import but not resampled 256Hz.
# chb15_30.edf was import but not resampled 256Hz.
# chb15_31.edf was import but not resampled 256Hz.
# chb15_31.edf seizure and buffer was labeled
# chb15_32.edf was import but not resampled 256Hz.
# chb15_33.edf was import but not resampled 256Hz.
# chb15_35.edf was import but not resampled 256Hz.
# chb15_37.edf was import but not resampled 256Hz.
# chb15_40.edf was import but not resampled 256Hz.
# chb15_40.edf seizure and buffer was labeled
# chb15_40.edf seizure and buffer was labeled
# chb15_40.edf seizure and buffer was labeled
# chb15_45.edf was import but not resampled 256Hz.
# chb15_46.edf was import but not resampled 256Hz.
# chb15_46.edf seizure and buffer was labeled
# chb15_49.edf was import but not resampled 256Hz.
# chb15_49.edf seizure and buffer was labeled
# chb15_50.edf was import but not resampled 256Hz.
# chb15_51.edf was import but not resampled 256Hz.
# chb15_52.edf was import but not resampled 256Hz.
# chb15_52.edf seizure and buffer was labeled
# chb15_54.edf was import but not resampled 256Hz.
# chb15_54.edf seizure and buffer was labeled
# chb15_54.edf seizure and buffer was labeled
# chb15_54.edf seizure and buffer was labeled
# chb15_54.edf seizure and buffer was labeled
# chb15_54.edf seizure and buffer was labeled
# chb15_61.edf was import but not resampled 256Hz.
# chb15_62.edf was import but not resampled 256Hz.
# chb15_62.edf seizure and buffer was labeled
# chb15_63.edf was import but not resampled 256Hz.
# chb16_01.edf was import but not resampled 256Hz.
# chb16_02.edf was import but not resampled 256Hz.
# chb16_03.edf was import but not resampled 256Hz.
# chb16_04.edf was import but not resampled 256Hz.
# chb16_05.edf was import but not resampled 256Hz.
# chb16_06.edf was import but not resampled 256Hz.
# chb16_07.edf was import but not resampled 256Hz.
# chb16_08.edf was import but not resampled 256Hz.
# chb16_09.edf was import but not resampled 256Hz.
# chb16_10.edf was import but not resampled 256Hz.
# chb16_10.edf seizure and buffer was labeled
# chb16_11.edf was import but not resampled 256Hz.
# chb16_11.edf seizure and buffer was labeled
# chb16_12.edf was import but not resampled 256Hz.
# chb16_13.edf was import but not resampled 256Hz.
# chb16_14.edf was import but not resampled 256Hz.
# chb16_14.edf seizure and buffer was labeled
# chb16_15.edf was import but not resampled 256Hz.
# chb16_16.edf was import but not resampled 256Hz.
# chb16_16.edf seizure and buffer was labeled
# chb16_17.edf was import but not resampled 256Hz.
# chb16_17.edf seizure and buffer was labeled
# chb16_17.edf seizure and buffer was labeled
# chb16_17.edf seizure and buffer was labeled
# chb16_17.edf seizure and buffer was labeled
# chb16_18.edf was import but not resampled 256Hz.
# chb16_18.edf seizure and buffer was labeled
# chb16_18.edf seizure and buffer was labeled
# incomplete channels. skipping ...
# chb16_19.edf was import but not resampled 256Hz.
# incomplete channels. skipping ...
# chb17a_03.edf was import but not resampled 256Hz.
# chb17a_03.edf seizure and buffer was labeled
# chb17a_04.edf was import but not resampled 256Hz.
# chb17a_04.edf seizure and buffer was labeled
# chb17a_05.edf was import but not resampled 256Hz.
# chb17a_06.edf was import but not resampled 256Hz.
# chb17a_08.edf was import but not resampled 256Hz.
# chb17b_57.edf was import but not resampled 256Hz.
# chb17b_58.edf was import but not resampled 256Hz.
# chb17b_59.edf was import but not resampled 256Hz.
# chb17b_60.edf was import but not resampled 256Hz.
# chb17b_63.edf was import but not resampled 256Hz.
# chb17b_63.edf seizure and buffer was labeled
# chb17b_67.edf was import but not resampled 256Hz.
# chb17b_68.edf was import but not resampled 256Hz.
# chb17b_69.edf was import but not resampled 256Hz.
# chb17c_02.edf was import but not resampled 256Hz.
# chb17c_03.edf was import but not resampled 256Hz.
# chb17c_04.edf was import but not resampled 256Hz.
# chb17c_05.edf was import but not resampled 256Hz.
# chb17c_06.edf was import but not resampled 256Hz.
# chb17c_07.edf was import but not resampled 256Hz.
# chb17c_08.edf was import but not resampled 256Hz.
# chb17c_13.edf was import but not resampled 256Hz.
# incomplete channels. skipping ...
# chb18_01.edf was import but not resampled 256Hz.
# incomplete channels. skipping ...
# chb18_02.edf was import but not resampled 256Hz.
# chb18_03.edf was import but not resampled 256Hz.
# chb18_04.edf was import but not resampled 256Hz.
# chb18_05.edf was import but not resampled 256Hz.
# chb18_06.edf was import but not resampled 256Hz.
# chb18_07.edf was import but not resampled 256Hz.
# chb18_08.edf was import but not resampled 256Hz.
# chb18_09.edf was import but not resampled 256Hz.
# chb18_10.edf was import but not resampled 256Hz.
# chb18_11.edf was import but not resampled 256Hz.
# chb18_12.edf was import but not resampled 256Hz.
# chb18_13.edf was import but not resampled 256Hz.
# chb18_14.edf was import but not resampled 256Hz.
# chb18_15.edf was import but not resampled 256Hz.
# chb18_16.edf was import but not resampled 256Hz.
# chb18_17.edf was import but not resampled 256Hz.
# chb18_18.edf was import but not resampled 256Hz.
# chb18_19.edf was import but not resampled 256Hz.
# chb18_20.edf was import but not resampled 256Hz.
# chb18_21.edf was import but not resampled 256Hz.
# chb18_22.edf was import but not resampled 256Hz.
# chb18_23.edf was import but not resampled 256Hz.
# chb18_24.edf was import but not resampled 256Hz.
# chb18_25.edf was import but not resampled 256Hz.
# chb18_26.edf was import but not resampled 256Hz.
# chb18_27.edf was import but not resampled 256Hz.
# chb18_28.edf was import but not resampled 256Hz.
# chb18_29.edf was import but not resampled 256Hz.
# chb18_29.edf seizure and buffer was labeled
# chb18_30.edf was import but not resampled 256Hz.
# chb18_30.edf seizure and buffer was labeled
# chb18_31.edf was import but not resampled 256Hz.
# chb18_31.edf seizure and buffer was labeled
# chb18_32.edf was import but not resampled 256Hz.
# chb18_32.edf seizure and buffer was labeled
# chb18_33.edf was import but not resampled 256Hz.
# chb18_34.edf was import but not resampled 256Hz.
# chb18_35.edf was import but not resampled 256Hz.
# chb18_35.edf seizure and buffer was labeled
# chb18_36.edf was import but not resampled 256Hz.
# chb18_36.edf seizure and buffer was labeled
# chb19_01.edf was import but not resampled 256Hz.
# incomplete channels. skipping ...
# chb19_02.edf was import but not resampled 256Hz.
# chb19_03.edf was import but not resampled 256Hz.
# chb19_04.edf was import but not resampled 256Hz.
# chb19_05.edf was import but not resampled 256Hz.
# chb19_06.edf was import but not resampled 256Hz.
# chb19_07.edf was import but not resampled 256Hz.
# chb19_08.edf was import but not resampled 256Hz.
# chb19_09.edf was import but not resampled 256Hz.
# chb19_10.edf was import but not resampled 256Hz.
# chb19_11.edf was import but not resampled 256Hz.
# chb19_12.edf was import but not resampled 256Hz.
# chb19_13.edf was import but not resampled 256Hz.
# chb19_14.edf was import but not resampled 256Hz.
# chb19_15.edf was import but not resampled 256Hz.
# chb19_16.edf was import but not resampled 256Hz.
# chb19_17.edf was import but not resampled 256Hz.
# chb19_18.edf was import but not resampled 256Hz.
# chb19_19.edf was import but not resampled 256Hz.
# chb19_20.edf was import but not resampled 256Hz.
# chb19_21.edf was import but not resampled 256Hz.
# chb19_22.edf was import but not resampled 256Hz.
# chb19_23.edf was import but not resampled 256Hz.
# chb19_24.edf was import but not resampled 256Hz.
# chb19_25.edf was import but not resampled 256Hz.
# chb19_26.edf was import but not resampled 256Hz.
# chb19_27.edf was import but not resampled 256Hz.
# chb19_28.edf was import but not resampled 256Hz.
# chb19_28.edf seizure and buffer was labeled
# chb19_29.edf was import but not resampled 256Hz.
# chb19_29.edf seizure and buffer was labeled
# chb19_30.edf was import but not resampled 256Hz.
# chb19_30.edf seizure and buffer was labeled
# chb20_01.edf was import but not resampled 256Hz.
# chb20_02.edf was import but not resampled 256Hz.
# chb20_03.edf was import but not resampled 256Hz.
# chb20_04.edf was import but not resampled 256Hz.
# chb20_05.edf was import but not resampled 256Hz.
# chb20_06.edf was import but not resampled 256Hz.
# chb20_07.edf was import but not resampled 256Hz.
# chb20_08.edf was import but not resampled 256Hz.
# chb20_11.edf was import but not resampled 256Hz.
# chb20_12.edf was import but not resampled 256Hz.
# chb20_12.edf seizure and buffer was labeled
# chb20_13.edf was import but not resampled 256Hz.
# chb20_13.edf seizure and buffer was labeled
# chb20_13.edf seizure and buffer was labeled
# chb20_14.edf was import but not resampled 256Hz.
# chb20_14.edf seizure and buffer was labeled
# chb20_15.edf was import but not resampled 256Hz.
# chb20_15.edf seizure and buffer was labeled
# chb20_15.edf seizure and buffer was labeled
# chb20_16.edf was import but not resampled 256Hz.
# chb20_16.edf seizure and buffer was labeled
# chb20_17.edf was import but not resampled 256Hz.
# chb20_21.edf was import but not resampled 256Hz.
# chb20_22.edf was import but not resampled 256Hz.
# file too short to host interictal sequence.
# chb20_23.edf was import but not resampled 256Hz.
# chb20_25.edf was import but not resampled 256Hz.
# chb20_26.edf was import but not resampled 256Hz.
# chb20_27.edf was import but not resampled 256Hz.
# chb20_28.edf was import but not resampled 256Hz.
# chb20_29.edf was import but not resampled 256Hz.
# chb20_30.edf was import but not resampled 256Hz.
# chb20_31.edf was import but not resampled 256Hz.
# chb20_34.edf was import but not resampled 256Hz.
# chb20_59.edf was import but not resampled 256Hz.
# chb20_60.edf was import but not resampled 256Hz.
# chb20_68.edf was import but not resampled 256Hz.
# chb20_68.edf seizure and buffer was labeled
# chb21_01.edf was import but not resampled 256Hz.
# chb21_02.edf was import but not resampled 256Hz.
# chb21_03.edf was import but not resampled 256Hz.
# chb21_04.edf was import but not resampled 256Hz.
# chb21_05.edf was import but not resampled 256Hz.
# chb21_06.edf was import but not resampled 256Hz.
# chb21_07.edf was import but not resampled 256Hz.
# chb21_08.edf was import but not resampled 256Hz.
# chb21_09.edf was import but not resampled 256Hz.
# chb21_10.edf was import but not resampled 256Hz.
# chb21_11.edf was import but not resampled 256Hz.
# chb21_12.edf was import but not resampled 256Hz.
# chb21_13.edf was import but not resampled 256Hz.
# chb21_14.edf was import but not resampled 256Hz.
# chb21_15.edf was import but not resampled 256Hz.
# chb21_16.edf was import but not resampled 256Hz.
# chb21_17.edf was import but not resampled 256Hz.
# chb21_18.edf was import but not resampled 256Hz.
# chb21_19.edf was import but not resampled 256Hz.
# chb21_19.edf seizure and buffer was labeled
# chb21_20.edf was import but not resampled 256Hz.
# chb21_20.edf seizure and buffer was labeled
# chb21_21.edf was import but not resampled 256Hz.
# chb21_21.edf seizure and buffer was labeled
# chb21_22.edf was import but not resampled 256Hz.
# chb21_22.edf seizure and buffer was labeled
# chb21_23.edf was import but not resampled 256Hz.
# chb21_24.edf was import but not resampled 256Hz.
# chb21_25.edf was import but not resampled 256Hz.
# chb21_26.edf was import but not resampled 256Hz.
# chb21_27.edf was import but not resampled 256Hz.
# chb21_28.edf was import but not resampled 256Hz.
# chb21_29.edf was import but not resampled 256Hz.
# chb21_30.edf was import but not resampled 256Hz.
# chb21_31.edf was import but not resampled 256Hz.
# chb21_32.edf was import but not resampled 256Hz.
# chb21_33.edf was import but not resampled 256Hz.
# chb22_01.edf was import but not resampled 256Hz.
# chb22_02.edf was import but not resampled 256Hz.
# chb22_03.edf was import but not resampled 256Hz.
# chb22_04.edf was import but not resampled 256Hz.
# chb22_05.edf was import but not resampled 256Hz.
# chb22_06.edf was import but not resampled 256Hz.
# chb22_07.edf was import but not resampled 256Hz.
# chb22_08.edf was import but not resampled 256Hz.
# chb22_09.edf was import but not resampled 256Hz.
# chb22_10.edf was import but not resampled 256Hz.
# chb22_11.edf was import but not resampled 256Hz.
# chb22_15.edf was import but not resampled 256Hz.
# chb22_16.edf was import but not resampled 256Hz.
# chb22_17.edf was import but not resampled 256Hz.
# chb22_18.edf was import but not resampled 256Hz.
# chb22_19.edf was import but not resampled 256Hz.
# chb22_20.edf was import but not resampled 256Hz.
# chb22_20.edf seizure and buffer was labeled
# chb22_21.edf was import but not resampled 256Hz.
# chb22_22.edf was import but not resampled 256Hz.
# chb22_23.edf was import but not resampled 256Hz.
# chb22_24.edf was import but not resampled 256Hz.
# chb22_25.edf was import but not resampled 256Hz.
# chb22_25.edf seizure and buffer was labeled
# chb22_26.edf was import but not resampled 256Hz.
# chb22_27.edf was import but not resampled 256Hz.
# chb22_28.edf was import but not resampled 256Hz.
# chb22_29.edf was import but not resampled 256Hz.
# chb22_30.edf was import but not resampled 256Hz.
# chb22_38.edf was import but not resampled 256Hz.
# chb22_38.edf seizure and buffer was labeled
# chb22_51.edf was import but not resampled 256Hz.
# chb22_54.edf was import but not resampled 256Hz.
# chb22_77.edf was import but not resampled 256Hz.
# chb23_06.edf was import but not resampled 256Hz.
# chb23_06.edf seizure and buffer was labeled
# chb23_07.edf was import but not resampled 256Hz.
# chb23_08.edf was import but not resampled 256Hz.
# chb23_08.edf seizure and buffer was labeled
# chb23_08.edf seizure and buffer was labeled
# chb23_09.edf was import but not resampled 256Hz.
# chb23_09.edf seizure and buffer was labeled
# chb23_09.edf seizure and buffer was labeled
# chb23_09.edf seizure and buffer was labeled
# chb23_09.edf seizure and buffer was labeled
# chb23_10.edf was import but not resampled 256Hz.
# chb23_16.edf was import but not resampled 256Hz.
# chb23_17.edf was import but not resampled 256Hz.
# chb23_19.edf was import but not resampled 256Hz.
# chb23_20.edf was import but not resampled 256Hz.
# chb24_01.edf was import but not resampled 256Hz.
# chb24_01.edf seizure and buffer was labeled
# chb24_01.edf seizure and buffer was labeled
# chb24_02.edf was import but not resampled 256Hz.
# chb24_03.edf was import but not resampled 256Hz.
# chb24_03.edf seizure and buffer was labeled
# chb24_03.edf seizure and buffer was labeled
# chb24_04.edf was import but not resampled 256Hz.
# chb24_04.edf seizure and buffer was labeled
# chb24_04.edf seizure and buffer was labeled
# chb24_04.edf seizure and buffer was labeled
# chb24_05.edf was import but not resampled 256Hz.
# chb24_06.edf was import but not resampled 256Hz.
# chb24_06.edf seizure and buffer was labeled
# chb24_07.edf was import but not resampled 256Hz.
# chb24_07.edf seizure and buffer was labeled
# preictal interval is not fully covered by datafile! skipping ...
# chb24_08.edf was import but not resampled 256Hz.
# chb24_09.edf was import but not resampled 256Hz.
# chb24_09.edf seizure and buffer was labeled
# chb24_10.edf was import but not resampled 256Hz.
# chb24_11.edf was import but not resampled 256Hz.
# chb24_11.edf seizure and buffer was labeled
# chb24_12.edf was import but not resampled 256Hz.
# chb24_13.edf was import but not resampled 256Hz.
# chb24_13.edf seizure and buffer was labeled
# chb24_14.edf was import but not resampled 256Hz.
# chb24_14.edf seizure and buffer was labeled
# chb24_15.edf was import but not resampled 256Hz.
# chb24_15.edf seizure and buffer was labeled
# chb24_16.edf was import but not resampled 256Hz.
# chb24_17.edf was import but not resampled 256Hz.
# chb24_17.edf seizure and buffer was labeled
# chb24_18.edf was import but not resampled 256Hz.
# chb24_19.edf was import but not resampled 256Hz.
# chb24_20.edf was import but not resampled 256Hz.
# chb24_21.edf was import but not resampled 256Hz.
# chb24_21.edf seizure and buffer was labeled
# chb24_22.edf was import but not resampled 256Hz.
# file too short to host interictal sequence.
# dataread_error 3
# reached_file_start 1
# reached_file_end 0
# seizure_too_small 0
# overlapping_seizure 0
# ictal_epochs 0
# preictal_epochs 180
# interictal_epochs 515
# seizure_max_reached 0
# incomplete_channels 28
# interictal_skipped 4
# D:\_c\spiced\ai-seizure-detectives\source\..\data\preprocessed_60_dur1_all.arrow was successfully written.

# %% [markdown]
# ## Feature Extraction

# %%
### aggregate Functions for mean psd:
delta = lambda x: calculate_mean_psd(x, frequency_ranges={'Delta' : FREQUENCY_RANGES['Delta']})[x.name]['Delta']
theta = lambda x: calculate_mean_psd(x, frequency_ranges={'Theta' : FREQUENCY_RANGES['Theta']})[x.name]['Theta']
gamma = lambda x: calculate_mean_psd(x, frequency_ranges={'Gamma': FREQUENCY_RANGES['Gamma']})[x.name]['Gamma']

delta_agg = pd.NamedAgg(column='delta', aggfunc=delta)
theta_agg = pd.NamedAgg(column='theta', aggfunc=theta)
gamma_agg = pd.NamedAgg(column='gamma', aggfunc=gamma)

### aggregate mean features:
abs_mean = lambda x: x.apply(abs).mean()
abs_mean_agg = pd.NamedAgg(column='abs_mean', aggfunc=abs_mean)

### aggregate Functions for target:
target_foo = lambda x, pred_interval=PRED_INTERVAL: 0 < x.dt.total_seconds().min() < pred_interval

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

def preprocess_data(df, window_size):
    # Grouping and aggregating features
    df_features = df.groupby(['epoch', 'segment_id']).agg(
        {C: ['std', 'var', abs_mean_agg, delta_agg, theta_agg, gamma_agg] for C in CHANNELS} | 
        {target_colname: [target_foo]}
    )
    
    # Renaming columns
    df_features.columns = ['_'.join(col).strip() for col in df_features.columns.values if target_colname != col[0]] + [target_colname]
    df_features.reset_index(inplace=True)


    # Reshaping array
    original_array = np.array(df_features)
    epoch_column = original_array[:, 0]
    num_epochs = df_features.epoch.unique()[-1]
    num_segments = len(df_features.segment_id.unique())
    reshaped_array = np.empty((num_epochs, num_segments, original_array.shape[1]))

    for epoch in range(num_epochs):
        start_idx = epoch * num_segments
        end_idx = (epoch + 1) * num_segments
        reshaped_array[epoch, :, :] = original_array[start_idx:end_idx, :]

    # Creating sequence trains
    num_batches, num_sequences, num_features = reshaped_array.shape
    num_augmented_batches = num_sequences - window_size + 1

    data = np.zeros((num_batches * num_augmented_batches, window_size, num_features))

    for batch_idx in range(num_batches):
        for seq_idx in range(num_augmented_batches):
            data[batch_idx * num_augmented_batches + seq_idx, :, :] = reshaped_array[batch_idx, seq_idx:seq_idx + window_size, :]
        
    return data

# %%
if not SKIP_FEATURES:
    data = preprocess_data(fit_df, window_size=window_size)
    print(data.shape)
    save_file(data=data, file_name=feature_filename)
else:
    data = load_file(feature_filename)
# Out:
# (21514, 30, 63)
# saving npy

# %%
# %run model_rnn.ipynb
# Out:
# WARNING:tensorflow:From d:\_c\spiced\ai-seizure-detectives\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# data already loaded in parent notebook
# 555 of epochs for training, 139 of epochs for testing/validation
# train shape (17205, 30, 62) ratio of seizures 0.25
# test shape (4309, 30, 62), ratio of seizures 0.28
# train shape (17205, 30, 60)
# test shape (4309, 30, 60)
# WARNING:tensorflow:From d:\_c\spiced\ai-seizure-detectives\venv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 256)               324608
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense (Dense)               (None, 256)               65792
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  batch_normalization (Batch  (None, 256)               1024
#  Normalization)
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 391681 (1.49 MB)
# Trainable params: 391169 (1.49 MB)
# Non-trainable params: 512 (2.00 KB)
# _________________________________________________________________
# Epoch 1/100
# WARNING:tensorflow:From d:\_c\spiced\ai-seizure-detectives\venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From d:\_c\spiced\ai-seizure-detectives\venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 14/14 [==============================] - 4s 130ms/step - loss: 19.3862 - accuracy: 0.4332 - auc: 0.4981 - val_loss: 19.2123 - val_accuracy: 0.3049 - val_auc: 0.4699
# Epoch 2/100
#  1/14 [=>............................] - ETA: 1s - loss: 19.3192 - accuracy: 0.4530 - auc: 0.5151
# d:\_c\spiced\ai-seizure-detectives\venv\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 14/14 [==============================] - 1s 99ms/step - loss: 19.3047 - accuracy: 0.4441 - auc: 0.5041 - val_loss: 19.1378 - val_accuracy: 0.3037 - val_auc: 0.4750
# Epoch 3/100
# 14/14 [==============================] - 1s 98ms/step - loss: 19.2149 - accuracy: 0.4502 - auc: 0.5155 - val_loss: 19.0636 - val_accuracy: 0.3017 - val_auc: 0.4847
# Epoch 4/100
# 14/14 [==============================] - 1s 98ms/step - loss: 19.1314 - accuracy: 0.4552 - auc: 0.5211 - val_loss: 18.9896 - val_accuracy: 0.3017 - val_auc: 0.4973
# Epoch 5/100
# 14/14 [==============================] - 1s 99ms/step - loss: 19.0536 - accuracy: 0.4597 - auc: 0.5224 - val_loss: 18.9160 - val_accuracy: 0.2973 - val_auc: 0.5109
# Epoch 6/100
# 14/14 [==============================] - 1s 99ms/step - loss: 18.9730 - accuracy: 0.4645 - auc: 0.5297 - val_loss: 18.8433 - val_accuracy: 0.2970 - val_auc: 0.5222
# Epoch 7/100
# 14/14 [==============================] - 1s 100ms/step - loss: 18.8990 - accuracy: 0.4674 - auc: 0.5340 - val_loss: 18.7705 - val_accuracy: 0.2967 - val_auc: 0.5358
# Epoch 8/100
# 14/14 [==============================] - 1s 103ms/step - loss: 18.8163 - accuracy: 0.4703 - auc: 0.5383 - val_loss: 18.6973 - val_accuracy: 0.2958 - val_auc: 0.5489
# Epoch 9/100
# 14/14 [==============================] - 1s 104ms/step - loss: 18.7462 - accuracy: 0.4730 - auc: 0.5408 - val_loss: 18.6247 - val_accuracy: 0.2961 - val_auc: 0.5625
# Epoch 10/100
# 14/14 [==============================] - 1s 104ms/step - loss: 18.6625 - accuracy: 0.4710 - auc: 0.5445 - val_loss: 18.5522 - val_accuracy: 0.2950 - val_auc: 0.5779
# Epoch 11/100
# 14/14 [==============================] - 1s 104ms/step - loss: 18.5859 - accuracy: 0.4789 - auc: 0.5507 - val_loss: 18.4804 - val_accuracy: 0.2961 - val_auc: 0.5906
# Epoch 12/100
# 14/14 [==============================] - 1s 105ms/step - loss: 18.5088 - accuracy: 0.4776 - auc: 0.5552 - val_loss: 18.4082 - val_accuracy: 0.3011 - val_auc: 0.6018
# Epoch 13/100
# 14/14 [==============================] - 1s 103ms/step - loss: 18.4450 - accuracy: 0.4811 - auc: 0.5509 - val_loss: 18.3358 - val_accuracy: 0.3051 - val_auc: 0.6128
# Epoch 14/100
# 14/14 [==============================] - 1s 104ms/step - loss: 18.3651 - accuracy: 0.4838 - auc: 0.5562 - val_loss: 18.2649 - val_accuracy: 0.3072 - val_auc: 0.6239
# Epoch 15/100
# 14/14 [==============================] - 1s 104ms/step - loss: 18.2872 - accuracy: 0.4892 - auc: 0.5685 - val_loss: 18.1934 - val_accuracy: 0.3098 - val_auc: 0.6346
# Epoch 16/100
# 14/14 [==============================] - 1s 103ms/step - loss: 18.2182 - accuracy: 0.4883 - auc: 0.5637 - val_loss: 18.1222 - val_accuracy: 0.3156 - val_auc: 0.6465
# Epoch 17/100
# 14/14 [==============================] - 1s 103ms/step - loss: 18.1432 - accuracy: 0.4839 - auc: 0.5626 - val_loss: 18.0503 - val_accuracy: 0.3301 - val_auc: 0.6528
# Epoch 18/100
# 14/14 [==============================] - 1s 103ms/step - loss: 18.0655 - accuracy: 0.4966 - auc: 0.5739 - val_loss: 17.9796 - val_accuracy: 0.3371 - val_auc: 0.6580
# Epoch 19/100
# 14/14 [==============================] - 1s 103ms/step - loss: 18.0027 - accuracy: 0.4897 - auc: 0.5647 - val_loss: 17.9090 - val_accuracy: 0.3409 - val_auc: 0.6640
# Epoch 20/100
# 14/14 [==============================] - 1s 100ms/step - loss: 17.9287 - accuracy: 0.4893 - auc: 0.5672 - val_loss: 17.8396 - val_accuracy: 0.3455 - val_auc: 0.6676
# Epoch 21/100
# 14/14 [==============================] - 1s 102ms/step - loss: 17.8466 - accuracy: 0.5008 - auc: 0.5821 - val_loss: 17.7695 - val_accuracy: 0.3548 - val_auc: 0.6699
# Epoch 22/100
# 14/14 [==============================] - 1s 100ms/step - loss: 17.7769 - accuracy: 0.4938 - auc: 0.5801 - val_loss: 17.7001 - val_accuracy: 0.3609 - val_auc: 0.6749
# Epoch 23/100
# 14/14 [==============================] - 1s 101ms/step - loss: 17.7107 - accuracy: 0.4971 - auc: 0.5822 - val_loss: 17.6307 - val_accuracy: 0.3685 - val_auc: 0.6796
# Epoch 24/100
# 14/14 [==============================] - 1s 102ms/step - loss: 17.6246 - accuracy: 0.5062 - auc: 0.5928 - val_loss: 17.5607 - val_accuracy: 0.3795 - val_auc: 0.6825
# Epoch 25/100
# 14/14 [==============================] - 1s 101ms/step - loss: 17.5578 - accuracy: 0.5043 - auc: 0.5942 - val_loss: 17.4912 - val_accuracy: 0.3891 - val_auc: 0.6843
# Epoch 26/100
# 14/14 [==============================] - 1s 104ms/step - loss: 17.4919 - accuracy: 0.5025 - auc: 0.5888 - val_loss: 17.4228 - val_accuracy: 0.3984 - val_auc: 0.6873
# Epoch 27/100
# 14/14 [==============================] - 1s 102ms/step - loss: 17.4134 - accuracy: 0.5055 - auc: 0.5950 - val_loss: 17.3542 - val_accuracy: 0.4031 - val_auc: 0.6894
# Epoch 28/100
# 14/14 [==============================] - 1s 101ms/step - loss: 17.3529 - accuracy: 0.5068 - auc: 0.5881 - val_loss: 17.2865 - val_accuracy: 0.4103 - val_auc: 0.6891
# Epoch 29/100
# 14/14 [==============================] - 1s 99ms/step - loss: 17.2803 - accuracy: 0.5100 - auc: 0.5956 - val_loss: 17.2184 - val_accuracy: 0.4196 - val_auc: 0.6890
# Epoch 30/100
# 14/14 [==============================] - 1s 101ms/step - loss: 17.2038 - accuracy: 0.5074 - auc: 0.6001 - val_loss: 17.1506 - val_accuracy: 0.4246 - val_auc: 0.6900
# Epoch 31/100
# 14/14 [==============================] - 1s 98ms/step - loss: 17.1306 - accuracy: 0.5188 - auc: 0.6127 - val_loss: 17.0832 - val_accuracy: 0.4316 - val_auc: 0.6905
# Epoch 32/100
# 14/14 [==============================] - 1s 97ms/step - loss: 17.0721 - accuracy: 0.5129 - auc: 0.6011 - val_loss: 17.0148 - val_accuracy: 0.4412 - val_auc: 0.6906
# Epoch 33/100
# 14/14 [==============================] - 1s 97ms/step - loss: 16.9943 - accuracy: 0.5211 - auc: 0.6109 - val_loss: 16.9477 - val_accuracy: 0.4475 - val_auc: 0.6932
# Epoch 34/100
# 14/14 [==============================] - 1s 97ms/step - loss: 16.9356 - accuracy: 0.5214 - auc: 0.6056 - val_loss: 16.8811 - val_accuracy: 0.4507 - val_auc: 0.6951
# Epoch 35/100
# 14/14 [==============================] - 1s 98ms/step - loss: 16.8610 - accuracy: 0.5165 - auc: 0.6109 - val_loss: 16.8141 - val_accuracy: 0.4531 - val_auc: 0.6968
# Epoch 36/100
# 14/14 [==============================] - 1s 99ms/step - loss: 16.7785 - accuracy: 0.5227 - auc: 0.6299 - val_loss: 16.7479 - val_accuracy: 0.4548 - val_auc: 0.6970
# Epoch 37/100
# 14/14 [==============================] - 1s 101ms/step - loss: 16.7344 - accuracy: 0.5211 - auc: 0.6091 - val_loss: 16.6813 - val_accuracy: 0.4580 - val_auc: 0.6975
# Epoch 38/100
# 14/14 [==============================] - 1s 102ms/step - loss: 16.6533 - accuracy: 0.5256 - auc: 0.6243 - val_loss: 16.6148 - val_accuracy: 0.4595 - val_auc: 0.6984
# Epoch 39/100
# 14/14 [==============================] - 1s 100ms/step - loss: 16.5929 - accuracy: 0.5279 - auc: 0.6173 - val_loss: 16.5487 - val_accuracy: 0.4632 - val_auc: 0.6991
# Epoch 40/100
# 14/14 [==============================] - 1s 97ms/step - loss: 16.5231 - accuracy: 0.5281 - auc: 0.6230 - val_loss: 16.4833 - val_accuracy: 0.4664 - val_auc: 0.6996
# Epoch 41/100
# 14/14 [==============================] - 1s 98ms/step - loss: 16.4468 - accuracy: 0.5272 - auc: 0.6293 - val_loss: 16.4188 - val_accuracy: 0.4667 - val_auc: 0.6996
# Epoch 42/100
# 14/14 [==============================] - 1s 98ms/step - loss: 16.4048 - accuracy: 0.5233 - auc: 0.6151 - val_loss: 16.3529 - val_accuracy: 0.4690 - val_auc: 0.6993
# Epoch 43/100
# 14/14 [==============================] - 1s 98ms/step - loss: 16.3201 - accuracy: 0.5333 - auc: 0.6326 - val_loss: 16.2873 - val_accuracy: 0.4720 - val_auc: 0.6980
# Epoch 44/100
# 14/14 [==============================] - 1s 100ms/step - loss: 16.2515 - accuracy: 0.5343 - auc: 0.6328 - val_loss: 16.2238 - val_accuracy: 0.4720 - val_auc: 0.6976
# Epoch 45/100
# 14/14 [==============================] - 1s 102ms/step - loss: 16.1906 - accuracy: 0.5332 - auc: 0.6326 - val_loss: 16.1605 - val_accuracy: 0.4728 - val_auc: 0.6976
# Epoch 46/100
# 14/14 [==============================] - 1s 100ms/step - loss: 16.1211 - accuracy: 0.5352 - auc: 0.6399 - val_loss: 16.0964 - val_accuracy: 0.4746 - val_auc: 0.6973
# Epoch 47/100
# 14/14 [==============================] - 1s 97ms/step - loss: 16.0579 - accuracy: 0.5401 - auc: 0.6427 - val_loss: 16.0320 - val_accuracy: 0.4775 - val_auc: 0.6977
# Epoch 48/100
# 14/14 [==============================] - 1s 96ms/step - loss: 15.9979 - accuracy: 0.5410 - auc: 0.6369 - val_loss: 15.9672 - val_accuracy: 0.4824 - val_auc: 0.6984
# Epoch 49/100
# 14/14 [==============================] - 1s 96ms/step - loss: 15.9279 - accuracy: 0.5435 - auc: 0.6414 - val_loss: 15.9051 - val_accuracy: 0.4818 - val_auc: 0.6979
# Epoch 50/100
# 14/14 [==============================] - 1s 101ms/step - loss: 15.8615 - accuracy: 0.5483 - auc: 0.6461 - val_loss: 15.8417 - val_accuracy: 0.4842 - val_auc: 0.6972
# Epoch 51/100
# 14/14 [==============================] - 1s 98ms/step - loss: 15.7978 - accuracy: 0.5453 - auc: 0.6466 - val_loss: 15.7801 - val_accuracy: 0.4818 - val_auc: 0.6973
# Epoch 52/100
# 14/14 [==============================] - 1s 101ms/step - loss: 15.7290 - accuracy: 0.5442 - auc: 0.6455 - val_loss: 15.7174 - val_accuracy: 0.4821 - val_auc: 0.6973
# Epoch 53/100
# 14/14 [==============================] - 1s 103ms/step - loss: 15.6633 - accuracy: 0.5519 - auc: 0.6552 - val_loss: 15.6542 - val_accuracy: 0.4842 - val_auc: 0.6973
# Epoch 54/100
# 14/14 [==============================] - 1s 102ms/step - loss: 15.6083 - accuracy: 0.5472 - auc: 0.6496 - val_loss: 15.5911 - val_accuracy: 0.4882 - val_auc: 0.6967
# Epoch 55/100
# 14/14 [==============================] - 1s 101ms/step - loss: 15.5394 - accuracy: 0.5518 - auc: 0.6566 - val_loss: 15.5284 - val_accuracy: 0.4888 - val_auc: 0.6976
# Epoch 56/100
# 14/14 [==============================] - 1s 102ms/step - loss: 15.4782 - accuracy: 0.5483 - auc: 0.6548 - val_loss: 15.4661 - val_accuracy: 0.4891 - val_auc: 0.6986
# Epoch 57/100
# 14/14 [==============================] - 1s 101ms/step - loss: 15.4129 - accuracy: 0.5538 - auc: 0.6576 - val_loss: 15.4041 - val_accuracy: 0.4914 - val_auc: 0.6985
# Epoch 58/100
# 14/14 [==============================] - 1s 101ms/step - loss: 15.3526 - accuracy: 0.5552 - auc: 0.6607 - val_loss: 15.3423 - val_accuracy: 0.4914 - val_auc: 0.6985
# Epoch 59/100
# 14/14 [==============================] - 1s 101ms/step - loss: 15.2947 - accuracy: 0.5528 - auc: 0.6588 - val_loss: 15.2807 - val_accuracy: 0.4917 - val_auc: 0.6985
# Epoch 60/100
# 14/14 [==============================] - 1s 102ms/step - loss: 15.2227 - accuracy: 0.5576 - auc: 0.6657 - val_loss: 15.2205 - val_accuracy: 0.4920 - val_auc: 0.7000
# Epoch 61/100
# 14/14 [==============================] - 1s 100ms/step - loss: 15.1613 - accuracy: 0.5632 - auc: 0.6676 - val_loss: 15.1599 - val_accuracy: 0.4917 - val_auc: 0.6998
# Epoch 62/100
# 14/14 [==============================] - 1s 98ms/step - loss: 15.0959 - accuracy: 0.5612 - auc: 0.6717 - val_loss: 15.0997 - val_accuracy: 0.4926 - val_auc: 0.6991
# Epoch 63/100
# 14/14 [==============================] - 1s 100ms/step - loss: 15.0495 - accuracy: 0.5599 - auc: 0.6631 - val_loss: 15.0389 - val_accuracy: 0.4935 - val_auc: 0.6997
# Epoch 64/100
# 14/14 [==============================] - 1s 102ms/step - loss: 14.9656 - accuracy: 0.5637 - auc: 0.6787 - val_loss: 14.9781 - val_accuracy: 0.4958 - val_auc: 0.6989
# Epoch 65/100
# 14/14 [==============================] - 1s 101ms/step - loss: 14.9158 - accuracy: 0.5593 - auc: 0.6717 - val_loss: 14.9168 - val_accuracy: 0.4975 - val_auc: 0.6990
# Epoch 66/100
# 14/14 [==============================] - 1s 98ms/step - loss: 14.8541 - accuracy: 0.5620 - auc: 0.6714 - val_loss: 14.8562 - val_accuracy: 0.4975 - val_auc: 0.6996
# Epoch 67/100
# 14/14 [==============================] - 1s 98ms/step - loss: 14.7955 - accuracy: 0.5675 - auc: 0.6758 - val_loss: 14.7968 - val_accuracy: 0.4961 - val_auc: 0.6984
# Epoch 68/100
# 14/14 [==============================] - 1s 99ms/step - loss: 14.7345 - accuracy: 0.5636 - auc: 0.6748 - val_loss: 14.7394 - val_accuracy: 0.4958 - val_auc: 0.6984
# Epoch 69/100
# 14/14 [==============================] - 1s 98ms/step - loss: 14.6759 - accuracy: 0.5648 - auc: 0.6769 - val_loss: 14.6824 - val_accuracy: 0.4949 - val_auc: 0.6979
# Epoch 70/100
# 14/14 [==============================] - 1s 102ms/step - loss: 14.6204 - accuracy: 0.5641 - auc: 0.6731 - val_loss: 14.6238 - val_accuracy: 0.4938 - val_auc: 0.6969
# Epoch 71/100
# 14/14 [==============================] - 1s 100ms/step - loss: 14.5579 - accuracy: 0.5702 - auc: 0.6781 - val_loss: 14.5647 - val_accuracy: 0.4929 - val_auc: 0.6973
# Epoch 72/100
# 14/14 [==============================] - 1s 101ms/step - loss: 14.4887 - accuracy: 0.5731 - auc: 0.6869 - val_loss: 14.5047 - val_accuracy: 0.4940 - val_auc: 0.6969
# Epoch 73/100
# 14/14 [==============================] - 1s 99ms/step - loss: 14.4302 - accuracy: 0.5750 - auc: 0.6871 - val_loss: 14.4473 - val_accuracy: 0.4935 - val_auc: 0.6959
# Epoch 74/100
# 14/14 [==============================] - 1s 101ms/step - loss: 14.3695 - accuracy: 0.5750 - auc: 0.6883 - val_loss: 14.3911 - val_accuracy: 0.4929 - val_auc: 0.6932
# Epoch 75/100
# 14/14 [==============================] - 1s 100ms/step - loss: 14.3090 - accuracy: 0.5836 - auc: 0.6953 - val_loss: 14.3336 - val_accuracy: 0.4938 - val_auc: 0.6938
# Epoch 76/100
# 14/14 [==============================] - 1s 102ms/step - loss: 14.2459 - accuracy: 0.5774 - auc: 0.6966 - val_loss: 14.2770 - val_accuracy: 0.4923 - val_auc: 0.6945
# Epoch 77/100
# 14/14 [==============================] - 1s 106ms/step - loss: 14.2039 - accuracy: 0.5697 - auc: 0.6839 - val_loss: 14.2170 - val_accuracy: 0.4929 - val_auc: 0.6945
# Epoch 78/100
# 14/14 [==============================] - 1s 105ms/step - loss: 14.1347 - accuracy: 0.5795 - auc: 0.6956 - val_loss: 14.1598 - val_accuracy: 0.4926 - val_auc: 0.6949
# Epoch 79/100
# 14/14 [==============================] - 1s 103ms/step - loss: 14.0782 - accuracy: 0.5791 - auc: 0.6932 - val_loss: 14.1029 - val_accuracy: 0.4938 - val_auc: 0.6951
# Epoch 80/100
# 14/14 [==============================] - 1s 101ms/step - loss: 14.0307 - accuracy: 0.5782 - auc: 0.6892 - val_loss: 14.0449 - val_accuracy: 0.4940 - val_auc: 0.6946
# Epoch 81/100
# 14/14 [==============================] - 1s 98ms/step - loss: 13.9660 - accuracy: 0.5870 - auc: 0.6944 - val_loss: 13.9878 - val_accuracy: 0.4961 - val_auc: 0.6943
# Epoch 82/100
# 14/14 [==============================] - 1s 100ms/step - loss: 13.8991 - accuracy: 0.5870 - auc: 0.7029 - val_loss: 13.9333 - val_accuracy: 0.4946 - val_auc: 0.6933
# Epoch 83/100
# 14/14 [==============================] - 1s 100ms/step - loss: 13.8478 - accuracy: 0.5873 - auc: 0.7025 - val_loss: 13.8803 - val_accuracy: 0.4935 - val_auc: 0.6933
# Epoch 84/100
# 14/14 [==============================] - 1s 98ms/step - loss: 13.7916 - accuracy: 0.5869 - auc: 0.6989 - val_loss: 13.8265 - val_accuracy: 0.4920 - val_auc: 0.6917
# Epoch 85/100
# 14/14 [==============================] - 1s 99ms/step - loss: 13.7308 - accuracy: 0.5846 - auc: 0.7055 - val_loss: 13.7708 - val_accuracy: 0.4920 - val_auc: 0.6912
# Epoch 86/100
# 14/14 [==============================] - 1s 96ms/step - loss: 13.6704 - accuracy: 0.5938 - auc: 0.7099 - val_loss: 13.7142 - val_accuracy: 0.4929 - val_auc: 0.6916
# Epoch 87/100
# 14/14 [==============================] - 1s 97ms/step - loss: 13.6176 - accuracy: 0.5875 - auc: 0.7046 - val_loss: 13.6602 - val_accuracy: 0.4908 - val_auc: 0.6916
# Epoch 88/100
# 14/14 [==============================] - 1s 97ms/step - loss: 13.5622 - accuracy: 0.5918 - auc: 0.7076 - val_loss: 13.6045 - val_accuracy: 0.4917 - val_auc: 0.6906
# Epoch 89/100
# 14/14 [==============================] - 1s 98ms/step - loss: 13.5050 - accuracy: 0.5950 - auc: 0.7120 - val_loss: 13.5474 - val_accuracy: 0.4967 - val_auc: 0.6912
# Epoch 90/100
# 14/14 [==============================] - 1s 98ms/step - loss: 13.4444 - accuracy: 0.5945 - auc: 0.7154 - val_loss: 13.4936 - val_accuracy: 0.4935 - val_auc: 0.6905
# Epoch 91/100
# 14/14 [==============================] - 1s 103ms/step - loss: 13.3869 - accuracy: 0.5956 - auc: 0.7163 - val_loss: 13.4386 - val_accuracy: 0.4987 - val_auc: 0.6901
# Epoch 92/100
# 14/14 [==============================] - 1s 97ms/step - loss: 13.3388 - accuracy: 0.5982 - auc: 0.7164 - val_loss: 13.3843 - val_accuracy: 0.5016 - val_auc: 0.6891
# Epoch 93/100
# 14/14 [==============================] - 1s 101ms/step - loss: 13.2794 - accuracy: 0.5971 - auc: 0.7198 - val_loss: 13.3319 - val_accuracy: 0.5010 - val_auc: 0.6892
# Epoch 94/100
# 14/14 [==============================] - 1s 98ms/step - loss: 13.2239 - accuracy: 0.5993 - auc: 0.7187 - val_loss: 13.2788 - val_accuracy: 0.4978 - val_auc: 0.6904
# Epoch 95/100
# 14/14 [==============================] - 1s 98ms/step - loss: 13.1730 - accuracy: 0.6027 - auc: 0.7195 - val_loss: 13.2215 - val_accuracy: 0.5062 - val_auc: 0.6913
# Epoch 96/100
# 14/14 [==============================] - 1s 99ms/step - loss: 13.1159 - accuracy: 0.6033 - auc: 0.7223 - val_loss: 13.1663 - val_accuracy: 0.5132 - val_auc: 0.6900
# Epoch 97/100
# 14/14 [==============================] - 1s 100ms/step - loss: 13.0536 - accuracy: 0.6048 - auc: 0.7280 - val_loss: 13.1163 - val_accuracy: 0.5086 - val_auc: 0.6911
# Epoch 98/100
# 14/14 [==============================] - 1s 100ms/step - loss: 13.0057 - accuracy: 0.5948 - auc: 0.7229 - val_loss: 13.0660 - val_accuracy: 0.5033 - val_auc: 0.6890
# Epoch 99/100
# 14/14 [==============================] - 1s 100ms/step - loss: 12.9520 - accuracy: 0.6087 - auc: 0.7242 - val_loss: 13.0115 - val_accuracy: 0.5103 - val_auc: 0.6874
# Epoch 100/100
# 14/14 [==============================] - 1s 99ms/step - loss: 12.8935 - accuracy: 0.6090 - auc: 0.7301 - val_loss: 12.9576 - val_accuracy: 0.5155 - val_auc: 0.6871
# 135/135 - 1s - loss: 13.0575 - accuracy: 0.5502 - auc: 0.6576 - 864ms/epoch - 6ms/step
# Model accuracy: [13.057502746582031, 0.5502436757087708, 0.6576249599456787]
# 538/538 [==============================] - 4s 6ms/step
# 135/135 [==============================] - 1s 6ms/step
# 135/135 [==============================] - 1s 6ms/step - loss: 13.0575 - accuracy: 0.5502 - auc: 0.6576
# Loss: 13.057502746582031
# Accuracy: 0.5502436757087708
# AUC: 0.6576249599456787
# Precision: 0.3600767754318618
# Recall: 0.7758478081058726
# Metrics:  ['loss', 'accuracy', 'auc']
# Results:  [13.057502746582031, 0.5502436757087708, 0.6576249599456787]
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.46      0.60      3100
#          1.0       0.36      0.78      0.49      1209
#
#     accuracy                           0.55      4309
#    macro avg       0.60      0.62      0.54      4309
# weighted avg       0.71      0.55      0.57      4309
# Ein Unterverzeichnis oder eine Datei mit dem Namen "-p" existiert bereits.
# Folgender Fehler trat auf: -p.
# Ein Unterverzeichnis oder eine Datei mit dem Namen "saved_model" existiert bereits.
# Folgender Fehler trat auf: saved_model.
# INFO:tensorflow:Assets written to: saved_model/my_RNN_model_60per5_fixing_overfit\assets
# INFO:tensorflow:Assets written to: saved_model/my_RNN_model_60per5_fixing_overfit\assets
