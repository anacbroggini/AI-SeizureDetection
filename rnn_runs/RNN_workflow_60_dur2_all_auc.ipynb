# %% [markdown]
# ## Pre-Processing

# %%
from source import data_import
from source.constants import CHANNELS, DEFAULT_PATIENTS
import numpy as np
import matplotlib.pyplot as plt

import os
import pandas as pd
# os.environ["MODIN_ENGINE"] = "ray"
# import modin.pandas as pd
# import ray
# ray.shutdown()
# ray.init()

from source.filter_eeg_channels import filter_eeg_channels
from source.calculate_mean_psd import calculate_mean_psd
from source.constants import CHANNELS, FREQUENCY_RANGES
from source.data_import import save_file, load_file 
                                            
from sklearn.preprocessing import StandardScaler, minmax_scale, MinMaxScaler

# %%
## PARAMETERS ##
SKIP_DATA = True
data_filename = "preprocessed_60_dur2_all.arrow" # data will be loaded/saved with this filename. Put None to skip saving the file

SKIP_FEATURES = True
feature_filename = 'features_60_dur2_all.npy' # data will be loaded/saved with this filename. Put None to skip saving the file

### DATA ###
# Load Patient Data #
patient_ids = None #DEFAULT_PATIENTS #DEFAULT_PATIENTS # use DEFAULT_PATIENTS for default patients selection
nr_segments=60
segment_duration=2
ictal_segmentation_foo=data_import.preictal_segmentation
interictal_segmentation_foo=data_import.inter_segmentation
channels=CHANNELS
seizure_offset=0

# filter #
exclude_ranges=[[58, 62], [118, 122]]

### FEATURES ###
target_colname = 'target'
PRED_INTERVAL = 6000 # how long should a segment count as preictal in seconds

window_size = 30 # Define the sequence_train window size

# %%
if not SKIP_DATA:
    # Load Patient Data
    p_df = data_import.load_segmented_data(patient_ids=patient_ids,
                                            nr_segments=nr_segments,
                                            segment_duration=segment_duration,
                                            ictal_segmentation_foo=data_import.preictal_segmentation,
                                            interictal_segmentation_foo=data_import.inter_segmentation,
                                            channels=channels,
                                            seizure_offset=seizure_offset
                                            )
    
    # Filter
    fit_df = filter_eeg_channels(p_df, CHANNELS, fs=256, exclude_ranges=exclude_ranges, Q=30)
    pd_toconcat = p_df[['epoch', 'segment_id']]
    fit_df = pd.concat(objs=[fit_df, pd_toconcat], axis =1)
    save_file(data=fit_df, file_name=data_filename)
    fit_df.head()
elif data_filename is not None:
    fit_df = load_file(data_filename)
    fit_df = pd.DataFrame(fit_df)
    fit_df.head()
# Out:
# D:\_c\spiced\ai-seizure-detectives\source\..\data\preprocessed_60_dur2_all.arrow was loaded.

# %% [markdown]
# ## Feature Extraction

# %%
### aggregate Functions for mean psd:
delta = lambda x: calculate_mean_psd(x, frequency_ranges={'Delta' : FREQUENCY_RANGES['Delta']})[x.name]['Delta']
theta = lambda x: calculate_mean_psd(x, frequency_ranges={'Theta' : FREQUENCY_RANGES['Theta']})[x.name]['Theta']
gamma = lambda x: calculate_mean_psd(x, frequency_ranges={'Gamma': FREQUENCY_RANGES['Gamma']})[x.name]['Gamma']

delta_agg = pd.NamedAgg(column='delta', aggfunc=delta)
theta_agg = pd.NamedAgg(column='theta', aggfunc=theta)
gamma_agg = pd.NamedAgg(column='gamma', aggfunc=gamma)

### aggregate mean features:
abs_mean = lambda x: x.apply(abs).mean()
abs_mean_agg = pd.NamedAgg(column='abs_mean', aggfunc=abs_mean)

### aggregate Functions for target:
target_foo = lambda x, pred_interval=PRED_INTERVAL: 0 < x.dt.total_seconds().min() < pred_interval

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

def preprocess_data(df, window_size):
    # Grouping and aggregating features
    df_features = df.groupby(['epoch', 'segment_id']).agg(
        {C: ['std', 'var', abs_mean_agg, delta_agg, theta_agg, gamma_agg] for C in CHANNELS} | 
        {target_colname: [target_foo]}
    )
    
    # Renaming columns
    df_features.columns = ['_'.join(col).strip() for col in df_features.columns.values if target_colname != col[0]] + [target_colname]
    df_features.reset_index(inplace=True)


    # Reshaping array
    original_array = np.array(df_features)
    epoch_column = original_array[:, 0]
    num_epochs = df_features.epoch.unique()[-1]
    num_segments = len(df_features.segment_id.unique())
    reshaped_array = np.empty((num_epochs, num_segments, original_array.shape[1]))

    for epoch in range(num_epochs):
        start_idx = epoch * num_segments
        end_idx = (epoch + 1) * num_segments
        reshaped_array[epoch, :, :] = original_array[start_idx:end_idx, :]

    # Creating sequence trains
    num_batches, num_sequences, num_features = reshaped_array.shape
    num_augmented_batches = num_sequences - window_size + 1

    data = np.zeros((num_batches * num_augmented_batches, window_size, num_features))

    for batch_idx in range(num_batches):
        for seq_idx in range(num_augmented_batches):
            data[batch_idx * num_augmented_batches + seq_idx, :, :] = reshaped_array[batch_idx, seq_idx:seq_idx + window_size, :]
        
    return data

# %%
if not SKIP_FEATURES:
    data = preprocess_data(fit_df, window_size=window_size)
    print(data.shape)
    save_file(data=data, file_name=feature_filename)
else:
    data = load_file(feature_filename)
# Out:
# loading npy

# %%
# %run model_rnn.ipynb
# Out:
# WARNING:tensorflow:From d:\_c\spiced\ai-seizure-detectives\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# data already loaded in parent notebook
# 552 of epochs for training, 138 of epochs for testing/validation
# train shape (17112, 30, 62) ratio of seizures 0.25
# test shape (4278, 30, 62), ratio of seizures 0.25
# train shape (17112, 30, 60)
# test shape (4278, 30, 60)
# WARNING:tensorflow:From d:\_c\spiced\ai-seizure-detectives\venv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 256)               324608
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense (Dense)               (None, 256)               65792
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  batch_normalization (Batch  (None, 256)               1024
#  Normalization)
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 391681 (1.49 MB)
# Trainable params: 391169 (1.49 MB)
# Non-trainable params: 512 (2.00 KB)
# _________________________________________________________________
# Epoch 1/200
# WARNING:tensorflow:From d:\_c\spiced\ai-seizure-detectives\venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From d:\_c\spiced\ai-seizure-detectives\venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 14/14 [==============================] - 3s 126ms/step - loss: 19.2628 - auc: 0.5039 - val_loss: 19.1123 - val_auc: 0.5220
# Epoch 2/200
#  1/14 [=>............................] - ETA: 1s - loss: 19.1890 - auc: 0.5226
# d:\_c\spiced\ai-seizure-detectives\venv\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 14/14 [==============================] - 1s 99ms/step - loss: 19.1782 - auc: 0.5133 - val_loss: 19.0369 - val_auc: 0.5226
# Epoch 3/200
# 14/14 [==============================] - 1s 99ms/step - loss: 19.0804 - auc: 0.5352 - val_loss: 18.9618 - val_auc: 0.5225
# Epoch 4/200
# 14/14 [==============================] - 1s 99ms/step - loss: 19.0152 - auc: 0.5268 - val_loss: 18.8869 - val_auc: 0.5240
# Epoch 5/200
# 14/14 [==============================] - 1s 97ms/step - loss: 18.9331 - auc: 0.5365 - val_loss: 18.8124 - val_auc: 0.5272
# Epoch 6/200
# 14/14 [==============================] - 1s 98ms/step - loss: 18.8588 - auc: 0.5365 - val_loss: 18.7382 - val_auc: 0.5306
# Epoch 7/200
# 14/14 [==============================] - 1s 97ms/step - loss: 18.7736 - auc: 0.5535 - val_loss: 18.6643 - val_auc: 0.5349
# Epoch 8/200
# 14/14 [==============================] - 1s 97ms/step - loss: 18.6999 - auc: 0.5508 - val_loss: 18.5910 - val_auc: 0.5412
# Epoch 9/200
# 14/14 [==============================] - 1s 100ms/step - loss: 18.6199 - auc: 0.5566 - val_loss: 18.5178 - val_auc: 0.5445
# Epoch 10/200
# 14/14 [==============================] - 1s 98ms/step - loss: 18.5511 - auc: 0.5532 - val_loss: 18.4445 - val_auc: 0.5497
# Epoch 11/200
# 14/14 [==============================] - 1s 97ms/step - loss: 18.4765 - auc: 0.5590 - val_loss: 18.3717 - val_auc: 0.5547
# Epoch 12/200
# 14/14 [==============================] - 1s 99ms/step - loss: 18.3965 - auc: 0.5645 - val_loss: 18.2989 - val_auc: 0.5587
# Epoch 13/200
# 14/14 [==============================] - 1s 98ms/step - loss: 18.3237 - auc: 0.5662 - val_loss: 18.2261 - val_auc: 0.5604
# Epoch 14/200
# 14/14 [==============================] - 1s 99ms/step - loss: 18.2542 - auc: 0.5619 - val_loss: 18.1538 - val_auc: 0.5618
# Epoch 15/200
# 14/14 [==============================] - 1s 96ms/step - loss: 18.1783 - auc: 0.5739 - val_loss: 18.0814 - val_auc: 0.5639
# Epoch 16/200
# 14/14 [==============================] - 1s 99ms/step - loss: 18.1100 - auc: 0.5682 - val_loss: 18.0096 - val_auc: 0.5657
# Epoch 17/200
# 14/14 [==============================] - 1s 98ms/step - loss: 18.0266 - auc: 0.5836 - val_loss: 17.9380 - val_auc: 0.5671
# Epoch 18/200
# 14/14 [==============================] - 1s 100ms/step - loss: 17.9577 - auc: 0.5818 - val_loss: 17.8668 - val_auc: 0.5675
# Epoch 19/200
# 14/14 [==============================] - 1s 97ms/step - loss: 17.8838 - auc: 0.5827 - val_loss: 17.7961 - val_auc: 0.5686
# Epoch 20/200
# 14/14 [==============================] - 1s 98ms/step - loss: 17.8132 - auc: 0.5829 - val_loss: 17.7255 - val_auc: 0.5691
# Epoch 21/200
# 14/14 [==============================] - 1s 97ms/step - loss: 17.7393 - auc: 0.5935 - val_loss: 17.6554 - val_auc: 0.5697
# Epoch 22/200
# 14/14 [==============================] - 1s 97ms/step - loss: 17.6575 - auc: 0.5970 - val_loss: 17.5854 - val_auc: 0.5685
# Epoch 23/200
# 14/14 [==============================] - 1s 97ms/step - loss: 17.5910 - auc: 0.6009 - val_loss: 17.5156 - val_auc: 0.5686
# Epoch 24/200
# 14/14 [==============================] - 1s 97ms/step - loss: 17.5187 - auc: 0.6063 - val_loss: 17.4465 - val_auc: 0.5687
# Epoch 25/200
# 14/14 [==============================] - 1s 97ms/step - loss: 17.4524 - auc: 0.6056 - val_loss: 17.3791 - val_auc: 0.5699
# Epoch 26/200
# 14/14 [==============================] - 1s 97ms/step - loss: 17.3799 - auc: 0.6069 - val_loss: 17.3096 - val_auc: 0.5690
# Epoch 27/200
# 14/14 [==============================] - 1s 97ms/step - loss: 17.3123 - auc: 0.6071 - val_loss: 17.2402 - val_auc: 0.5687
# Epoch 28/200
# 14/14 [==============================] - 1s 98ms/step - loss: 17.2379 - auc: 0.6183 - val_loss: 17.1720 - val_auc: 0.5691
# Epoch 29/200
# 14/14 [==============================] - 1s 97ms/step - loss: 17.1665 - auc: 0.6197 - val_loss: 17.1048 - val_auc: 0.5696
# Epoch 30/200
# 14/14 [==============================] - 1s 96ms/step - loss: 17.0943 - auc: 0.6201 - val_loss: 17.0374 - val_auc: 0.5705
# Epoch 31/200
# 14/14 [==============================] - 1s 96ms/step - loss: 17.0287 - auc: 0.6229 - val_loss: 16.9703 - val_auc: 0.5708
# Epoch 32/200
# 14/14 [==============================] - 1s 98ms/step - loss: 16.9629 - auc: 0.6201 - val_loss: 16.9035 - val_auc: 0.5707
# Epoch 33/200
# 14/14 [==============================] - 1s 96ms/step - loss: 16.8841 - auc: 0.6334 - val_loss: 16.8367 - val_auc: 0.5706
# Epoch 34/200
# 14/14 [==============================] - 1s 96ms/step - loss: 16.8176 - auc: 0.6339 - val_loss: 16.7706 - val_auc: 0.5712
# Epoch 35/200
# 14/14 [==============================] - 1s 97ms/step - loss: 16.7484 - auc: 0.6390 - val_loss: 16.7042 - val_auc: 0.5722
# Epoch 36/200
# 14/14 [==============================] - 1s 96ms/step - loss: 16.6851 - auc: 0.6356 - val_loss: 16.6391 - val_auc: 0.5719
# Epoch 37/200
# 14/14 [==============================] - 1s 97ms/step - loss: 16.6168 - auc: 0.6365 - val_loss: 16.5731 - val_auc: 0.5711
# Epoch 38/200
# 14/14 [==============================] - 1s 96ms/step - loss: 16.5546 - auc: 0.6380 - val_loss: 16.5090 - val_auc: 0.5707
# Epoch 39/200
# 14/14 [==============================] - 1s 96ms/step - loss: 16.4864 - auc: 0.6424 - val_loss: 16.4427 - val_auc: 0.5704
# Epoch 40/200
# 14/14 [==============================] - 1s 96ms/step - loss: 16.4248 - auc: 0.6401 - val_loss: 16.3781 - val_auc: 0.5695
# Epoch 41/200
# 14/14 [==============================] - 1s 96ms/step - loss: 16.3507 - auc: 0.6462 - val_loss: 16.3145 - val_auc: 0.5697
# Epoch 42/200
# 14/14 [==============================] - 1s 97ms/step - loss: 16.2734 - auc: 0.6592 - val_loss: 16.2501 - val_auc: 0.5699
# Epoch 43/200
# 14/14 [==============================] - 1s 96ms/step - loss: 16.2049 - auc: 0.6631 - val_loss: 16.1868 - val_auc: 0.5701
# Epoch 44/200
# 14/14 [==============================] - 1s 96ms/step - loss: 16.1426 - auc: 0.6615 - val_loss: 16.1233 - val_auc: 0.5702
# Epoch 45/200
# 14/14 [==============================] - 1s 97ms/step - loss: 16.0724 - auc: 0.6677 - val_loss: 16.0604 - val_auc: 0.5694
# Epoch 46/200
# 14/14 [==============================] - 1s 96ms/step - loss: 16.0130 - auc: 0.6634 - val_loss: 15.9960 - val_auc: 0.5699
# Epoch 47/200
# 14/14 [==============================] - 1s 97ms/step - loss: 15.9514 - auc: 0.6678 - val_loss: 15.9340 - val_auc: 0.5698
# Epoch 48/200
# 14/14 [==============================] - 1s 96ms/step - loss: 15.8861 - auc: 0.6632 - val_loss: 15.8722 - val_auc: 0.5695
# Epoch 49/200
# 14/14 [==============================] - 1s 97ms/step - loss: 15.8066 - auc: 0.6768 - val_loss: 15.8095 - val_auc: 0.5694
# Epoch 50/200
# 14/14 [==============================] - 1s 97ms/step - loss: 15.7421 - auc: 0.6782 - val_loss: 15.7480 - val_auc: 0.5694
# Epoch 51/200
# 14/14 [==============================] - 1s 97ms/step - loss: 15.6795 - auc: 0.6815 - val_loss: 15.6848 - val_auc: 0.5689
# Epoch 52/200
# 14/14 [==============================] - 1s 96ms/step - loss: 15.6182 - auc: 0.6804 - val_loss: 15.6208 - val_auc: 0.5686
# Epoch 53/200
# 14/14 [==============================] - 1s 96ms/step - loss: 15.5587 - auc: 0.6831 - val_loss: 15.5582 - val_auc: 0.5680
# Epoch 54/200
# 14/14 [==============================] - 1s 97ms/step - loss: 15.4923 - auc: 0.6863 - val_loss: 15.4964 - val_auc: 0.5678
# Epoch 55/200
# 14/14 [==============================] - 1s 96ms/step - loss: 15.4360 - auc: 0.6818 - val_loss: 15.4354 - val_auc: 0.5669
# Epoch 56/200
# 14/14 [==============================] - 1s 95ms/step - loss: 15.3615 - auc: 0.6937 - val_loss: 15.3752 - val_auc: 0.5676
# Epoch 57/200
# 14/14 [==============================] - 1s 96ms/step - loss: 15.3056 - auc: 0.6894 - val_loss: 15.3144 - val_auc: 0.5672
# Epoch 58/200
# 14/14 [==============================] - 1s 97ms/step - loss: 15.2378 - auc: 0.6995 - val_loss: 15.2538 - val_auc: 0.5667
# Epoch 59/200
# 14/14 [==============================] - 1s 96ms/step - loss: 15.1767 - auc: 0.6979 - val_loss: 15.1956 - val_auc: 0.5670
# Epoch 60/200
# 14/14 [==============================] - 1s 95ms/step - loss: 15.1169 - auc: 0.6979 - val_loss: 15.1369 - val_auc: 0.5663
# Epoch 61/200
# 14/14 [==============================] - 1s 96ms/step - loss: 15.0556 - auc: 0.6973 - val_loss: 15.0764 - val_auc: 0.5654
# Epoch 62/200
# 14/14 [==============================] - 1s 97ms/step - loss: 14.9926 - auc: 0.7021 - val_loss: 15.0172 - val_auc: 0.5648
# Epoch 63/200
# 14/14 [==============================] - 1s 97ms/step - loss: 14.9257 - auc: 0.7085 - val_loss: 14.9574 - val_auc: 0.5650
# Epoch 64/200
# 14/14 [==============================] - 1s 96ms/step - loss: 14.8651 - auc: 0.7081 - val_loss: 14.8984 - val_auc: 0.5648
# Epoch 65/200
# 14/14 [==============================] - 1s 96ms/step - loss: 14.8000 - auc: 0.7173 - val_loss: 14.8388 - val_auc: 0.5644
# Epoch 66/200
# 14/14 [==============================] - 1s 97ms/step - loss: 14.7395 - auc: 0.7148 - val_loss: 14.7805 - val_auc: 0.5641
# Epoch 67/200
# 14/14 [==============================] - 1s 96ms/step - loss: 14.6770 - auc: 0.7177 - val_loss: 14.7231 - val_auc: 0.5652
# Epoch 68/200
# 14/14 [==============================] - 1s 96ms/step - loss: 14.6159 - auc: 0.7173 - val_loss: 14.6635 - val_auc: 0.5642
# Epoch 69/200
# 14/14 [==============================] - 1s 96ms/step - loss: 14.5617 - auc: 0.7183 - val_loss: 14.6067 - val_auc: 0.5638
# Epoch 70/200
# 14/14 [==============================] - 1s 97ms/step - loss: 14.5025 - auc: 0.7214 - val_loss: 14.5483 - val_auc: 0.5642
# Epoch 71/200
# 14/14 [==============================] - 1s 97ms/step - loss: 14.4478 - auc: 0.7164 - val_loss: 14.4921 - val_auc: 0.5646
# Epoch 72/200
# 14/14 [==============================] - 1s 97ms/step - loss: 14.3783 - auc: 0.7294 - val_loss: 14.4327 - val_auc: 0.5651
# Epoch 73/200
# 14/14 [==============================] - 1s 104ms/step - loss: 14.3161 - auc: 0.7329 - val_loss: 14.3755 - val_auc: 0.5654
# Epoch 74/200
# 14/14 [==============================] - 1s 98ms/step - loss: 14.2514 - auc: 0.7366 - val_loss: 14.3185 - val_auc: 0.5644
# Epoch 75/200
# 14/14 [==============================] - 1s 97ms/step - loss: 14.1951 - auc: 0.7347 - val_loss: 14.2610 - val_auc: 0.5633
# Epoch 76/200
# 14/14 [==============================] - 1s 97ms/step - loss: 14.1388 - auc: 0.7348 - val_loss: 14.2051 - val_auc: 0.5636
# Epoch 77/200
# 14/14 [==============================] - 1s 97ms/step - loss: 14.0799 - auc: 0.7388 - val_loss: 14.1471 - val_auc: 0.5629
# Epoch 78/200
# 14/14 [==============================] - 1s 98ms/step - loss: 14.0200 - auc: 0.7394 - val_loss: 14.0895 - val_auc: 0.5609
# Epoch 79/200
# 14/14 [==============================] - 1s 98ms/step - loss: 13.9605 - auc: 0.7461 - val_loss: 14.0346 - val_auc: 0.5620
# Epoch 80/200
# 14/14 [==============================] - 1s 103ms/step - loss: 13.9002 - auc: 0.7471 - val_loss: 13.9771 - val_auc: 0.5635
# Epoch 81/200
# 14/14 [==============================] - 1s 101ms/step - loss: 13.8437 - auc: 0.7461 - val_loss: 13.9205 - val_auc: 0.5634
# Epoch 82/200
# 14/14 [==============================] - 1s 98ms/step - loss: 13.7879 - auc: 0.7487 - val_loss: 13.8653 - val_auc: 0.5635
# Epoch 83/200
# 14/14 [==============================] - 1s 96ms/step - loss: 13.7229 - auc: 0.7582 - val_loss: 13.8099 - val_auc: 0.5634
# Epoch 84/200
# 14/14 [==============================] - 1s 98ms/step - loss: 13.6631 - auc: 0.7617 - val_loss: 13.7555 - val_auc: 0.5630
# Epoch 85/200
# 14/14 [==============================] - 1s 97ms/step - loss: 13.6077 - auc: 0.7621 - val_loss: 13.6971 - val_auc: 0.5653
# Epoch 86/200
# 14/14 [==============================] - 1s 96ms/step - loss: 13.5500 - auc: 0.7624 - val_loss: 13.6397 - val_auc: 0.5660
# Epoch 87/200
# 14/14 [==============================] - 1s 96ms/step - loss: 13.4888 - auc: 0.7698 - val_loss: 13.5853 - val_auc: 0.5676
# Epoch 88/200
# 14/14 [==============================] - 1s 96ms/step - loss: 13.4405 - auc: 0.7638 - val_loss: 13.5286 - val_auc: 0.5662
# Epoch 89/200
# 14/14 [==============================] - 1s 96ms/step - loss: 13.3837 - auc: 0.7680 - val_loss: 13.4754 - val_auc: 0.5688
# Epoch 90/200
# 14/14 [==============================] - 1s 95ms/step - loss: 13.3203 - auc: 0.7728 - val_loss: 13.4196 - val_auc: 0.5698
# Epoch 91/200
# 14/14 [==============================] - 1s 96ms/step - loss: 13.2720 - auc: 0.7682 - val_loss: 13.3632 - val_auc: 0.5690
# Epoch 92/200
# 14/14 [==============================] - 1s 96ms/step - loss: 13.2091 - auc: 0.7751 - val_loss: 13.3083 - val_auc: 0.5690
# Epoch 93/200
# 14/14 [==============================] - 1s 96ms/step - loss: 13.1604 - auc: 0.7748 - val_loss: 13.2525 - val_auc: 0.5710
# Epoch 94/200
# 14/14 [==============================] - 1s 96ms/step - loss: 13.0920 - auc: 0.7825 - val_loss: 13.1980 - val_auc: 0.5716
# Epoch 95/200
# 14/14 [==============================] - 1s 96ms/step - loss: 13.0428 - auc: 0.7819 - val_loss: 13.1452 - val_auc: 0.5723
# Epoch 96/200
# 14/14 [==============================] - 1s 96ms/step - loss: 12.9847 - auc: 0.7849 - val_loss: 13.0948 - val_auc: 0.5724
# Epoch 97/200
# 14/14 [==============================] - 1s 97ms/step - loss: 12.9337 - auc: 0.7852 - val_loss: 13.0374 - val_auc: 0.5744
# Epoch 98/200
# 14/14 [==============================] - 1s 95ms/step - loss: 12.8721 - auc: 0.7914 - val_loss: 12.9835 - val_auc: 0.5751
# Epoch 99/200
# 14/14 [==============================] - 1s 95ms/step - loss: 12.8179 - auc: 0.7926 - val_loss: 12.9279 - val_auc: 0.5766
# Epoch 100/200
# 14/14 [==============================] - 1s 95ms/step - loss: 12.7652 - auc: 0.7938 - val_loss: 12.8780 - val_auc: 0.5765
# Epoch 101/200
# 14/14 [==============================] - 1s 96ms/step - loss: 12.7139 - auc: 0.7922 - val_loss: 12.8251 - val_auc: 0.5796
# Epoch 102/200
# 14/14 [==============================] - 1s 95ms/step - loss: 12.6537 - auc: 0.7991 - val_loss: 12.7709 - val_auc: 0.5795
# Epoch 103/200
# 14/14 [==============================] - 1s 95ms/step - loss: 12.6033 - auc: 0.7981 - val_loss: 12.7172 - val_auc: 0.5817
# Epoch 104/200
# 14/14 [==============================] - 1s 96ms/step - loss: 12.5503 - auc: 0.8002 - val_loss: 12.6693 - val_auc: 0.5841
# Epoch 105/200
# 14/14 [==============================] - 1s 96ms/step - loss: 12.4897 - auc: 0.8041 - val_loss: 12.6155 - val_auc: 0.5833
# Epoch 106/200
# 14/14 [==============================] - 1s 96ms/step - loss: 12.4408 - auc: 0.8048 - val_loss: 12.5621 - val_auc: 0.5851
# Epoch 107/200
# 14/14 [==============================] - 1s 95ms/step - loss: 12.3852 - auc: 0.8092 - val_loss: 12.5116 - val_auc: 0.5859
# Epoch 108/200
# 14/14 [==============================] - 1s 96ms/step - loss: 12.3271 - auc: 0.8140 - val_loss: 12.4600 - val_auc: 0.5873
# Epoch 109/200
# 14/14 [==============================] - 1s 96ms/step - loss: 12.2740 - auc: 0.8166 - val_loss: 12.4095 - val_auc: 0.5894
# Epoch 110/200
# 14/14 [==============================] - 1s 97ms/step - loss: 12.2203 - auc: 0.8194 - val_loss: 12.3554 - val_auc: 0.5920
# Epoch 111/200
# 14/14 [==============================] - 1s 96ms/step - loss: 12.1696 - auc: 0.8190 - val_loss: 12.3055 - val_auc: 0.5930
# Epoch 112/200
# 14/14 [==============================] - 1s 96ms/step - loss: 12.1199 - auc: 0.8188 - val_loss: 12.2544 - val_auc: 0.5925
# Epoch 113/200
# 14/14 [==============================] - 1s 96ms/step - loss: 12.0616 - auc: 0.8233 - val_loss: 12.2011 - val_auc: 0.5984
# Epoch 114/200
# 14/14 [==============================] - 1s 96ms/step - loss: 12.0132 - auc: 0.8245 - val_loss: 12.1523 - val_auc: 0.5984
# Epoch 115/200
# 14/14 [==============================] - 1s 96ms/step - loss: 11.9596 - auc: 0.8249 - val_loss: 12.1054 - val_auc: 0.5996
# Epoch 116/200
# 14/14 [==============================] - 1s 97ms/step - loss: 11.9076 - auc: 0.8277 - val_loss: 12.0589 - val_auc: 0.5993
# Epoch 117/200
# 14/14 [==============================] - 1s 96ms/step - loss: 11.8591 - auc: 0.8274 - val_loss: 12.0112 - val_auc: 0.6012
# Epoch 118/200
# 14/14 [==============================] - 1s 96ms/step - loss: 11.8045 - auc: 0.8309 - val_loss: 11.9626 - val_auc: 0.6018
# Epoch 119/200
# 14/14 [==============================] - 1s 95ms/step - loss: 11.7457 - auc: 0.8389 - val_loss: 11.9180 - val_auc: 0.6001
# Epoch 120/200
# 14/14 [==============================] - 1s 96ms/step - loss: 11.7036 - auc: 0.8341 - val_loss: 11.8717 - val_auc: 0.6032
# Epoch 121/200
# 14/14 [==============================] - 1s 97ms/step - loss: 11.6532 - auc: 0.8347 - val_loss: 11.8238 - val_auc: 0.6027
# Epoch 122/200
# 14/14 [==============================] - 1s 95ms/step - loss: 11.6047 - auc: 0.8348 - val_loss: 11.7782 - val_auc: 0.6028
# Epoch 123/200
# 14/14 [==============================] - 1s 96ms/step - loss: 11.5426 - auc: 0.8435 - val_loss: 11.7331 - val_auc: 0.6041
# Epoch 124/200
# 14/14 [==============================] - 1s 96ms/step - loss: 11.4922 - auc: 0.8459 - val_loss: 11.6890 - val_auc: 0.6026
# Epoch 125/200
# 14/14 [==============================] - 1s 97ms/step - loss: 11.4484 - auc: 0.8429 - val_loss: 11.6372 - val_auc: 0.6074
# Epoch 126/200
# 14/14 [==============================] - 1s 96ms/step - loss: 11.3963 - auc: 0.8461 - val_loss: 11.5962 - val_auc: 0.6049
# Epoch 127/200
# 14/14 [==============================] - 1s 96ms/step - loss: 11.3454 - auc: 0.8482 - val_loss: 11.5542 - val_auc: 0.6035
# Epoch 128/200
# 14/14 [==============================] - 1s 96ms/step - loss: 11.2944 - auc: 0.8518 - val_loss: 11.5103 - val_auc: 0.6033
# Epoch 129/200
# 14/14 [==============================] - 1s 97ms/step - loss: 11.2522 - auc: 0.8479 - val_loss: 11.4629 - val_auc: 0.6033
# Epoch 130/200
# 14/14 [==============================] - 1s 95ms/step - loss: 11.1976 - auc: 0.8518 - val_loss: 11.4116 - val_auc: 0.6081
# Epoch 131/200
# 14/14 [==============================] - 1s 96ms/step - loss: 11.1503 - auc: 0.8540 - val_loss: 11.3722 - val_auc: 0.6034
# Epoch 132/200
# 14/14 [==============================] - 1s 97ms/step - loss: 11.1011 - auc: 0.8529 - val_loss: 11.3325 - val_auc: 0.6038
# Epoch 133/200
# 14/14 [==============================] - 1s 97ms/step - loss: 11.0515 - auc: 0.8560 - val_loss: 11.2855 - val_auc: 0.6042
# Epoch 134/200
# 14/14 [==============================] - 1s 95ms/step - loss: 11.0067 - auc: 0.8556 - val_loss: 11.2401 - val_auc: 0.6029
# Epoch 135/200
# 14/14 [==============================] - 1s 96ms/step - loss: 10.9535 - auc: 0.8611 - val_loss: 11.2018 - val_auc: 0.6034
# Epoch 136/200
# 14/14 [==============================] - 1s 97ms/step - loss: 10.9105 - auc: 0.8580 - val_loss: 11.1616 - val_auc: 0.6023
# Epoch 137/200
# 14/14 [==============================] - 1s 97ms/step - loss: 10.8593 - auc: 0.8615 - val_loss: 11.1159 - val_auc: 0.6029
# Epoch 138/200
# 14/14 [==============================] - 1s 96ms/step - loss: 10.8129 - auc: 0.8621 - val_loss: 11.0816 - val_auc: 0.6007
# Epoch 139/200
# 14/14 [==============================] - 1s 96ms/step - loss: 10.7610 - auc: 0.8664 - val_loss: 11.0323 - val_auc: 0.6017
# Epoch 140/200
# 14/14 [==============================] - 1s 97ms/step - loss: 10.7174 - auc: 0.8654 - val_loss: 10.9931 - val_auc: 0.6004
# Epoch 141/200
# 14/14 [==============================] - 1s 97ms/step - loss: 10.6653 - auc: 0.8691 - val_loss: 10.9513 - val_auc: 0.5993
# Epoch 142/200
# 14/14 [==============================] - 1s 97ms/step - loss: 10.6196 - auc: 0.8701 - val_loss: 10.9086 - val_auc: 0.5998
# Epoch 143/200
# 14/14 [==============================] - 1s 97ms/step - loss: 10.5728 - auc: 0.8700 - val_loss: 10.8731 - val_auc: 0.5986
# Epoch 144/200
# 14/14 [==============================] - 1s 96ms/step - loss: 10.5305 - auc: 0.8701 - val_loss: 10.8316 - val_auc: 0.6006
# Epoch 145/200
# 14/14 [==============================] - 1s 96ms/step - loss: 10.4813 - auc: 0.8736 - val_loss: 10.7952 - val_auc: 0.5980
# Epoch 146/200
# 14/14 [==============================] - 1s 97ms/step - loss: 10.4320 - auc: 0.8757 - val_loss: 10.7550 - val_auc: 0.5973
# Epoch 147/200
# 14/14 [==============================] - 1s 95ms/step - loss: 10.3932 - auc: 0.8734 - val_loss: 10.7192 - val_auc: 0.5979
# Epoch 148/200
# 14/14 [==============================] - 1s 97ms/step - loss: 10.3474 - auc: 0.8734 - val_loss: 10.6832 - val_auc: 0.5963
# Epoch 149/200
# 14/14 [==============================] - 1s 96ms/step - loss: 10.2942 - auc: 0.8814 - val_loss: 10.6317 - val_auc: 0.5972
# Epoch 150/200
# 14/14 [==============================] - 1s 97ms/step - loss: 10.2517 - auc: 0.8780 - val_loss: 10.5895 - val_auc: 0.5997
# Epoch 151/200
# 14/14 [==============================] - 1s 97ms/step - loss: 10.2045 - auc: 0.8815 - val_loss: 10.5526 - val_auc: 0.5969
# Epoch 152/200
# 14/14 [==============================] - 1s 96ms/step - loss: 10.1622 - auc: 0.8810 - val_loss: 10.5089 - val_auc: 0.5985
# Epoch 153/200
# 14/14 [==============================] - 1s 96ms/step - loss: 10.1102 - auc: 0.8863 - val_loss: 10.4776 - val_auc: 0.5967
# Epoch 154/200
# 14/14 [==============================] - 1s 97ms/step - loss: 10.0645 - auc: 0.8861 - val_loss: 10.4535 - val_auc: 0.5950
# Epoch 155/200
# 14/14 [==============================] - 1s 97ms/step - loss: 10.0267 - auc: 0.8847 - val_loss: 10.4149 - val_auc: 0.5937
# Epoch 156/200
# 14/14 [==============================] - 1s 97ms/step - loss: 9.9754 - auc: 0.8901 - val_loss: 10.3736 - val_auc: 0.5939
# Epoch 157/200
# 14/14 [==============================] - 1s 96ms/step - loss: 9.9362 - auc: 0.8872 - val_loss: 10.3300 - val_auc: 0.5940
# Epoch 158/200
# 14/14 [==============================] - 1s 96ms/step - loss: 9.8923 - auc: 0.8887 - val_loss: 10.3080 - val_auc: 0.5915
# Epoch 159/200
# 14/14 [==============================] - 1s 97ms/step - loss: 9.8459 - auc: 0.8914 - val_loss: 10.2573 - val_auc: 0.5929
# Epoch 160/200
# 14/14 [==============================] - 1s 96ms/step - loss: 9.8044 - auc: 0.8911 - val_loss: 10.2275 - val_auc: 0.5918
# Epoch 161/200
# 14/14 [==============================] - 1s 96ms/step - loss: 9.7587 - auc: 0.8936 - val_loss: 10.1884 - val_auc: 0.5896
# Epoch 162/200
# 14/14 [==============================] - 1s 96ms/step - loss: 9.7150 - auc: 0.8948 - val_loss: 10.1506 - val_auc: 0.5913
# Epoch 163/200
# 14/14 [==============================] - 1s 96ms/step - loss: 9.6744 - auc: 0.8941 - val_loss: 10.1116 - val_auc: 0.5908
# Epoch 164/200
# 14/14 [==============================] - 1s 96ms/step - loss: 9.6287 - auc: 0.8968 - val_loss: 10.0795 - val_auc: 0.5897
# Epoch 165/200
# 14/14 [==============================] - 1s 96ms/step - loss: 9.5849 - auc: 0.8983 - val_loss: 10.0423 - val_auc: 0.5887
# Epoch 166/200
# 14/14 [==============================] - 1s 96ms/step - loss: 9.5444 - auc: 0.8986 - val_loss: 10.0171 - val_auc: 0.5894
# Epoch 167/200
# 14/14 [==============================] - 1s 96ms/step - loss: 9.5018 - auc: 0.9000 - val_loss: 9.9893 - val_auc: 0.5888
# Epoch 168/200
# 14/14 [==============================] - 1s 96ms/step - loss: 9.4592 - auc: 0.9014 - val_loss: 9.9418 - val_auc: 0.5872
# Epoch 169/200
# 14/14 [==============================] - 1s 96ms/step - loss: 9.4179 - auc: 0.9011 - val_loss: 9.9132 - val_auc: 0.5878
# Epoch 170/200
# 14/14 [==============================] - 1s 96ms/step - loss: 9.3744 - auc: 0.9035 - val_loss: 9.8775 - val_auc: 0.5845
# Epoch 171/200
# 14/14 [==============================] - 1s 96ms/step - loss: 9.3341 - auc: 0.9038 - val_loss: 9.8393 - val_auc: 0.5850
# Epoch 172/200
# 14/14 [==============================] - 1s 96ms/step - loss: 9.2943 - auc: 0.9037 - val_loss: 9.8122 - val_auc: 0.5862
# Epoch 173/200
# 14/14 [==============================] - 1s 98ms/step - loss: 9.2499 - auc: 0.9066 - val_loss: 9.7663 - val_auc: 0.5873
# Epoch 174/200
# 14/14 [==============================] - 1s 101ms/step - loss: 9.2055 - auc: 0.9092 - val_loss: 9.7233 - val_auc: 0.5823
# Epoch 175/200
# 14/14 [==============================] - 1s 96ms/step - loss: 9.1670 - auc: 0.9080 - val_loss: 9.6876 - val_auc: 0.5829
# Epoch 176/200
# 14/14 [==============================] - 1s 96ms/step - loss: 9.1250 - auc: 0.9096 - val_loss: 9.6515 - val_auc: 0.5831
# Epoch 177/200
# 14/14 [==============================] - 1s 97ms/step - loss: 9.0864 - auc: 0.9096 - val_loss: 9.6366 - val_auc: 0.5822
# Epoch 178/200
# 14/14 [==============================] - 1s 99ms/step - loss: 9.0415 - auc: 0.9126 - val_loss: 9.5943 - val_auc: 0.5853
# Epoch 179/200
# 14/14 [==============================] - 1s 102ms/step - loss: 9.0071 - auc: 0.9112 - val_loss: 9.5552 - val_auc: 0.5831
# Epoch 180/200
# 14/14 [==============================] - 1s 97ms/step - loss: 8.9670 - auc: 0.9115 - val_loss: 9.5231 - val_auc: 0.5849
# Epoch 181/200
# 14/14 [==============================] - 2s 121ms/step - loss: 8.9248 - auc: 0.9128 - val_loss: 9.4828 - val_auc: 0.5852
# Epoch 182/200
# 14/14 [==============================] - 2s 163ms/step - loss: 8.8785 - auc: 0.9177 - val_loss: 9.4574 - val_auc: 0.5803
# Epoch 183/200
# 14/14 [==============================] - 2s 161ms/step - loss: 8.8451 - auc: 0.9145 - val_loss: 9.4204 - val_auc: 0.5825
# Epoch 184/200
# 14/14 [==============================] - 2s 161ms/step - loss: 8.8103 - auc: 0.9124 - val_loss: 9.3702 - val_auc: 0.5848
# Epoch 185/200
# 14/14 [==============================] - 2s 163ms/step - loss: 8.7662 - auc: 0.9162 - val_loss: 9.3504 - val_auc: 0.5823
# Epoch 186/200
# 14/14 [==============================] - 2s 162ms/step - loss: 8.7277 - auc: 0.9171 - val_loss: 9.3214 - val_auc: 0.5820
# Epoch 187/200
# 14/14 [==============================] - 2s 166ms/step - loss: 8.6928 - auc: 0.9151 - val_loss: 9.2971 - val_auc: 0.5806
# Epoch 188/200
# 14/14 [==============================] - 2s 163ms/step - loss: 8.6478 - auc: 0.9190 - val_loss: 9.2557 - val_auc: 0.5802
# Epoch 189/200
# 14/14 [==============================] - 2s 164ms/step - loss: 8.6113 - auc: 0.9182 - val_loss: 9.2224 - val_auc: 0.5802
# Epoch 190/200
# 14/14 [==============================] - 2s 162ms/step - loss: 8.5722 - auc: 0.9200 - val_loss: 9.1825 - val_auc: 0.5844
# Epoch 191/200
# 14/14 [==============================] - 2s 162ms/step - loss: 8.5349 - auc: 0.9191 - val_loss: 9.1609 - val_auc: 0.5800
# Epoch 192/200
# 14/14 [==============================] - 2s 161ms/step - loss: 8.4919 - auc: 0.9225 - val_loss: 9.1244 - val_auc: 0.5780
# Epoch 193/200
# 14/14 [==============================] - 2s 164ms/step - loss: 8.4572 - auc: 0.9219 - val_loss: 9.0890 - val_auc: 0.5807
# Epoch 194/200
# 14/14 [==============================] - 2s 163ms/step - loss: 8.4168 - auc: 0.9236 - val_loss: 9.0490 - val_auc: 0.5826
# Epoch 195/200
# 14/14 [==============================] - 2s 160ms/step - loss: 8.3865 - auc: 0.9208 - val_loss: 9.0278 - val_auc: 0.5770
# Epoch 196/200
# 14/14 [==============================] - 2s 163ms/step - loss: 8.3426 - auc: 0.9251 - val_loss: 8.9936 - val_auc: 0.5793
# Epoch 197/200
# 14/14 [==============================] - 2s 161ms/step - loss: 8.3100 - auc: 0.9223 - val_loss: 8.9641 - val_auc: 0.5786
# Epoch 198/200
# 14/14 [==============================] - 2s 161ms/step - loss: 8.2708 - auc: 0.9245 - val_loss: 8.9398 - val_auc: 0.5768
# Epoch 199/200
# 14/14 [==============================] - 2s 161ms/step - loss: 8.2342 - auc: 0.9258 - val_loss: 8.9088 - val_auc: 0.5819
# Epoch 200/200
# 14/14 [==============================] - 2s 161ms/step - loss: 8.1935 - auc: 0.9275 - val_loss: 8.8582 - val_auc: 0.5812
# 134/134 - 2s - loss: 8.7440 - auc: 0.6547 - 2s/epoch - 13ms/step
# Model accuracy: [8.743961334228516, 0.6547182202339172]
# 535/535 [==============================] - 7s 13ms/step
# 134/134 [==============================] - 2s 13ms/step
# 134/134 [==============================] - 2s 13ms/step - loss: 8.7440 - auc: 0.6547
# Loss: 8.743961334228516
# Accuracy: 0.6547182202339172
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_13936\1734228371.py:10
#       8 print('Loss:', metrics[0])
#       9 print('Accuracy:', metrics[1])
# ---> 10 print('AUC:', metrics[2])
#      11 print('Precision:', precision)
#      12 print('Recall:', recall)
#
# IndexError: list index out of range
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# d:\_c\spiced\ai-seizure-detectives\RNN_workflow_60_dur2_all_auc.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/_c/spiced/ai-seizure-detectives/RNN_workflow_60_dur2_all_auc.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> get_ipython().run_line_magic('run', 'model_rnn.ipynb')
#
# File d:\_c\spiced\ai-seizure-detectives\venv\Lib\site-packages\IPython\core\interactiveshell.py:2454, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2452     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2453 with self.builtin_trap:
# -> 2454     result = fn(*args, **kwargs)
#    2456 # The code below prevents the output from being displayed
#    2457 # when using magics with decorator @output_can_be_silenced
#    2458 # when the last Python token in the expression is a ';'.
#    2459 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File d:\_c\spiced\ai-seizure-detectives\venv\Lib\site-packages\IPython\core\magics\execution.py:737, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     735     with preserve_keys(self.shell.user_ns, '__file__'):
#     736         self.shell.user_ns['__file__'] = filename
# --> 737         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     738     return
#     740 # Control the response to exit() calls made by the script being run
#
# File d:\_c\spiced\ai-seizure-detectives\venv\Lib\site-packages\IPython\core\interactiveshell.py:2976, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2974 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2975 if raise_exceptions:
# -> 2976     result.raise_error()
#    2977 elif not result.success:
#    2978     break
#
# File d:\_c\spiced\ai-seizure-detectives\venv\Lib\site-packages\IPython\core\interactiveshell.py:292, in ExecutionResult.raise_error(self)
#     290     raise self.error_before_exec
#     291 if self.error_in_exec is not None:
# --> 292     raise self.error_in_exec
#
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Local\Temp\ipykernel_13936\1734228371.py:10
#       8 print('Loss:', metrics[0])
#       9 print('Accuracy:', metrics[1])
# ---> 10 print('AUC:', metrics[2])
#      11 print('Precision:', precision)
#      12 print('Recall:', recall)
#
# IndexError: list index out of range
