# %% [markdown]
# ## Pre-Processing

# %%
from source import data_import
from source.constants import CHANNELS, DEFAULT_PATIENTS
import numpy as np
import matplotlib.pyplot as plt

import os
import pandas as pd
# os.environ["MODIN_ENGINE"] = "ray"
# import modin.pandas as pd
# import ray
# ray.shutdown()
# ray.init()

from source.filter_eeg_channels import filter_eeg_channels
from source.calculate_mean_psd import calculate_mean_psd
from source.constants import CHANNELS, FREQUENCY_RANGES
from source.data_import import save_file, load_file 
                                            
from sklearn.preprocessing import StandardScaler, minmax_scale, MinMaxScaler

# %%
## PARAMETERS ##
SKIP_DATA = False
data_filename = "preprocessed_90_dur1_all_w45.arrow" # data will be loaded/saved with this filename. Put None to skip saving the file

SKIP_FEATURES = False
feature_filename = 'features_90_dur1_all_w45.npy' # data will be loaded/saved with this filename. Put None to skip saving the file

### DATA ###
# Load Patient Data #
patient_ids = None #DEFAULT_PATIENTS #DEFAULT_PATIENTS # use DEFAULT_PATIENTS for default patients selection
nr_segments=90
segment_duration=1
ictal_segmentation_foo=data_import.preictal_segmentation
interictal_segmentation_foo=data_import.inter_segmentation
channels=CHANNELS
seizure_offset=0

# filter #
exclude_ranges=[[58, 62], [118, 122]]

### FEATURES ###
target_colname = 'target'
PRED_INTERVAL = 6000 # how long should a segment count as preictal in seconds

window_size = 45 # Define the sequence_train window size

# %%
if not SKIP_DATA:
    # Load Patient Data
    p_df = data_import.load_segmented_data(patient_ids=patient_ids,
                                            nr_segments=nr_segments,
                                            segment_duration=segment_duration,
                                            ictal_segmentation_foo=data_import.preictal_segmentation,
                                            interictal_segmentation_foo=data_import.inter_segmentation,
                                            channels=channels,
                                            seizure_offset=seizure_offset
                                            )
    
    # Filter
    fit_df = filter_eeg_channels(p_df, CHANNELS, fs=256, exclude_ranges=exclude_ranges, Q=30)
    pd_toconcat = p_df[['epoch', 'segment_id']]
    fit_df = pd.concat(objs=[fit_df, pd_toconcat], axis =1)
    save_file(data=fit_df, file_name=data_filename)
    fit_df.head()
elif data_filename is not None:
    fit_df = load_file(data_filename)
    fit_df = pd.DataFrame(fit_df)
    fit_df.head()
# Out:
# D:\_c\spiced\ai-seizure-detectives\source\..\data\preprocessed_90_dur1_all_w45.arrow was loaded.

# %% [markdown]
# ## Feature Extraction

# %%
### aggregate Functions for mean psd:
delta = lambda x: calculate_mean_psd(x, frequency_ranges={'Delta' : FREQUENCY_RANGES['Delta']})[x.name]['Delta']
theta = lambda x: calculate_mean_psd(x, frequency_ranges={'Theta' : FREQUENCY_RANGES['Theta']})[x.name]['Theta']
gamma = lambda x: calculate_mean_psd(x, frequency_ranges={'Gamma': FREQUENCY_RANGES['Gamma']})[x.name]['Gamma']

delta_agg = pd.NamedAgg(column='delta', aggfunc=delta)
theta_agg = pd.NamedAgg(column='theta', aggfunc=theta)
gamma_agg = pd.NamedAgg(column='gamma', aggfunc=gamma)

### aggregate mean features:
abs_mean = lambda x: x.apply(abs).mean()
abs_mean_agg = pd.NamedAgg(column='abs_mean', aggfunc=abs_mean)

### aggregate Functions for target:
target_foo = lambda x, pred_interval=PRED_INTERVAL: 0 < x.dt.total_seconds().min() < pred_interval

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

def preprocess_data(df, window_size):
    # Grouping and aggregating features
    df_features = df.groupby(['epoch', 'segment_id']).agg(
        {C: ['std', 'var', abs_mean_agg, delta_agg, theta_agg, gamma_agg] for C in CHANNELS} | 
        {target_colname: [target_foo]}
    )
    
    # Renaming columns
    df_features.columns = ['_'.join(col).strip() for col in df_features.columns.values if target_colname != col[0]] + [target_colname]
    df_features.reset_index(inplace=True)


    # Reshaping array
    original_array = np.array(df_features)
    epoch_column = original_array[:, 0]
    num_epochs = df_features.epoch.unique()[-1]
    num_segments = len(df_features.segment_id.unique())
    reshaped_array = np.empty((num_epochs, num_segments, original_array.shape[1]))

    for epoch in range(num_epochs):
        start_idx = epoch * num_segments
        end_idx = (epoch + 1) * num_segments
        reshaped_array[epoch, :, :] = original_array[start_idx:end_idx, :]

    # Creating sequence trains
    num_batches, num_sequences, num_features = reshaped_array.shape
    num_augmented_batches = num_sequences - window_size + 1

    data = np.zeros((num_batches * num_augmented_batches, window_size, num_features))

    for batch_idx in range(num_batches):
        for seq_idx in range(num_augmented_batches):
            data[batch_idx * num_augmented_batches + seq_idx, :, :] = reshaped_array[batch_idx, seq_idx:seq_idx + window_size, :]
        
    return data

# %%
if not SKIP_FEATURES:
    data = preprocess_data(fit_df, window_size=window_size)
    print(data.shape)
    save_file(data=data, file_name=feature_filename)
else:
    data = load_file(feature_filename)
# Out:
# loading npy

# %%
# %run model_rnn.ipynb
# Out:
# WARNING:tensorflow:From d:\_c\spiced\ai-seizure-detectives\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# data already loaded in parent notebook
# 554 of epochs for training, 139 of epochs for testing/validation
# train shape (25484, 45, 62) ratio of seizures 0.25
# test shape (6394, 45, 62), ratio of seizures 0.29
# train shape (25484, 45, 60)
# test shape (6394, 45, 60)
# WARNING:tensorflow:From d:\_c\spiced\ai-seizure-detectives\venv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 256)               324608
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense (Dense)               (None, 256)               65792
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  batch_normalization (Batch  (None, 256)               1024
#  Normalization)
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 391681 (1.49 MB)
# Trainable params: 391169 (1.49 MB)
# Non-trainable params: 512 (2.00 KB)
# _________________________________________________________________
# Epoch 1/80
# WARNING:tensorflow:From d:\_c\spiced\ai-seizure-detectives\venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From d:\_c\spiced\ai-seizure-detectives\venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 21/21 [==============================] - 5s 166ms/step - loss: 19.1323 - accuracy: 0.4581 - auc: 0.5114 - val_loss: 18.9839 - val_accuracy: 0.2535 - val_auc: 0.4327
# Epoch 2/80
#  1/21 [>.............................] - ETA: 2s - loss: 19.0306 - accuracy: 0.4820 - auc: 0.5430
# d:\_c\spiced\ai-seizure-detectives\venv\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 21/21 [==============================] - 3s 141ms/step - loss: 19.0129 - accuracy: 0.4634 - auc: 0.5149 - val_loss: 18.8731 - val_accuracy: 0.2533 - val_auc: 0.4390
# Epoch 3/80
# 21/21 [==============================] - 3s 140ms/step - loss: 18.8905 - accuracy: 0.4719 - auc: 0.5329 - val_loss: 18.7630 - val_accuracy: 0.2539 - val_auc: 0.4474
# Epoch 4/80
# 21/21 [==============================] - 3s 140ms/step - loss: 18.7780 - accuracy: 0.4741 - auc: 0.5323 - val_loss: 18.6537 - val_accuracy: 0.2537 - val_auc: 0.4530
# Epoch 5/80
# 21/21 [==============================] - 3s 141ms/step - loss: 18.6669 - accuracy: 0.4734 - auc: 0.5335 - val_loss: 18.5448 - val_accuracy: 0.2539 - val_auc: 0.4617
# Epoch 6/80
# 21/21 [==============================] - 3s 141ms/step - loss: 18.5537 - accuracy: 0.4747 - auc: 0.5365 - val_loss: 18.4368 - val_accuracy: 0.2537 - val_auc: 0.4684
# Epoch 7/80
# 21/21 [==============================] - 3s 139ms/step - loss: 18.4340 - accuracy: 0.4796 - auc: 0.5463 - val_loss: 18.3288 - val_accuracy: 0.2533 - val_auc: 0.4761
# Epoch 8/80
# 21/21 [==============================] - 3s 139ms/step - loss: 18.3287 - accuracy: 0.4828 - auc: 0.5467 - val_loss: 18.2211 - val_accuracy: 0.2543 - val_auc: 0.4838
# Epoch 9/80
# 21/21 [==============================] - 3s 139ms/step - loss: 18.2181 - accuracy: 0.4841 - auc: 0.5497 - val_loss: 18.1137 - val_accuracy: 0.2552 - val_auc: 0.4903
# Epoch 10/80
# 21/21 [==============================] - 3s 138ms/step - loss: 18.1102 - accuracy: 0.4824 - auc: 0.5481 - val_loss: 18.0071 - val_accuracy: 0.2596 - val_auc: 0.4989
# Epoch 11/80
# 21/21 [==============================] - 3s 142ms/step - loss: 17.9902 - accuracy: 0.4875 - auc: 0.5611 - val_loss: 17.9009 - val_accuracy: 0.2653 - val_auc: 0.5039
# Epoch 12/80
# 21/21 [==============================] - 3s 139ms/step - loss: 17.8961 - accuracy: 0.4855 - auc: 0.5516 - val_loss: 17.7957 - val_accuracy: 0.2700 - val_auc: 0.5095
# Epoch 13/80
# 21/21 [==============================] - 3s 138ms/step - loss: 17.7846 - accuracy: 0.4894 - auc: 0.5592 - val_loss: 17.6898 - val_accuracy: 0.2839 - val_auc: 0.5156
# Epoch 14/80
# 21/21 [==============================] - 3s 140ms/step - loss: 17.6630 - accuracy: 0.4983 - auc: 0.5708 - val_loss: 17.5837 - val_accuracy: 0.3021 - val_auc: 0.5230
# Epoch 15/80
# 21/21 [==============================] - 3s 138ms/step - loss: 17.5637 - accuracy: 0.4974 - auc: 0.5688 - val_loss: 17.4776 - val_accuracy: 0.3263 - val_auc: 0.5287
# Epoch 16/80
# 21/21 [==============================] - 3s 137ms/step - loss: 17.4545 - accuracy: 0.5040 - auc: 0.5779 - val_loss: 17.3744 - val_accuracy: 0.3388 - val_auc: 0.5323
# Epoch 17/80
# 21/21 [==============================] - 3s 139ms/step - loss: 17.3487 - accuracy: 0.5068 - auc: 0.5807 - val_loss: 17.2723 - val_accuracy: 0.3471 - val_auc: 0.5379
# Epoch 18/80
# 21/21 [==============================] - 3s 138ms/step - loss: 17.2345 - accuracy: 0.5077 - auc: 0.5909 - val_loss: 17.1688 - val_accuracy: 0.3584 - val_auc: 0.5455
# Epoch 19/80
# 21/21 [==============================] - 3s 137ms/step - loss: 17.1353 - accuracy: 0.5123 - auc: 0.5905 - val_loss: 17.0669 - val_accuracy: 0.3639 - val_auc: 0.5496
# Epoch 20/80
# 21/21 [==============================] - 3s 138ms/step - loss: 17.0328 - accuracy: 0.5116 - auc: 0.5918 - val_loss: 16.9634 - val_accuracy: 0.3806 - val_auc: 0.5551
# Epoch 21/80
# 21/21 [==============================] - 3s 138ms/step - loss: 16.9320 - accuracy: 0.5099 - auc: 0.5912 - val_loss: 16.8629 - val_accuracy: 0.3838 - val_auc: 0.5612
# Epoch 22/80
# 21/21 [==============================] - 3s 138ms/step - loss: 16.8252 - accuracy: 0.5147 - auc: 0.5969 - val_loss: 16.7621 - val_accuracy: 0.3949 - val_auc: 0.5643
# Epoch 23/80
# 21/21 [==============================] - 3s 140ms/step - loss: 16.7253 - accuracy: 0.5196 - auc: 0.6028 - val_loss: 16.6615 - val_accuracy: 0.4047 - val_auc: 0.5692
# Epoch 24/80
# 21/21 [==============================] - 3s 149ms/step - loss: 16.6196 - accuracy: 0.5214 - auc: 0.6051 - val_loss: 16.5622 - val_accuracy: 0.4134 - val_auc: 0.5734
# Epoch 25/80
# 21/21 [==============================] - 3s 144ms/step - loss: 16.5218 - accuracy: 0.5231 - auc: 0.6084 - val_loss: 16.4641 - val_accuracy: 0.4165 - val_auc: 0.5777
# Epoch 26/80
# 21/21 [==============================] - 3s 145ms/step - loss: 16.4160 - accuracy: 0.5271 - auc: 0.6149 - val_loss: 16.3657 - val_accuracy: 0.4275 - val_auc: 0.5811
# Epoch 27/80
# 21/21 [==============================] - 3s 146ms/step - loss: 16.3178 - accuracy: 0.5237 - auc: 0.6150 - val_loss: 16.2680 - val_accuracy: 0.4354 - val_auc: 0.5833
# Epoch 28/80
# 21/21 [==============================] - 3s 150ms/step - loss: 16.2206 - accuracy: 0.5272 - auc: 0.6163 - val_loss: 16.1717 - val_accuracy: 0.4381 - val_auc: 0.5870
# Epoch 29/80
# 21/21 [==============================] - 3s 148ms/step - loss: 16.1223 - accuracy: 0.5286 - auc: 0.6219 - val_loss: 16.0738 - val_accuracy: 0.4469 - val_auc: 0.5887
# Epoch 30/80
# 21/21 [==============================] - 3s 149ms/step - loss: 16.0242 - accuracy: 0.5353 - auc: 0.6220 - val_loss: 15.9766 - val_accuracy: 0.4509 - val_auc: 0.5912
# Epoch 31/80
# 21/21 [==============================] - 3s 150ms/step - loss: 15.9278 - accuracy: 0.5370 - auc: 0.6279 - val_loss: 15.8791 - val_accuracy: 0.4542 - val_auc: 0.5947
# Epoch 32/80
# 21/21 [==============================] - 3s 151ms/step - loss: 15.8291 - accuracy: 0.5414 - auc: 0.6307 - val_loss: 15.7855 - val_accuracy: 0.4554 - val_auc: 0.5994
# Epoch 33/80
# 21/21 [==============================] - 3s 150ms/step - loss: 15.7377 - accuracy: 0.5374 - auc: 0.6279 - val_loss: 15.6900 - val_accuracy: 0.4597 - val_auc: 0.6012
# Epoch 34/80
# 21/21 [==============================] - 3s 148ms/step - loss: 15.6365 - accuracy: 0.5377 - auc: 0.6334 - val_loss: 15.5978 - val_accuracy: 0.4603 - val_auc: 0.6031
# Epoch 35/80
# 21/21 [==============================] - 3s 149ms/step - loss: 15.5415 - accuracy: 0.5432 - auc: 0.6374 - val_loss: 15.5036 - val_accuracy: 0.4626 - val_auc: 0.6061
# Epoch 36/80
# 21/21 [==============================] - 3s 148ms/step - loss: 15.4523 - accuracy: 0.5455 - auc: 0.6387 - val_loss: 15.4093 - val_accuracy: 0.4652 - val_auc: 0.6060
# Epoch 37/80
# 21/21 [==============================] - 3s 149ms/step - loss: 15.3495 - accuracy: 0.5497 - auc: 0.6443 - val_loss: 15.3181 - val_accuracy: 0.4648 - val_auc: 0.6064
# Epoch 38/80
# 21/21 [==============================] - 3s 148ms/step - loss: 15.2478 - accuracy: 0.5540 - auc: 0.6536 - val_loss: 15.2274 - val_accuracy: 0.4677 - val_auc: 0.6083
# Epoch 39/80
# 21/21 [==============================] - 3s 149ms/step - loss: 15.1588 - accuracy: 0.5504 - auc: 0.6511 - val_loss: 15.1353 - val_accuracy: 0.4687 - val_auc: 0.6102
# Epoch 40/80
# 21/21 [==============================] - 3s 149ms/step - loss: 15.0665 - accuracy: 0.5626 - auc: 0.6589 - val_loss: 15.0432 - val_accuracy: 0.4699 - val_auc: 0.6107
# Epoch 41/80
# 21/21 [==============================] - 3s 151ms/step - loss: 14.9768 - accuracy: 0.5555 - auc: 0.6594 - val_loss: 14.9528 - val_accuracy: 0.4730 - val_auc: 0.6128
# Epoch 42/80
# 21/21 [==============================] - 3s 150ms/step - loss: 14.8863 - accuracy: 0.5598 - auc: 0.6600 - val_loss: 14.8614 - val_accuracy: 0.4769 - val_auc: 0.6125
# Epoch 43/80
# 21/21 [==============================] - 3s 148ms/step - loss: 14.7885 - accuracy: 0.5626 - auc: 0.6647 - val_loss: 14.7738 - val_accuracy: 0.4775 - val_auc: 0.6157
# Epoch 44/80
# 21/21 [==============================] - 3s 150ms/step - loss: 14.7017 - accuracy: 0.5615 - auc: 0.6660 - val_loss: 14.6862 - val_accuracy: 0.4789 - val_auc: 0.6164
# Epoch 45/80
# 21/21 [==============================] - 3s 148ms/step - loss: 14.6069 - accuracy: 0.5675 - auc: 0.6715 - val_loss: 14.5994 - val_accuracy: 0.4803 - val_auc: 0.6170
# Epoch 46/80
# 21/21 [==============================] - 3s 150ms/step - loss: 14.5189 - accuracy: 0.5709 - auc: 0.6743 - val_loss: 14.5107 - val_accuracy: 0.4838 - val_auc: 0.6168
# Epoch 47/80
# 21/21 [==============================] - 3s 148ms/step - loss: 14.4275 - accuracy: 0.5723 - auc: 0.6767 - val_loss: 14.4236 - val_accuracy: 0.4858 - val_auc: 0.6166
# Epoch 48/80
# 21/21 [==============================] - 3s 149ms/step - loss: 14.3423 - accuracy: 0.5720 - auc: 0.6798 - val_loss: 14.3368 - val_accuracy: 0.4864 - val_auc: 0.6161
# Epoch 49/80
# 21/21 [==============================] - 3s 151ms/step - loss: 14.2518 - accuracy: 0.5743 - auc: 0.6823 - val_loss: 14.2516 - val_accuracy: 0.4893 - val_auc: 0.6179
# Epoch 50/80
# 21/21 [==============================] - 3s 151ms/step - loss: 14.1621 - accuracy: 0.5818 - auc: 0.6872 - val_loss: 14.1655 - val_accuracy: 0.4938 - val_auc: 0.6188
# Epoch 51/80
# 21/21 [==============================] - 3s 149ms/step - loss: 14.0702 - accuracy: 0.5830 - auc: 0.6924 - val_loss: 14.0815 - val_accuracy: 0.4954 - val_auc: 0.6172
# Epoch 52/80
# 21/21 [==============================] - 3s 150ms/step - loss: 13.9858 - accuracy: 0.5866 - auc: 0.6934 - val_loss: 13.9958 - val_accuracy: 0.4997 - val_auc: 0.6170
# Epoch 53/80
# 21/21 [==============================] - 3s 151ms/step - loss: 13.8972 - accuracy: 0.5890 - auc: 0.6972 - val_loss: 13.9126 - val_accuracy: 0.5013 - val_auc: 0.6175
# Epoch 54/80
# 21/21 [==============================] - 3s 149ms/step - loss: 13.8091 - accuracy: 0.5935 - auc: 0.7029 - val_loss: 13.8252 - val_accuracy: 0.5062 - val_auc: 0.6184
# Epoch 55/80
# 21/21 [==============================] - 3s 150ms/step - loss: 13.7233 - accuracy: 0.5942 - auc: 0.7085 - val_loss: 13.7477 - val_accuracy: 0.5062 - val_auc: 0.6197
# Epoch 56/80
# 21/21 [==============================] - 3s 154ms/step - loss: 13.6386 - accuracy: 0.5945 - auc: 0.7083 - val_loss: 13.6596 - val_accuracy: 0.5125 - val_auc: 0.6185
# Epoch 57/80
# 21/21 [==============================] - 3s 151ms/step - loss: 13.5481 - accuracy: 0.5980 - auc: 0.7141 - val_loss: 13.5805 - val_accuracy: 0.5134 - val_auc: 0.6187
# Epoch 58/80
# 21/21 [==============================] - 3s 150ms/step - loss: 13.4640 - accuracy: 0.6071 - auc: 0.7215 - val_loss: 13.4991 - val_accuracy: 0.5187 - val_auc: 0.6204
# Epoch 59/80
# 21/21 [==============================] - 3s 154ms/step - loss: 13.3746 - accuracy: 0.6094 - auc: 0.7241 - val_loss: 13.4176 - val_accuracy: 0.5213 - val_auc: 0.6194
# Epoch 60/80
# 21/21 [==============================] - 3s 152ms/step - loss: 13.2922 - accuracy: 0.6111 - auc: 0.7293 - val_loss: 13.3397 - val_accuracy: 0.5211 - val_auc: 0.6182
# Epoch 61/80
# 21/21 [==============================] - 3s 150ms/step - loss: 13.2092 - accuracy: 0.6089 - auc: 0.7299 - val_loss: 13.2599 - val_accuracy: 0.5248 - val_auc: 0.6181
# Epoch 62/80
# 21/21 [==============================] - 3s 149ms/step - loss: 13.1235 - accuracy: 0.6199 - auc: 0.7366 - val_loss: 13.1848 - val_accuracy: 0.5238 - val_auc: 0.6169
# Epoch 63/80
# 21/21 [==============================] - 3s 150ms/step - loss: 13.0399 - accuracy: 0.6161 - auc: 0.7405 - val_loss: 13.1074 - val_accuracy: 0.5266 - val_auc: 0.6160
# Epoch 64/80
# 21/21 [==============================] - 3s 149ms/step - loss: 12.9592 - accuracy: 0.6246 - auc: 0.7405 - val_loss: 13.0244 - val_accuracy: 0.5354 - val_auc: 0.6170
# Epoch 65/80
# 21/21 [==============================] - 3s 149ms/step - loss: 12.8699 - accuracy: 0.6231 - auc: 0.7492 - val_loss: 12.9427 - val_accuracy: 0.5468 - val_auc: 0.6213
# Epoch 66/80
# 21/21 [==============================] - 3s 150ms/step - loss: 12.7829 - accuracy: 0.6339 - auc: 0.7582 - val_loss: 12.8681 - val_accuracy: 0.5505 - val_auc: 0.6156
# Epoch 67/80
# 21/21 [==============================] - 3s 148ms/step - loss: 12.7036 - accuracy: 0.6399 - auc: 0.7613 - val_loss: 12.7918 - val_accuracy: 0.5495 - val_auc: 0.6201
# Epoch 68/80
# 21/21 [==============================] - 3s 150ms/step - loss: 12.6300 - accuracy: 0.6382 - auc: 0.7577 - val_loss: 12.7195 - val_accuracy: 0.5546 - val_auc: 0.6157
# Epoch 69/80
# 21/21 [==============================] - 3s 152ms/step - loss: 12.5437 - accuracy: 0.6399 - auc: 0.7650 - val_loss: 12.6478 - val_accuracy: 0.5519 - val_auc: 0.6143
# Epoch 70/80
# 21/21 [==============================] - 3s 150ms/step - loss: 12.4484 - accuracy: 0.6525 - auc: 0.7791 - val_loss: 12.5715 - val_accuracy: 0.5570 - val_auc: 0.6150
# Epoch 71/80
# 21/21 [==============================] - 3s 150ms/step - loss: 12.3739 - accuracy: 0.6503 - auc: 0.7769 - val_loss: 12.4980 - val_accuracy: 0.5609 - val_auc: 0.6126
# Epoch 72/80
# 21/21 [==============================] - 3s 153ms/step - loss: 12.2939 - accuracy: 0.6550 - auc: 0.7804 - val_loss: 12.4261 - val_accuracy: 0.5658 - val_auc: 0.6124
# Epoch 73/80
# 21/21 [==============================] - 3s 152ms/step - loss: 12.2098 - accuracy: 0.6636 - auc: 0.7879 - val_loss: 12.3575 - val_accuracy: 0.5641 - val_auc: 0.6106
# Epoch 74/80
# 21/21 [==============================] - 3s 149ms/step - loss: 12.1355 - accuracy: 0.6628 - auc: 0.7871 - val_loss: 12.2807 - val_accuracy: 0.5701 - val_auc: 0.6162
# Epoch 75/80
# 21/21 [==============================] - 3s 150ms/step - loss: 12.0624 - accuracy: 0.6705 - auc: 0.7899 - val_loss: 12.2038 - val_accuracy: 0.5786 - val_auc: 0.6170
# Epoch 76/80
# 21/21 [==============================] - 3s 150ms/step - loss: 11.9769 - accuracy: 0.6733 - auc: 0.7969 - val_loss: 12.1330 - val_accuracy: 0.5794 - val_auc: 0.6149
# Epoch 77/80
# 21/21 [==============================] - 3s 155ms/step - loss: 11.8971 - accuracy: 0.6768 - auc: 0.8010 - val_loss: 12.0635 - val_accuracy: 0.5807 - val_auc: 0.6170
# Epoch 78/80
# 21/21 [==============================] - 3s 151ms/step - loss: 11.8193 - accuracy: 0.6837 - auc: 0.8041 - val_loss: 11.9913 - val_accuracy: 0.5878 - val_auc: 0.6152
# Epoch 79/80
# 21/21 [==============================] - 3s 153ms/step - loss: 11.7414 - accuracy: 0.6838 - auc: 0.8090 - val_loss: 11.9122 - val_accuracy: 0.5976 - val_auc: 0.6201
# Epoch 80/80
# 21/21 [==============================] - 3s 154ms/step - loss: 11.6640 - accuracy: 0.6876 - auc: 0.8115 - val_loss: 11.8494 - val_accuracy: 0.5919 - val_auc: 0.6180
# 200/200 - 2s - loss: 11.8117 - accuracy: 0.6378 - auc: 0.6926 - 2s/epoch - 9ms/step
# Model accuracy: [11.811731338500977, 0.6377854347229004, 0.6925792694091797]
# 797/797 [==============================] - 8s 9ms/step
# 200/200 [==============================] - 2s 9ms/step
# 200/200 [==============================] - 2s 9ms/step - loss: 11.8117 - accuracy: 0.6378 - auc: 0.6926
# Loss: 11.811731338500977
# AUC: 0.6377854347229004
# Accuracy: 0.6925792694091797
# Precision: 0.4155429382540809
# Recall: 0.6364130434782609
# Metrics:  ['loss', 'accuracy', 'auc']
# Results:  [11.811731338500977, 0.6377854347229004, 0.6925792694091797]
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.64      0.72      4554
#          1.0       0.42      0.64      0.50      1840
#
#     accuracy                           0.64      6394
#    macro avg       0.61      0.64      0.61      6394
# weighted avg       0.70      0.64      0.65      6394
# Ein Unterverzeichnis oder eine Datei mit dem Namen "-p" existiert bereits.
# Folgender Fehler trat auf: -p.
# Ein Unterverzeichnis oder eine Datei mit dem Namen "saved_model" existiert bereits.
# Folgender Fehler trat auf: saved_model.
# INFO:tensorflow:Assets written to: saved_model/my_RNN_model_60per5_fixing_overfit\assets
# INFO:tensorflow:Assets written to: saved_model/my_RNN_model_60per5_fixing_overfit\assets
