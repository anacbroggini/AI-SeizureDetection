# %%
import glob
import os

# %%
CLIP_PATH = "data/Patient_1/"

def get_clips(data_folder):

    # Get all clips
    clips = os.listdir(data_folder)

    # Preictal recordings - time-series segments of the measurement before a seizure occura
    clips_preictal = glob.glob(os.path.join(data_folder, "*preictal*"))

    # Interictial segments - segments with no oncoming seizures
    clips_interictial = glob.glob(os.path.join(data_folder, "*interictal*"))

    return clips_interictial, clips_preictal


# Get EEG recordings
clips_interictal, clips_preictal = get_clips(data_folder = CLIP_PATH)
clips_interictal[0:2]
# Out:
# ['data/Patient_1/Patient_1_interictal_segment_0020.mat',
#  'data/Patient_1/Patient_1_interictal_segment_0042.mat']

# %%
import os
import numpy as np
from scipy.io import loadmat

# Construct LSTM sequences from one segment
def lstm_sequence(input_segment, target, sampling_freq, window, stride, block_s = 60):
    """ Function for generating blocks of LSTM input tensors
        input_segment : The EEG segment
        target        : 1/0 (preictal/interictial); None for test
        sampling_freq : Samplig frequency
        window        : Window size for 1d convolutions on each block
        stride        : Stride size of the 1d convolution
        block_s       : Size of the block in seconds (default = 60)
    """

    # Dimensions
    n_channels, T_segment = input_segment.shape

    # Determine block dimensions
    block_len = sampling_freq * block_s   # Length of each block
    n_blocks = (T_segment-1) // block_len # Number of blocks
    blocks = [block for block in range(0,(n_blocks+1)*block_len,block_len)]

    # Determine the sequence length for LSTM
    div = (block_len - window)%stride
    if (div != 0):
        pad = stride - div # Size of padding neded
    else:
        pad = 0

    seq_len = (block_len + pad - window) // stride

    # Initiate tensor
    X = np.zeros((n_blocks, seq_len, n_channels))

    # Loop over blocks and fill X
    for ib in range(n_blocks):
        # Get block
        data_block = input_segment[:, blocks[ib]:blocks[ib+1]]

        # Pad if necessary
        if (pad !=0):
            data_block = np.concatenate((data_block, np.zeros((n_channels, pad))), axis=1)

        # 1d convolution by mean
        index = 0
        for j in range(seq_len):
            X[ib, j, :] = np.mean(data_block[:, (index+j):(index+j+seq_len)], axis = 1)

    # Fill in the target
    if (target == 1):
        Y = np.ones(n_blocks)
    elif(target == 0):
        Y = np.zeros(n_blocks)
    else:
        Y = None

    return X, Y, n_blocks

# Collect all the segments to build a tesnsor input for LSTM
def lstm_build_input(clips, target, window, stride, block_s = 60):
    """ Collect all the data and build sequences for LSTM
        clips              : List of clips
        target             : 1/0 (preictal/interictial); None for test set
        window             : Window size for 1d convolutions
        stride             : Length of the stride in 1d convolution
        block_s            : Size of the block in seconds (default = 60)
    """

    # Number of clips
    n_clips = len(clips)

    # Loop over all clips and store data
    iclip = 0
    for file in clips:
        clip = loadmat(file)
        segment_name = list(clip.keys())[3] # Get segment name
        input_segment = clip[segment_name][0][0][0] # Get electrode data
        sampling_freq = np.squeeze(clip[segment_name][0][0][2]) # Sampling frequency

        # Get number of channels
        n_channels = clip[segment_name][0][0][0].shape[0]

        # Get tensor input and targets from blocks
        X, Y, n_blocks = lstm_sequence(input_segment, target, sampling_freq, window, stride, block_s)

        # Concatenate the tensor and target vector
        if (iclip == 0):
            X_train = X
            Y_train = Y[:,None] if Y is not None else None
        else:
            X_train = np.vstack((X_train,X))
            Y_train = np.vstack((Y_train,Y[:,None])) if Y is not None else None

        iclip +=1

    return X_train, Y_train


# Window, stride and block_s
window = 16000
stride = 100
block_s = 60

X_1, Y_1 = lstm_build_input(clips_preictal, 1, window, stride)
X_0, Y_0 = lstm_build_input(clips_interictal, 0, window, stride)

# Scale the data
X_1 = X_1 / np.max(np.abs(X_1), axis=1)[:,None,:]
X_0 = X_0 / np.max(np.abs(X_0), axis=1)[:,None,:]

# Combine the data
X = np.concatenate((X_0, X_1), axis = 0)
Y = np.concatenate((Y_0, Y_1), axis = 0)
Y = np.squeeze(Y)

print("Data shape = ", X.shape)
# Out:
# Data shape =  (612, 2840, 15)

# %%
Y.shape
# Out:
# (612,)

# %%
# Normalize
X = X / np.max(np.abs(X), axis=1)[:,None,:]

# Shuffle
np.random.seed(1)
shuffle = np.random.choice(np.arange(len(Y)), size=len(Y), replace=False)
X = X[shuffle]
Y = Y[shuffle]

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential()
model.add(layers.Input(shape=(2840, 15)))
model.add(layers.LSTM(64))
model.add(layers.BatchNormalization())
model.add(layers.Dense(1, activation='sigmoid'))

# %%
import numpy
from keras.callbacks import Callback

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score


class RocCallback(Callback):
    def __init__(self,training_data,validation_data):
        self.x = training_data[0]
        self.y = training_data[1]
        self.x_val = validation_data[0]
        self.y_val = validation_data[1]

    def on_train_begin(self, logs={}):
        return

    def on_train_end(self, logs={}):
        return

    def on_epoch_begin(self, epoch, logs={}):
        return

    def on_epoch_end(self, epoch, logs={}):
        y_pred_train = model.predict(self.x)
        roc_train = roc_auc_score(self.y, y_pred_train)
        y_pred_val = model.predict(self.x_val)
        roc_val = roc_auc_score(self.y_val, y_pred_val)
        print('roc-auc_train: ', roc_train)
        print('roc-auc_val: ', roc_val)
        return

    def on_batch_begin(self, batch, logs={}):
        return

    def on_batch_end(self, batch, logs={}):
        return

n_channels = 15
# Function that trains the model
def train_model(X, Y):
    X = X.reshape(X.shape[0], -1, n_channels)   # reshape DH table to 3d numpy array
    X_train, X_valid, Y_train, Y_valid = train_test_split(X, Y, stratify=Y, test_size = 0.1)
    roc = RocCallback(training_data=(X_train, Y_train), validation_data=(X_valid, Y_valid))
    model.compile(loss='binary_crossentropy', optimizer="adam", metrics=["accuracy"])
    # model.fit(X_train, Y_train, validation_data=(X_valid, Y_valid), callbacks=[roc], batch_size = 200, epochs=100)
    model.fit(X_train, Y_train, validation_data=(X_valid, Y_valid), callbacks=[roc], batch_size = 200, epochs=100)

# Function that gets the model's predictions on input data
def predict_with_model(X):
    X = X.reshape(X.shape[0], -1, n_channels)  # reshape DH table to 3d numpy array
    Y_pred = model.predict(X, batch_size=200)
    return Y_pred

# Function to extract a list element at a given index
def get_predicted_class(data, idx):
    return data[idx]

# Split the data into training and test datasets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, stratify=Y, test_size = 0.2)

# Convert numpy arrays X_train and Y_train to DH table X_table
n_rows = X_train.shape[0]
n_cols = X_train.shape[1] * X_train.shape[2]
column_names = ['Col_'+str(i) for i in range(n_cols)]
X_reshaped = X_train.reshape(n_rows, n_cols)
# X_table = numpy.to_table(X_reshaped, cols=column_names)

def add_class_col(index):
    y_class = [int(i) for i in Y_train.tolist()]
    return y_class[index]

# X_table = X_table.update(["Class = (int)add_class_col(i)"])


train_model(X_train, Y_train)

# # Train the model
# learn.learn(
#     table=X_table,
#     model_func=train_model,
#     inputs=[learn.Input(column_names, table_to_array_double), learn.Input(["Class"], table_to_array_int)],
#     outputs=None,
#     batch_size=200
# )


# Convert numpy array X_test to DH table X_table_test
X_reshaped_test = X_test.reshape(X_test.shape[0], n_cols)
# X_table_test = numpy.to_table(X_reshaped_test, cols=column_names)

# Use the learn function to create a new table that contains predicted values
y_pred = predict_with_model(X_test)

# predicted = learn.learn(
#     table=X_table_test,
#     model_func=predict_with_model,
#     inputs=[learn.Input(column_names, table_to_array_double)],
#     outputs=[learn.Output("PredictedClass", get_predicted_class, "int")],
#     batch_size=200
# )
# Out:
# Epoch 1/100
# 14/14 [==============================] - 2s 137ms/step
# 2/2 [==============================] - 0s 116ms/step
# roc-auc_train:  0.5429438058748404
# roc-auc_val:  0.6923076923076924
# 3/3 [==============================] - 7s 2s/step - loss: 0.8594 - accuracy: 0.5114 - val_loss: 0.6702 - val_accuracy: 0.6939
# Epoch 2/100
# 14/14 [==============================] - 2s 137ms/step
# 2/2 [==============================] - 0s 110ms/step
# roc-auc_train:  0.5883354618986802
# roc-auc_val:  0.6623931623931625
# 3/3 [==============================] - 5s 2s/step - loss: 0.7480 - accuracy: 0.5159 - val_loss: 0.6743 - val_accuracy: 0.6735
# Epoch 3/100
# 14/14 [==============================] - 2s 136ms/step
# 2/2 [==============================] - 0s 120ms/step
# roc-auc_train:  0.6478554704129417
# roc-auc_val:  0.6111111111111112
# 3/3 [==============================] - 5s 2s/step - loss: 0.6858 - accuracy: 0.5591 - val_loss: 0.6798 - val_accuracy: 0.6327
# Epoch 4/100
# 14/14 [==============================] - 2s 138ms/step
# 2/2 [==============================] - 0s 111ms/step
# roc-auc_train:  0.7002979991485738
# roc-auc_val:  0.5555555555555556
# 3/3 [==============================] - 5s 2s/step - loss: 0.6525 - accuracy: 0.6000 - val_loss: 0.6807 - val_accuracy: 0.6327
# Epoch 5/100
# 14/14 [==============================] - 2s 134ms/step
# 2/2 [==============================] - 0s 113ms/step
# roc-auc_train:  0.7276766709237974
# roc-auc_val:  0.5341880341880343
# 3/3 [==============================] - 5s 2s/step - loss: 0.6251 - accuracy: 0.6318 - val_loss: 0.6787 - val_accuracy: 0.6327
# Epoch 6/100
# 14/14 [==============================] - 2s 137ms/step
# 2/2 [==============================] - 0s 114ms/step
# roc-auc_train:  0.7478980417198808
# roc-auc_val:  0.5341880341880342
# 3/3 [==============================] - 5s 2s/step - loss: 0.6094 - accuracy: 0.6636 - val_loss: 0.6735 - val_accuracy: 0.6327
# Epoch 7/100
# 14/14 [==============================] - 2s 137ms/step
# 2/2 [==============================] - 0s 112ms/step
# roc-auc_train:  0.763888888888889
# roc-auc_val:  0.561965811965812
# 3/3 [==============================] - 5s 2s/step - loss: 0.5923 - accuracy: 0.7045 - val_loss: 0.6627 - val_accuracy: 0.6531
# Epoch 8/100
# 14/14 [==============================] - 2s 137ms/step
# 2/2 [==============================] - 0s 108ms/step
# roc-auc_train:  0.7723233290762026
# roc-auc_val:  0.5833333333333334
# 3/3 [==============================] - 5s 2s/step - loss: 0.5811 - accuracy: 0.7205 - val_loss: 0.6506 - val_accuracy: 0.7143
# Epoch 9/100
# 14/14 [==============================] - 2s 135ms/step
# 2/2 [==============================] - 0s 109ms/step
# roc-auc_train:  0.7867443593018305
# roc-auc_val:  0.5897435897435898
# 3/3 [==============================] - 5s 2s/step - loss: 0.5695 - accuracy: 0.7318 - val_loss: 0.6417 - val_accuracy: 0.7347
# Epoch 10/100
# 14/14 [==============================] - 2s 136ms/step
# 2/2 [==============================] - 0s 115ms/step
# roc-auc_train:  0.8059280544912728
# roc-auc_val:  0.594017094017094
# 3/3 [==============================] - 5s 2s/step - loss: 0.5584 - accuracy: 0.7591 - val_loss: 0.6364 - val_accuracy: 0.6939
# Epoch 11/100
# 14/14 [==============================] - 2s 135ms/step
# 2/2 [==============================] - 0s 111ms/step
# roc-auc_train:  0.8150276713495105
# roc-auc_val:  0.6047008547008548
# 3/3 [==============================] - 5s 2s/step - loss: 0.5456 - accuracy: 0.7523 - val_loss: 0.6283 - val_accuracy: 0.6939
# Epoch 12/100
# 14/14 [==============================] - 2s 136ms/step
# 2/2 [==============================] - 0s 112ms/step
# roc-auc_train:  0.8303533418475947
# roc-auc_val:  0.6239316239316239
# 3/3 [==============================] - 5s 2s/step - loss: 0.5323 - accuracy: 0.7705 - val_loss: 0.6219 - val_accuracy: 0.6939
# Epoch 13/100
# 14/14 [==============================] - 2s 135ms/step
# 2/2 [==============================] - 0s 112ms/step
# roc-auc_train:  0.846011600681141
# roc-auc_val:  0.6132478632478633
# 3/3 [==============================] - 5s 2s/step - loss: 0.5180 - accuracy: 0.7909 - val_loss: 0.6185 - val_accuracy: 0.7143
# Epoch 14/100
# 14/14 [==============================] - 2s 135ms/step
# 2/2 [==============================] - 0s 117ms/step
# roc-auc_train:  0.8659269902085994
# roc-auc_val:  0.5747863247863247
# 3/3 [==============================] - 5s 2s/step - loss: 0.5059 - accuracy: 0.8000 - val_loss: 0.6171 - val_accuracy: 0.7347
# Epoch 15/100
# 14/14 [==============================] - 2s 135ms/step
# 2/2 [==============================] - 0s 109ms/step
# roc-auc_train:  0.8798690932311621
# roc-auc_val:  0.5683760683760684
# 3/3 [==============================] - 5s 2s/step - loss: 0.4935 - accuracy: 0.8136 - val_loss: 0.6205 - val_accuracy: 0.6939
# Epoch 16/100
# 14/14 [==============================] - 2s 139ms/step
# 2/2 [==============================] - 0s 121ms/step
# roc-auc_train:  0.8846317581949766
# roc-auc_val:  0.5555555555555556
# 3/3 [==============================] - 5s 2s/step - loss: 0.4836 - accuracy: 0.8114 - val_loss: 0.6231 - val_accuracy: 0.6939
# Epoch 17/100
# 14/14 [==============================] - 2s 141ms/step
# 2/2 [==============================] - 0s 114ms/step
# roc-auc_train:  0.8894742443593018
# roc-auc_val:  0.5662393162393162
# 3/3 [==============================] - 5s 2s/step - loss: 0.4741 - accuracy: 0.8250 - val_loss: 0.6224 - val_accuracy: 0.6939
# Epoch 18/100
# 14/14 [==============================] - 2s 144ms/step
# 2/2 [==============================] - 0s 117ms/step
# roc-auc_train:  0.893837803320562
# roc-auc_val:  0.5662393162393162
# 3/3 [==============================] - 5s 2s/step - loss: 0.4571 - accuracy: 0.8341 - val_loss: 0.6148 - val_accuracy: 0.6939
# Epoch 19/100
# 14/14 [==============================] - 2s 140ms/step
# 2/2 [==============================] - 0s 119ms/step
# roc-auc_train:  0.8931194125159643
# roc-auc_val:  0.561965811965812
# 3/3 [==============================] - 5s 2s/step - loss: 0.4423 - accuracy: 0.8500 - val_loss: 0.6077 - val_accuracy: 0.6939
# Epoch 20/100
# 14/14 [==============================] - 2s 143ms/step
# 2/2 [==============================] - 0s 111ms/step
# roc-auc_train:  0.8946626223925074
# roc-auc_val:  0.5641025641025641
# 3/3 [==============================] - 5s 2s/step - loss: 0.4300 - accuracy: 0.8386 - val_loss: 0.6040 - val_accuracy: 0.6939
# Epoch 21/100
# 14/14 [==============================] - 2s 140ms/step
# 2/2 [==============================] - 0s 108ms/step
# roc-auc_train:  0.9097488292890592
# roc-auc_val:  0.5747863247863247
# 3/3 [==============================] - 5s 2s/step - loss: 0.4188 - accuracy: 0.8455 - val_loss: 0.6090 - val_accuracy: 0.6939
# Epoch 22/100
# 14/14 [==============================] - 2s 141ms/step
# 2/2 [==============================] - 0s 113ms/step
# roc-auc_train:  0.9257130693912303
# roc-auc_val:  0.5427350427350428
# 3/3 [==============================] - 5s 2s/step - loss: 0.4025 - accuracy: 0.8523 - val_loss: 0.6154 - val_accuracy: 0.6735
# Epoch 23/100
# 14/14 [==============================] - 2s 141ms/step
# 2/2 [==============================] - 0s 114ms/step
# roc-auc_train:  0.940746062154108
# roc-auc_val:  0.5363247863247863
# 3/3 [==============================] - 5s 2s/step - loss: 0.3867 - accuracy: 0.8841 - val_loss: 0.6196 - val_accuracy: 0.6735
# Epoch 24/100
# 14/14 [==============================] - 2s 142ms/step
# 2/2 [==============================] - 0s 113ms/step
# roc-auc_train:  0.9322850148999574
# roc-auc_val:  0.5491452991452992
# 3/3 [==============================] - 5s 2s/step - loss: 0.3666 - accuracy: 0.8932 - val_loss: 0.6070 - val_accuracy: 0.6939
# Epoch 25/100
# 14/14 [==============================] - 2s 141ms/step
# 2/2 [==============================] - 0s 116ms/step
# roc-auc_train:  0.9500053214133674
# roc-auc_val:  0.5277777777777778
# 3/3 [==============================] - 5s 2s/step - loss: 0.3574 - accuracy: 0.8932 - val_loss: 0.6154 - val_accuracy: 0.6735
# Epoch 26/100
# 14/14 [==============================] - 2s 148ms/step
# 2/2 [==============================] - 0s 116ms/step
# roc-auc_train:  0.9597568114091103
# roc-auc_val:  0.5256410256410257
# 3/3 [==============================] - 5s 2s/step - loss: 0.3333 - accuracy: 0.9114 - val_loss: 0.6230 - val_accuracy: 0.6531
# Epoch 27/100
# 14/14 [==============================] - 2s 143ms/step
# 2/2 [==============================] - 0s 114ms/step
# roc-auc_train:  0.9633886760323542
# roc-auc_val:  0.5405982905982907
# 3/3 [==============================] - 5s 2s/step - loss: 0.3133 - accuracy: 0.9000 - val_loss: 0.6266 - val_accuracy: 0.6327
# Epoch 28/100
# 14/14 [==============================] - 2s 143ms/step
# 2/2 [==============================] - 0s 116ms/step
# roc-auc_train:  0.9681779480630055
# roc-auc_val:  0.5192307692307693
# 3/3 [==============================] - 5s 2s/step - loss: 0.2861 - accuracy: 0.9205 - val_loss: 0.6450 - val_accuracy: 0.6327
# Epoch 29/100
# 14/14 [==============================] - 2s 144ms/step
# 2/2 [==============================] - 0s 118ms/step
# roc-auc_train:  0.9655438484461473
# roc-auc_val:  0.5854700854700855
# 3/3 [==============================] - 5s 2s/step - loss: 0.2632 - accuracy: 0.9386 - val_loss: 0.6217 - val_accuracy: 0.6531
# Epoch 30/100
# 14/14 [==============================] - 2s 141ms/step
# 2/2 [==============================] - 0s 114ms/step
# roc-auc_train:  0.8223180076628351
# roc-auc_val:  0.6431623931623932
# 3/3 [==============================] - 5s 2s/step - loss: 0.2951 - accuracy: 0.9068 - val_loss: 0.6069 - val_accuracy: 0.6531
# Epoch 31/100
# 14/14 [==============================] - 2s 144ms/step
# 2/2 [==============================] - 0s 127ms/step
# roc-auc_train:  0.8879842486164325
# roc-auc_val:  0.5833333333333333
# 3/3 [==============================] - 5s 2s/step - loss: 0.3522 - accuracy: 0.8909 - val_loss: 0.6073 - val_accuracy: 0.7143
# Epoch 32/100
# 14/14 [==============================] - 2s 142ms/step
# 2/2 [==============================] - 0s 118ms/step
# roc-auc_train:  0.9382449978714346
# roc-auc_val:  0.5149572649572649
# 3/3 [==============================] - 5s 2s/step - loss: 0.2933 - accuracy: 0.9023 - val_loss: 0.6337 - val_accuracy: 0.7347
# Epoch 33/100
# 14/14 [==============================] - 2s 142ms/step
# 2/2 [==============================] - 0s 125ms/step
# roc-auc_train:  0.9530917411664539
# roc-auc_val:  0.4935897435897436
# 3/3 [==============================] - 5s 2s/step - loss: 0.2834 - accuracy: 0.8841 - val_loss: 0.6713 - val_accuracy: 0.7347
# Epoch 34/100
# 14/14 [==============================] - 2s 142ms/step
# 2/2 [==============================] - 0s 114ms/step
# roc-auc_train:  0.9552203065134098
# roc-auc_val:  0.4871794871794872
# 3/3 [==============================] - 6s 2s/step - loss: 0.2856 - accuracy: 0.8955 - val_loss: 0.6596 - val_accuracy: 0.7551
# Epoch 35/100
# 14/14 [==============================] - 2s 142ms/step
# 2/2 [==============================] - 0s 114ms/step
# roc-auc_train:  0.96237760749255
# roc-auc_val:  0.5042735042735043
# 3/3 [==============================] - 5s 2s/step - loss: 0.2699 - accuracy: 0.9000 - val_loss: 0.6358 - val_accuracy: 0.7347
# Epoch 36/100
# 14/14 [==============================] - 2s 142ms/step
# 2/2 [==============================] - 0s 125ms/step
# roc-auc_train:  0.9736057896977438
# roc-auc_val:  0.5961538461538461
# 3/3 [==============================] - 5s 2s/step - loss: 0.2396 - accuracy: 0.9136 - val_loss: 0.6023 - val_accuracy: 0.7143
# Epoch 37/100
# 14/14 [==============================] - 2s 141ms/step
# 2/2 [==============================] - 0s 114ms/step
# roc-auc_train:  0.9751223925074499
# roc-auc_val:  0.6175213675213675
# 3/3 [==============================] - 5s 2s/step - loss: 0.2160 - accuracy: 0.9273 - val_loss: 0.6234 - val_accuracy: 0.6735
# Epoch 38/100
# 14/14 [==============================] - 2s 141ms/step
# 2/2 [==============================] - 0s 112ms/step
# roc-auc_train:  0.973472754363559
# roc-auc_val:  0.6025641025641026
# 3/3 [==============================] - 5s 2s/step - loss: 0.2000 - accuracy: 0.9386 - val_loss: 0.7424 - val_accuracy: 0.6531
# Epoch 39/100
# 14/14 [==============================] - 2s 143ms/step
# 2/2 [==============================] - 0s 119ms/step
# roc-auc_train:  0.925313963388676
# roc-auc_val:  0.6153846153846154
# 3/3 [==============================] - 5s 2s/step - loss: 0.2228 - accuracy: 0.9477 - val_loss: 0.8376 - val_accuracy: 0.6531
# Epoch 40/100
# 14/14 [==============================] - 2s 143ms/step
# 2/2 [==============================] - 0s 133ms/step
# roc-auc_train:  0.8731108982545766
# roc-auc_val:  0.5192307692307693
# 3/3 [==============================] - 5s 2s/step - loss: 0.5946 - accuracy: 0.8614 - val_loss: 1.1199 - val_accuracy: 0.5102
# Epoch 41/100
# 14/14 [==============================] - 2s 147ms/step
# 2/2 [==============================] - 0s 126ms/step
# roc-auc_train:  0.8751596424010217
# roc-auc_val:  0.5064102564102564
# 3/3 [==============================] - 5s 2s/step - loss: 0.7073 - accuracy: 0.7932 - val_loss: 1.0195 - val_accuracy: 0.5102
# Epoch 42/100
# 14/14 [==============================] - 2s 143ms/step
# 2/2 [==============================] - 0s 116ms/step
# roc-auc_train:  0.8880374627501064
# roc-auc_val:  0.5683760683760684
# 3/3 [==============================] - 5s 2s/step - loss: 0.5593 - accuracy: 0.7841 - val_loss: 0.8278 - val_accuracy: 0.5102
# Epoch 43/100
# 14/14 [==============================] - 2s 151ms/step
# 2/2 [==============================] - 0s 113ms/step
# roc-auc_train:  0.8756385696040869
# roc-auc_val:  0.5769230769230769
# 3/3 [==============================] - 6s 2s/step - loss: 0.4784 - accuracy: 0.7841 - val_loss: 0.7396 - val_accuracy: 0.5306
# Epoch 44/100
# 14/14 [==============================] - 3s 185ms/step
# 2/2 [==============================] - 0s 112ms/step
# roc-auc_train:  0.8941836951894423
# roc-auc_val:  0.5598290598290598
# 3/3 [==============================] - 6s 3s/step - loss: 0.4418 - accuracy: 0.7750 - val_loss: 0.6768 - val_accuracy: 0.6327
# Epoch 45/100
# 14/14 [==============================] - 2s 137ms/step
# 2/2 [==============================] - 0s 112ms/step
# roc-auc_train:  0.9221743295019157
# roc-auc_val:  0.5299145299145299
# 3/3 [==============================] - 6s 3s/step - loss: 0.3684 - accuracy: 0.8250 - val_loss: 0.6496 - val_accuracy: 0.6531
# Epoch 46/100
# 14/14 [==============================] - 2s 141ms/step
# 2/2 [==============================] - 0s 113ms/step
# roc-auc_train:  0.9371275010642827
# roc-auc_val:  0.4935897435897436
# 3/3 [==============================] - 6s 2s/step - loss: 0.3210 - accuracy: 0.8773 - val_loss: 0.6435 - val_accuracy: 0.6939
# Epoch 47/100
# 14/14 [==============================] - 2s 139ms/step
# 2/2 [==============================] - 0s 114ms/step
# roc-auc_train:  0.9430342699020859
# roc-auc_val:  0.47435897435897434
# 3/3 [==============================] - 7s 2s/step - loss: 0.3132 - accuracy: 0.8955 - val_loss: 0.6411 - val_accuracy: 0.6939
# Epoch 48/100
# 14/14 [==============================] - 2s 157ms/step
# 2/2 [==============================] - 0s 110ms/step
# roc-auc_train:  0.9488878246062155
# roc-auc_val:  0.4444444444444445
# 3/3 [==============================] - 9s 3s/step - loss: 0.3112 - accuracy: 0.8773 - val_loss: 0.6478 - val_accuracy: 0.6939
# Epoch 49/100
# 14/14 [==============================] - 2s 159ms/step
# 2/2 [==============================] - 0s 130ms/step
# roc-auc_train:  0.9602490421455939
# roc-auc_val:  0.44871794871794873
# 3/3 [==============================] - 7s 2s/step - loss: 0.3014 - accuracy: 0.8909 - val_loss: 0.6426 - val_accuracy: 0.6939
# Epoch 50/100
# 14/14 [==============================] - 2s 137ms/step
# 2/2 [==============================] - 0s 113ms/step
# roc-auc_train:  0.959637079608344
# roc-auc_val:  0.48931623931623935
# 3/3 [==============================] - 10s 3s/step - loss: 0.2908 - accuracy: 0.9091 - val_loss: 0.6295 - val_accuracy: 0.6939
# Epoch 51/100
# 14/14 [==============================] - 2s 137ms/step
# 2/2 [==============================] - 0s 111ms/step
# roc-auc_train:  0.9666081311196254
# roc-auc_val:  0.5
# 3/3 [==============================] - 8s 2s/step - loss: 0.2788 - accuracy: 0.9023 - val_loss: 0.6375 - val_accuracy: 0.6939
# Epoch 52/100
# 14/14 [==============================] - 2s 136ms/step
# 2/2 [==============================] - 0s 115ms/step
# roc-auc_train:  0.970679012345679
# roc-auc_val:  0.5064102564102564
# 3/3 [==============================] - 7s 2s/step - loss: 0.2620 - accuracy: 0.9182 - val_loss: 0.6490 - val_accuracy: 0.6939
# Epoch 53/100
# 14/14 [==============================] - 2s 137ms/step
# 2/2 [==============================] - 0s 111ms/step
# roc-auc_train:  0.9728873988931461
# roc-auc_val:  0.5021367521367521
# 3/3 [==============================] - 6s 2s/step - loss: 0.2489 - accuracy: 0.9182 - val_loss: 0.6624 - val_accuracy: 0.6939
# Epoch 54/100
# 14/14 [==============================] - 2s 144ms/step
# 2/2 [==============================] - 0s 115ms/step
# roc-auc_train:  0.974537037037037
# roc-auc_val:  0.49786324786324787
# 3/3 [==============================] - 6s 2s/step - loss: 0.2413 - accuracy: 0.9205 - val_loss: 0.6837 - val_accuracy: 0.6735
# Epoch 55/100
# 14/14 [==============================] - 2s 141ms/step
# 2/2 [==============================] - 0s 116ms/step
# roc-auc_train:  0.9772775649212431
# roc-auc_val:  0.5192307692307693
# 3/3 [==============================] - 6s 2s/step - loss: 0.2378 - accuracy: 0.9273 - val_loss: 0.6785 - val_accuracy: 0.6531
# Epoch 56/100
# 14/14 [==============================] - 2s 138ms/step
# 2/2 [==============================] - 0s 115ms/step
# roc-auc_train:  0.9738452532992763
# roc-auc_val:  0.5427350427350428
# 3/3 [==============================] - 5s 2s/step - loss: 0.2228 - accuracy: 0.9205 - val_loss: 0.6720 - val_accuracy: 0.6735
# Epoch 57/100
# 14/14 [==============================] - 2s 140ms/step
# 2/2 [==============================] - 0s 112ms/step
# roc-auc_train:  0.9831311196253725
# roc-auc_val:  0.5128205128205129
# 3/3 [==============================] - 6s 2s/step - loss: 0.2225 - accuracy: 0.9182 - val_loss: 0.7005 - val_accuracy: 0.6735
# Epoch 58/100
# 14/14 [==============================] - 2s 138ms/step
# 2/2 [==============================] - 0s 113ms/step
# roc-auc_train:  0.9723020434227331
# roc-auc_val:  0.48504273504273504
# 3/3 [==============================] - 6s 2s/step - loss: 0.2160 - accuracy: 0.9250 - val_loss: 0.7266 - val_accuracy: 0.6327
# Epoch 59/100
# 14/14 [==============================] - 2s 142ms/step
# 2/2 [==============================] - 0s 117ms/step
# roc-auc_train:  0.9719295444870157
# roc-auc_val:  0.4978632478632479
# 3/3 [==============================] - 5s 2s/step - loss: 0.2351 - accuracy: 0.9068 - val_loss: 0.7287 - val_accuracy: 0.6327
# Epoch 60/100
# 14/14 [==============================] - 2s 140ms/step
# 2/2 [==============================] - 0s 115ms/step
# roc-auc_train:  0.9758673903788846
# roc-auc_val:  0.49786324786324787
# 3/3 [==============================] - 5s 2s/step - loss: 0.2340 - accuracy: 0.9182 - val_loss: 0.7206 - val_accuracy: 0.6122
# Epoch 61/100
# 14/14 [==============================] - 2s 140ms/step
# 2/2 [==============================] - 0s 116ms/step
# roc-auc_train:  0.9692422307364836
# roc-auc_val:  0.5427350427350428
# 3/3 [==============================] - 5s 2s/step - loss: 0.2256 - accuracy: 0.9182 - val_loss: 0.6984 - val_accuracy: 0.6327
# Epoch 62/100
# 14/14 [==============================] - 2s 140ms/step
# 2/2 [==============================] - 0s 124ms/step
# roc-auc_train:  0.9603554704129417
# roc-auc_val:  0.5769230769230769
# 3/3 [==============================] - 5s 2s/step - loss: 0.2214 - accuracy: 0.9114 - val_loss: 0.6864 - val_accuracy: 0.6735
# Epoch 63/100
# 14/14 [==============================] - 2s 140ms/step
# 2/2 [==============================] - 0s 114ms/step
# roc-auc_train:  0.962457428693061
# roc-auc_val:  0.5747863247863247
# 3/3 [==============================] - 5s 2s/step - loss: 0.2248 - accuracy: 0.9045 - val_loss: 0.6947 - val_accuracy: 0.6735
# Epoch 64/100
# 14/14 [==============================] - 2s 139ms/step
# 2/2 [==============================] - 0s 113ms/step
# roc-auc_train:  0.9702532992762878
# roc-auc_val:  0.561965811965812
# 3/3 [==============================] - 6s 2s/step - loss: 0.2222 - accuracy: 0.9068 - val_loss: 0.7086 - val_accuracy: 0.6735
# Epoch 65/100
# 14/14 [==============================] - 2s 140ms/step
# 2/2 [==============================] - 0s 113ms/step
# roc-auc_train:  0.9776766709237973
# roc-auc_val:  0.5427350427350427
# 3/3 [==============================] - 5s 2s/step - loss: 0.2157 - accuracy: 0.9136 - val_loss: 0.7263 - val_accuracy: 0.6735
# Epoch 66/100
# 14/14 [==============================] - 2s 140ms/step
# 2/2 [==============================] - 0s 123ms/step
# roc-auc_train:  0.9776766709237974
# roc-auc_val:  0.5512820512820513
# 3/3 [==============================] - 5s 2s/step - loss: 0.2047 - accuracy: 0.9205 - val_loss: 0.7420 - val_accuracy: 0.6735
# Epoch 67/100
# 14/14 [==============================] - 2s 140ms/step
# 2/2 [==============================] - 0s 115ms/step
# roc-auc_train:  0.9780491698595147
# roc-auc_val:  0.5405982905982907
# 3/3 [==============================] - 5s 2s/step - loss: 0.2026 - accuracy: 0.9227 - val_loss: 0.7563 - val_accuracy: 0.6735
# Epoch 68/100
# 14/14 [==============================] - 2s 142ms/step
# 2/2 [==============================] - 0s 115ms/step
# roc-auc_train:  0.9789804171988081
# roc-auc_val:  0.5470085470085471
# 3/3 [==============================] - 5s 2s/step - loss: 0.1976 - accuracy: 0.9273 - val_loss: 0.7685 - val_accuracy: 0.6735
# Epoch 69/100
# 14/14 [==============================] - 2s 140ms/step
# 2/2 [==============================] - 0s 115ms/step
# roc-auc_train:  0.9785014899957429
# roc-auc_val:  0.5555555555555556
# 3/3 [==============================] - 5s 2s/step - loss: 0.1969 - accuracy: 0.9295 - val_loss: 0.7805 - val_accuracy: 0.6735
# Epoch 70/100
# 14/14 [==============================] - 2s 142ms/step
# 2/2 [==============================] - 0s 114ms/step
# roc-auc_train:  0.9763463175819498
# roc-auc_val:  0.5491452991452991
# 3/3 [==============================] - 5s 2s/step - loss: 0.1970 - accuracy: 0.9295 - val_loss: 0.7622 - val_accuracy: 0.6735
# Epoch 71/100
# 14/14 [==============================] - 2s 141ms/step
# 2/2 [==============================] - 0s 121ms/step
# roc-auc_train:  0.9593177948063005
# roc-auc_val:  0.5576923076923077
# 3/3 [==============================] - 5s 2s/step - loss: 0.2138 - accuracy: 0.9182 - val_loss: 0.7074 - val_accuracy: 0.6939
# Epoch 72/100
# 14/14 [==============================] - 2s 139ms/step
# 2/2 [==============================] - 0s 111ms/step
# roc-auc_train:  0.9610472541507024
# roc-auc_val:  0.5811965811965812
# 3/3 [==============================] - 5s 2s/step - loss: 0.2378 - accuracy: 0.9000 - val_loss: 0.6808 - val_accuracy: 0.7143
# Epoch 73/100
# 14/14 [==============================] - 2s 139ms/step
# 2/2 [==============================] - 0s 113ms/step
# roc-auc_train:  0.9746434653043848
# roc-auc_val:  0.638888888888889
# 3/3 [==============================] - 5s 2s/step - loss: 0.2284 - accuracy: 0.9136 - val_loss: 0.6540 - val_accuracy: 0.6939
# Epoch 74/100
# 14/14 [==============================] - 2s 140ms/step
# 2/2 [==============================] - 0s 114ms/step
# roc-auc_train:  0.9755747126436781
# roc-auc_val:  0.6474358974358974
# 3/3 [==============================] - 5s 2s/step - loss: 0.2189 - accuracy: 0.9227 - val_loss: 0.6383 - val_accuracy: 0.7143
# Epoch 75/100
# 14/14 [==============================] - 2s 139ms/step
# 2/2 [==============================] - 0s 113ms/step
# roc-auc_train:  0.9765059599829715
# roc-auc_val:  0.6517094017094016
# 3/3 [==============================] - 5s 2s/step - loss: 0.2154 - accuracy: 0.9182 - val_loss: 0.6376 - val_accuracy: 0.7143
# Epoch 76/100
# 14/14 [==============================] - 2s 140ms/step
# 2/2 [==============================] - 0s 115ms/step
# roc-auc_train:  0.9785547041294167
# roc-auc_val:  0.6346153846153846
# 3/3 [==============================] - 5s 2s/step - loss: 0.2131 - accuracy: 0.9205 - val_loss: 0.6544 - val_accuracy: 0.6939
# Epoch 77/100
# 14/14 [==============================] - 2s 139ms/step
# 2/2 [==============================] - 0s 112ms/step
# roc-auc_train:  0.980656662409536
# roc-auc_val:  0.6047008547008548
# 3/3 [==============================] - 5s 2s/step - loss: 0.2041 - accuracy: 0.9250 - val_loss: 0.6829 - val_accuracy: 0.6531
# Epoch 78/100
# 14/14 [==============================] - 2s 138ms/step
# 2/2 [==============================] - 0s 119ms/step
# roc-auc_train:  0.9810291613452533
# roc-auc_val:  0.594017094017094
# 3/3 [==============================] - 5s 2s/step - loss: 0.1973 - accuracy: 0.9091 - val_loss: 0.7142 - val_accuracy: 0.6327
# Epoch 79/100
# 14/14 [==============================] - 2s 140ms/step
# 2/2 [==============================] - 0s 112ms/step
# roc-auc_train:  0.9811355896126011
# roc-auc_val:  0.5726495726495727
# 3/3 [==============================] - 5s 2s/step - loss: 0.1900 - accuracy: 0.9159 - val_loss: 0.7458 - val_accuracy: 0.6531
# Epoch 80/100
# 14/14 [==============================] - 2s 140ms/step
# 2/2 [==============================] - 0s 114ms/step
# roc-auc_train:  0.9829980842911877
# roc-auc_val:  0.5598290598290598
# 3/3 [==============================] - 5s 2s/step - loss: 0.1798 - accuracy: 0.9295 - val_loss: 0.7720 - val_accuracy: 0.6531
# Epoch 81/100
# 14/14 [==============================] - 2s 140ms/step
# 2/2 [==============================] - 0s 112ms/step
# roc-auc_train:  0.9853128991060025
# roc-auc_val:  0.5576923076923077
# 3/3 [==============================] - 5s 2s/step - loss: 0.1748 - accuracy: 0.9250 - val_loss: 0.7682 - val_accuracy: 0.6939
# Epoch 82/100
# 14/14 [==============================] - 2s 140ms/step
# 2/2 [==============================] - 0s 114ms/step
# roc-auc_train:  0.9858716475095786
# roc-auc_val:  0.5747863247863249
# 3/3 [==============================] - 5s 2s/step - loss: 0.1736 - accuracy: 0.9364 - val_loss: 0.7583 - val_accuracy: 0.6939
# Epoch 83/100
# 14/14 [==============================] - 2s 140ms/step
# 2/2 [==============================] - 0s 113ms/step
# roc-auc_train:  0.9864303959131545
# roc-auc_val:  0.5854700854700855
# 3/3 [==============================] - 5s 2s/step - loss: 0.1631 - accuracy: 0.9432 - val_loss: 0.7668 - val_accuracy: 0.6939
# Epoch 84/100
# 14/14 [==============================] - 2s 140ms/step
# 2/2 [==============================] - 0s 112ms/step
# roc-auc_train:  0.9885589612601107
# roc-auc_val:  0.5833333333333334
# 3/3 [==============================] - 5s 2s/step - loss: 0.1582 - accuracy: 0.9432 - val_loss: 0.7864 - val_accuracy: 0.6939
# Epoch 85/100
# 14/14 [==============================] - 2s 139ms/step
# 2/2 [==============================] - 0s 114ms/step
# roc-auc_train:  0.988904853128991
# roc-auc_val:  0.5705128205128205
# 3/3 [==============================] - 5s 2s/step - loss: 0.1443 - accuracy: 0.9432 - val_loss: 0.8290 - val_accuracy: 0.6735
# Epoch 86/100
# 14/14 [==============================] - 2s 140ms/step
# 2/2 [==============================] - 0s 116ms/step
# roc-auc_train:  0.9856055768412091
# roc-auc_val:  0.5876068376068376
# 3/3 [==============================] - 5s 2s/step - loss: 0.1496 - accuracy: 0.9318 - val_loss: 0.8485 - val_accuracy: 0.6531
# Epoch 87/100
# 14/14 [==============================] - 2s 140ms/step
# 2/2 [==============================] - 0s 111ms/step
# roc-auc_train:  0.9914857386121754
# roc-auc_val:  0.6068376068376069
# 3/3 [==============================] - 5s 2s/step - loss: 0.1516 - accuracy: 0.9318 - val_loss: 0.8141 - val_accuracy: 0.6531
# Epoch 88/100
# 14/14 [==============================] - 2s 141ms/step
# 2/2 [==============================] - 0s 113ms/step
# roc-auc_train:  0.9912196679438058
# roc-auc_val:  0.6132478632478633
# 3/3 [==============================] - 5s 2s/step - loss: 0.1381 - accuracy: 0.9455 - val_loss: 0.7964 - val_accuracy: 0.6735
# Epoch 89/100
# 14/14 [==============================] - 2s 140ms/step
# 2/2 [==============================] - 0s 114ms/step
# roc-auc_train:  0.99284269902086
# roc-auc_val:  0.6239316239316239
# 3/3 [==============================] - 5s 2s/step - loss: 0.1341 - accuracy: 0.9500 - val_loss: 0.7946 - val_accuracy: 0.6735
# Epoch 90/100
# 14/14 [==============================] - 2s 141ms/step
# 2/2 [==============================] - 0s 121ms/step
# roc-auc_train:  0.9914325244785014
# roc-auc_val:  0.6303418803418803
# 3/3 [==============================] - 5s 2s/step - loss: 0.1369 - accuracy: 0.9500 - val_loss: 0.8292 - val_accuracy: 0.6939
# Epoch 91/100
# 14/14 [==============================] - 2s 141ms/step
# 2/2 [==============================] - 0s 116ms/step
# roc-auc_train:  0.991139846743295
# roc-auc_val:  0.6217948717948718
# 3/3 [==============================] - 5s 2s/step - loss: 0.1270 - accuracy: 0.9568 - val_loss: 0.8658 - val_accuracy: 0.6735
# Epoch 92/100
# 14/14 [==============================] - 2s 140ms/step
# 2/2 [==============================] - 0s 114ms/step
# roc-auc_train:  0.991193060876969
# roc-auc_val:  0.6196581196581197
# 3/3 [==============================] - 5s 2s/step - loss: 0.1323 - accuracy: 0.9500 - val_loss: 0.8445 - val_accuracy: 0.6939
# Epoch 93/100
# 14/14 [==============================] - 2s 141ms/step
# 2/2 [==============================] - 0s 112ms/step
# roc-auc_train:  0.9951841209025116
# roc-auc_val:  0.6239316239316239
# 3/3 [==============================] - 5s 2s/step - loss: 0.1279 - accuracy: 0.9432 - val_loss: 0.8729 - val_accuracy: 0.6735
# Epoch 94/100
# 14/14 [==============================] - 2s 140ms/step
# 2/2 [==============================] - 0s 113ms/step
# roc-auc_train:  0.9949978714346531
# roc-auc_val:  0.6303418803418804
# 3/3 [==============================] - 5s 2s/step - loss: 0.1063 - accuracy: 0.9614 - val_loss: 0.8991 - val_accuracy: 0.6735
# Epoch 95/100
# 14/14 [==============================] - 2s 139ms/step
# 2/2 [==============================] - 0s 113ms/step
# roc-auc_train:  0.9927096636866751
# roc-auc_val:  0.6196581196581197
# 3/3 [==============================] - 5s 2s/step - loss: 0.1032 - accuracy: 0.9591 - val_loss: 0.9650 - val_accuracy: 0.6531
# Epoch 96/100
# 14/14 [==============================] - 2s 139ms/step
# 2/2 [==============================] - 0s 114ms/step
# roc-auc_train:  0.9948116219667944
# roc-auc_val:  0.6367521367521368
# 3/3 [==============================] - 5s 2s/step - loss: 0.1118 - accuracy: 0.9591 - val_loss: 0.8799 - val_accuracy: 0.7143
# Epoch 97/100
# 14/14 [==============================] - 2s 141ms/step
# 2/2 [==============================] - 0s 117ms/step
# roc-auc_train:  0.9949446573009791
# roc-auc_val:  0.6495726495726496
# 3/3 [==============================] - 5s 2s/step - loss: 0.1065 - accuracy: 0.9614 - val_loss: 0.8566 - val_accuracy: 0.7143
# Epoch 98/100
# 14/14 [==============================] - 2s 139ms/step
# 2/2 [==============================] - 0s 114ms/step
# roc-auc_train:  0.992204129416773
# roc-auc_val:  0.670940170940171
# 3/3 [==============================] - 5s 2s/step - loss: 0.0945 - accuracy: 0.9659 - val_loss: 0.8769 - val_accuracy: 0.6939
# Epoch 99/100
# 14/14 [==============================] - 2s 139ms/step
# 2/2 [==============================] - 0s 118ms/step
# roc-auc_train:  0.9880002128565347
# roc-auc_val:  0.6303418803418804
# 3/3 [==============================] - 5s 2s/step - loss: 0.1153 - accuracy: 0.9614 - val_loss: 1.0318 - val_accuracy: 0.6531
# Epoch 100/100
# 14/14 [==============================] - 2s 139ms/step
# 2/2 [==============================] - 0s 119ms/step
# roc-auc_train:  0.9161345253299276
# roc-auc_val:  0.688034188034188
# 3/3 [==============================] - 5s 2s/step - loss: 0.1393 - accuracy: 0.9500 - val_loss: 0.9738 - val_accuracy: 0.7143
# 1/1 [==============================] - 0s 374ms/step

# %%
y_pred = predict_with_model(X_test)
y_test = Y_test

from sklearn.metrics import precision_score, recall_score
y_pred_c = y_pred.round().astype(int)
precision = precision_score(y_test, y_pred_c)
recall = recall_score(y_test, y_pred_c)

loss, accuracy = model.evaluate(X_test, y_test)

print('Loss:', loss)
print('Accuracy:', accuracy)
print('Precision:', precision)
print('Recall:', recall)
Y_test.sum(), y_pred_c.sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/weasel/reps/ai-seizure-detectives/.temp/deepheaven.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell://wsl%2Bdebian/home/weasel/reps/ai-seizure-detectives/.temp/deepheaven.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> y_pred = predict_with_model(X_test)
#       <a href='vscode-notebook-cell://wsl%2Bdebian/home/weasel/reps/ai-seizure-detectives/.temp/deepheaven.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> y_test = Y_test
#       <a href='vscode-notebook-cell://wsl%2Bdebian/home/weasel/reps/ai-seizure-detectives/.temp/deepheaven.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> from sklearn.metrics import precision_score, recall_score
#
# NameError: name 'predict_with_model' is not defined

# %%
(y_pred_c[:,0].astype(bool) & y_test.astype(bool)).sum()
# Out:
# 6

# %%
y_pred = predict_with_model(X_test)
y_test = Y_test

from sklearn.metrics import precision_score, recall_score
y_pred_c = y_pred.round().astype(int)
precision = precision_score(y_test, y_pred_c)
recall = recall_score(y_test, y_pred_c)

loss, accuracy = model.evaluate(X_test, y_test)

print('Loss:', loss)
print('Accuracy:', accuracy)
print('Precision:', precision)
print('Recall:', recall)
Y_test.sum(), y_pred_c.sum()
# Out:
# 1/1 [==============================] - 0s 355ms/step
# 4/4 [==============================] - 1s 135ms/step - loss: 0.8821 - accuracy: 0.7398
# Loss: 0.8820559978485107
# Accuracy: 0.7398374080657959
# Precision: 0.5454545454545454
# Recall: 0.18181818181818182
# (33.0, 11)
